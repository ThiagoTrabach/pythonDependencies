# %% [markdown]
# # Análise das Dependências do Python

# %%
import pandas as pd
import requests
import urllib.request
import string
import numpy as np
import json
import collections
from bs4 import BeautifulSoup
import tqdm
import pickle
import time

# %matplotlib inline
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## 1. Web-Scraping dos Dados

# %% [markdown]
# ### 1.1. Scraping da Relação de Pacotes Científicos

# %% [markdown]
# Para o trabalho serão utilizados os pacotes científicos distribuidos pelo Anaconda. Na documentação do Ananconda são relacionados os pacotes de acordo com a versão do Python: 2.7, 3.4, 3.5 e 3.6

# %%
#Carrega as tabela a partir do html

pkgs_py27 = pd.read_html('https://docs.continuum.io/anaconda/pkg-docs',skiprows=1)[0]
pkgs_py34 = pd.read_html('https://docs.continuum.io/anaconda/pkg-docs',skiprows=1)[1]
pkgs_py35 = pd.read_html('https://docs.continuum.io/anaconda/pkg-docs',skiprows=1)[2]
pkgs_py36 = pd.read_html('https://docs.continuum.io/anaconda/pkg-docs',skiprows=1)[3]

# %%
#retirar as informações desnecessarias: 
#sistema operacional do pacote
def limpa_campo_pkg(pkgs):
    
    pkgs.columns = ['pkg', 'version', 'summary', 'in_installer']
    
    pkgs['pkg'] = pkgs.pkg.apply(lambda x: str(x).replace('Mac',''))
    pkgs['pkg'] = pkgs.pkg.apply(lambda x: str(x).replace('Linux',''))
    pkgs['pkg'] = pkgs.pkg.apply(lambda x: str(x).replace('Windows',''))
    pkgs['pkg'] = pkgs.pkg.apply(lambda x: str(x).rstrip())
    
    return pkgs

# %%
pkgs_py27 = limpa_campo_pkg(pkgs_py27)
pkgs_py34 = limpa_campo_pkg(pkgs_py34)
pkgs_py35 = limpa_campo_pkg(pkgs_py35)
pkgs_py36 = limpa_campo_pkg(pkgs_py36)

# %% [markdown]
# Para a obtenção dos links referentes a cada pacote que estão na tabela de pacotes, o método anterior não é efetivo. Será utilizado o Beautiful Soup 4.

# %%
def make_soup(url):
    the_page = urllib.request.urlopen(url)
    soup = BeautifulSoup(the_page,"html.parser")
    
    return soup

# %%
soup = make_soup('https://docs.continuum.io/anaconda/pkg-docs')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="en">
# <head>
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><script type="text/javascript">window.NREUM||(NREUM={}),__nr_require=function(e,n,t){function r(t){if(!n[t]){var o=n[t]={exports:{}};e[t][0].call(o.exports,function(n){var o=e[t][1][n];return r(o||n)},o,o.exports)}return n[t].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<t.length;o++)r(t[o]);return r}({1:[function(e,n,t){function r(){}function o(e,n,t){return function(){return i(e,[c.now()].concat(u(arguments)),n?null:this,t),n?void 0:this}}var i=e("handle"),a=e(2),u=e(3),f=e("ee").get("tracer"),c=e("loader"),s=NREUM;"undefined"==typeof window.newrelic&&(newrelic=s);var p=["setPageViewName","setCustomAttribute","setErrorHandler","finished","addToTrace","inlineHit","addRelease"],d="api-",l=d+"ixn-";a(p,function(e,n){s[n]=o(d+n,!0,"api")}),s.addPageAction=o(d+"addPageAction",!0),s.setCurrentRouteName=o(d+"routeName",!0),n.exports=newrelic,s.interaction=function(){return(new r).get()};var m=r.prototype={createTracer:function(e,n){var t={},r=this,o="function"==typeof n;return i(l+"tracer",[c.now(),e,t],r),function(){if(f.emit((o?"":"no-")+"fn-start",[c.now(),r,o],t),o)try{return n.apply(this,arguments)}finally{f.emit("fn-end",[c.now()],t)}}}};a("setName,setAttribute,save,ignore,onEnd,getContext,end,get".split(","),function(e,n){m[n]=o(l+n)}),newrelic.noticeError=function(e){"string"==typeof e&&(e=new Error(e)),i("err",[e,c.now()])}},{}],2:[function(e,n,t){function r(e,n){var t=[],r="",i=0;for(r in e)o.call(e,r)&&(t[i]=n(r,e[r]),i+=1);return t}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],3:[function(e,n,t){function r(e,n,t){n||(n=0),"undefined"==typeof t&&(t=e?e.length:0);for(var r=-1,o=t-n||0,i=Array(o<0?0:o);++r<o;)i[r]=e[n+r];return i}n.exports=r},{}],4:[function(e,n,t){n.exports={exists:"undefined"!=typeof window.performance&&window.performance.timing&&"undefined"!=typeof window.performance.timing.navigationStart}},{}],ee:[function(e,n,t){function r(){}function o(e){function n(e){return e&&e instanceof r?e:e?f(e,u,i):i()}function t(t,r,o,i){if(!d.aborted||i){e&&e(t,r,o);for(var a=n(o),u=m(t),f=u.length,c=0;c<f;c++)u[c].apply(a,r);var p=s[y[t]];return p&&p.push([b,t,r,a]),a}}function l(e,n){v[e]=m(e).concat(n)}function m(e){return v[e]||[]}function w(e){return p[e]=p[e]||o(t)}function g(e,n){c(e,function(e,t){n=n||"feature",y[t]=n,n in s||(s[n]=[])})}var v={},y={},b={on:l,emit:t,get:w,listeners:m,context:n,buffer:g,abort:a,aborted:!1};return b}function i(){return new r}function a(){(s.api||s.feature)&&(d.aborted=!0,s=d.backlog={})}var u="nr@context",f=e("gos"),c=e(2),s={},p={},d=n.exports=o();d.backlog=s},{}],gos:[function(e,n,t){function r(e,n,t){if(o.call(e,n))return e[n];var r=t();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,n,{value:r,writable:!0,enumerable:!1}),r}catch(i){}return e[n]=r,r}var o=Object.prototype.hasOwnProperty;n.exports=r},{}],handle:[function(e,n,t){function r(e,n,t,r){o.buffer([e],r),o.emit(e,n,t)}var o=e("ee").get("handle");n.exports=r,r.ee=o},{}],id:[function(e,n,t){function r(e){var n=typeof e;return!e||"object"!==n&&"function"!==n?-1:e===window?0:a(e,i,function(){return o++})}var o=1,i="nr@id",a=e("gos");n.exports=r},{}],loader:[function(e,n,t){function r(){if(!x++){var e=h.info=NREUM.info,n=d.getElementsByTagName("script")[0];if(setTimeout(s.abort,3e4),!(e&&e.licenseKey&&e.applicationID&&n))return s.abort();c(y,function(n,t){e[n]||(e[n]=t)}),f("mark",["onload",a()+h.offset],null,"api");var t=d.createElement("script");t.src="https://"+e.agent,n.parentNode.insertBefore(t,n)}}function o(){"complete"===d.readyState&&i()}function i(){f("mark",["domContent",a()+h.offset],null,"api")}function a(){return E.exists&&performance.now?Math.round(performance.now()):(u=Math.max((new Date).getTime(),u))-h.offset}var u=(new Date).getTime(),f=e("handle"),c=e(2),s=e("ee"),p=window,d=p.document,l="addEventListener",m="attachEvent",w=p.XMLHttpRequest,g=w&&w.prototype;NREUM.o={ST:setTimeo ...
# <meta content="OJZQjBWiBzXortqzYvmDhWW6RgksYQSThI4KUWweDsU" name="google-site-verification"/>
# <link href="https://docs.continuum.io/sites/all/themes/continuum_docs/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="Anaconda 4.3.1 includes an easy installation of Python (2.7.13, 3.4.5, 3.5.2, and/or 3.6.0) and updates of over 100 pre-built and tested scientific and analytic Python packages. These packages include NumPy, Pandas, SciPy, Matplotlib, and Jupyter. Over 620 more packages" name="description"/>
# <link href="https://docs.continuum.io/anaconda/pkg-docs" rel="canonical"/>
# <link href="https://docs.continuum.io/node/8185" rel="shortlink"/>
# <title>Anaconda package list | Continuum Analytics: Documentation</title>
# <link href="/sites/all/themes/continuum_docs/assets/images/favicons/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="/sites/all/themes/continuum_docs/assets/images/favicons/manifest.json" rel="manifest">
# <meta content="#ffffff" name="msapplication-TileColor">
# <meta content="/sites/all/themes/continuum_docs/assets/images/favicons/ms-icon-144x144.png" name="msapplication-TileImage">
# <meta content="#ffffff" name="theme-color"> <link href="https://docs.continuum.io/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://docs.continuum.io/sites/default/files/css/css_tGTNtRAsNJmcVz4r7F6YCijbrQGDbBmziHSrRd1Stqc.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://docs.continuum.io/sites/default/files/css/css_EPsgvacVXxxhwhLr4DGj8P1D4es4L_QnnRJPHn_TJHE.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://docs.continuum.io/sites/default/files/css/css_TC3MBATHfIki0zhbp7ptk7bFGEii_fTczbtGWPGGRU4.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://docs.continuum.io/sites/default/files/css/css_uE5qUMoVP7lqqI-rY2usPK_08FXK_zdChx_DXONzARE.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://docs.continuum.io/sites/default/files/css/css_PIKAzHiWi8mruPPFo5NuonAWRMoCAzJmVhThdiB-xfc.css" media="print" rel="stylesheet" type="text/css"/>
# <script src="https://docs.continuum.io/sites/all/libraries/modernizr/modernizr-latest.js?oqh8y9" type="text/javascript"></script>
# <script src="https://docs.continuum.io/sites/default/files/js/js_8_x2l8P4q48ZLPhwpWrqAqAyn1Btn5WWmZ8mjIaltds.js" type="text/javascript"></script>
# <script src="https://docs.continuum.io/sites/default/files/js/js_m_jimcnhFIj9PrGKuriUbpJzGdzO-vls5g5KWzKAIPc.js" type="text/javascript"></script>
# <script src="https://docs.continuum.io/sites/default/files/js/js_hDg2cAn4kQEMa_Y6cxLCtK3XsiwPV2KxtUxDJKNJ-kc.js" type="text/javascript"></script>
# <script src="https://docs.continuum.io/sites/default/files/js/js_tL-GB7EYwK1wvQZ_0oIR0ixY1BRWB3pnS1Xh5DnXk5Y.js" type="text/javascript"></script>
# <script src="https://docs.continuum.io/sites/default/files/js/js_PbPCmO1tsF3fnnnEvTqzv76UIS8rHcC6d4lJkMybd5w.js" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"continuum_docs","theme_token":"bxPJ4gSdXh8PupGBMZUR4LJEgrjdYuG9qrkwFn_MH0o","js":{"sites\/all\/modules\/contrib\/syntaxhighlighter\/syntaxhighlighter.min.js":1,"sites\/all\/libraries\/modernizr\/modernizr-latest.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/2.1\/jquery.min.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.core.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.widget.min.js":1,"sites\/all\/modules\/contrib\/syntaxhighlighter_insert\/syntaxhighlighter_insert.utils.js":1,"sites\/all\/modules\/contrib\/syntaxhighlighter_insert\/syntaxhighlighter_insert.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.button.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.mouse.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.draggable.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.position.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.resizable.min.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/ui\/minified\/jquery.ui.dialog.min.js":1,"sites\/all\/libraries\/syntaxhighlighter_3.0.83\/scripts\/shCore.js":1,"sites\/all\/libraries\/syntaxhighlighter_3.0.83\/scripts\/shBrushPhp.js":1,"misc\/textarea.js":1,"sites\/all\/modules\/contrib\/webform\/js\/webform.js":1,"sites\/all\/themes\/continuum_docs\/assets\/scripts\/jquery.jscrollpane.min.js":1,"sites\/all\/themes\/continuum_docs\/assets\/scripts\/continuum.lib.min.js":1,"sites\/all\/themes\/continuum_docs\/assets\/scripts\/continuum.init.js":1,"sites\/all\/themes\/continuum_docs\/assets\/scripts\/foundation.init.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.button.css":1,"misc\/ui\/jquery.ui.resizable.css":1,"misc\/ui\/jquery.ui.dialog.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/libraries\/syntaxhighlighter_3.0.83\/styles\/shCore.css":1,"sites\/all\/libraries\/syntaxhighlighter_3.0.83\/styles\/shThemeDefault.css":1,"sites\/default\/files\/honeypot\/honeypot.css":1,"sites\/all\/modules\/contrib\/webform\/css\/webform.css":1,"sites\/all\/modules\/contrib\/syntaxhighlighter_insert\/syntaxhighlighter_insert_wysiwyg\/syntaxhighlighter_insert_wysiwyg.css":1,"sites\/all\/themes\/continuum_docs\/assets\/styles\/css\/lib.css":1,"sites\/all\/themes\/continuum_docs\/assets\/styles\/css\/site.css":1,"sites\/all\/themes\/continuum_docs\/assets\/styles\/css\/ie9.css":1,"sites\/all\/themes\/continuum_docs\/assets\/styles\/css\/print.css":1}},"syntaxhighlighter_insert_wysiwyg":{"current_form":"form-bQ6qYRd3lZj613lusFBMxvxFiNcHBzxEUNwpQIJYRfs"},"webform":{"conditionals":{"webform-client-form-100":{"ruleGroups":{"rgid_0":{"andor":"or","actions":{"aid_0":{"target":"webform-component--how-to-improve-this-page","invert":0,"action":"show","argument":""},"aid_1":{"target":"webform-component--email","invert":0,"action":"show","argument":""}},"rules":{"rid_0":{"source_type":"component","source":"webform-component--was-this-helpful","value":"Yes","callback":"conditionalOperatorStringEqual"},"rid_1":{"source_type":"component","sour ...
# //--><!]]>
# </script>
# <!-- Optimizely -->
# <script src="https://cdn.optimizely.com/js/5392410081.js"></script>
# <!-- End Optimizely -->
# <!--[if lt IE 9]>
#     <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
#   <![endif]-->
# </meta></meta></meta></link></meta></meta></head>
# <!--[if IE 9 ]>
#   <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-8185 node-type-doc-cache panels-layout-continuum_two_col ie9" >
#   <![endif]-->
# <!--[if (gt IE 9)|(gt IEMobile 7)|!(IEMobile)|!(IE)]><!-->
# <body class="html not-front not-logged-in no-sidebars page-node page-node- page-node-8185 node-type-doc-cache panels-layout-continuum_two_col">
# <!--<![endif]-->
# <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#       ga('create', 'UA-91143514-1', 'auto');
#       ga('send', 'pageview');
#
#     </script>
# <div class="row light-on-dark-copy">
# <a class="show-on-focus skip-to-main" href="#main-content">Skip to main content</a>
# </div>
# <div class="off-canvas-wrap" data-offcanvas="offcanvas-main">
# <div class="inner-wrap">
# <header class="brand-header">
# <div class="content-wrapper">
# <div class="columns small-6 medium-6 large-6">
# <a aria-label="Anaconda Powered by Continuum Analytics. Click to return home." class="image-link " href="/" role="button">
# <img aria-hidden="true" class="logo" src="/sites/all/themes/continuum_docs/assets/images/logos/logo-docs.svg">
# </img></a>
# </div>
# <div class="columns large-3 small-2 right">
# <div class="row">
# <div class="columns">
# <div class="header-search">
# <form accept-charset="UTF-8" action="/search_docs" class="header-search__form hide-for-medium-down" id="apachesolr-panels-search-form" method="POST" role="search">
# <label class="header-search__input-label" for="search-input">Search</label>
# <input class="header-search__input" name="apachesolr_panels_search_form" placeholder="Search" type="text"/>
# <input name="form_id" type="hidden" value="apachesolr_panels_search_form"/>
# <input name="form_build_id" type="hidden" value="form-bQ6qYRd3lZj613lusFBMxvxFiNcHBzxEUNwpQIJYRfs"/>
# <input class="header-search__submit" type="submit"/>
# </form>
# <a class="search__link" href="/search_docs">
# <span class="search__link-icon"></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div></header> <div class="page-utility-wrapper">
# </div>
# <main id="main-content">
# <div class="content-wrapper">
# <div class="breadcrumb-wrapper">
# <div class="breadcrumb-container">
# <button class="anchor toggle-sidebar menu-icon menu-icon" href="#">
# <i class="fa fa-bars"></i>
# </button>
# <div class="region region-breadcrumb">
# <div class="block block-crumbs" id="block-crumbs-breadcrumb">
# <div class="content">
# <h2 class="element-invisible">You are here</h2><div class="breadcrumb"><a href="/">Home</a><span class="crumbs-separator"> / </span><a href="/anaconda/">Anaconda</a><span class="crumbs-separator"> / </span><span class="crumbs-current-page">Anaconda package list</span></div> </div>
# </div>
# </div>
# </div>
# </div>
# <div>
# <div class="region region-content">
# <div class="block block-system" id="block-system-main">
# <div class="content">
# <div class="layout-two-col ">
# <aside class="layout-two-col__second natural" id="layout-two-col-sidebar" role="complementary">
# <div class="sidebar-close"></div>
# <div class="panel-pane pane-entity-field pane-node-field-doc-navigation-menu">
# <div class="pane-content">
# <div class="field field-name-field-doc-navigation-menu field-type-text-long field-label-hidden"><div class="field-items"><div class="field-item even">
# <ul class="current">
# <li class="toctree-l1"><a class="reference external" href="http://docs.continuum.io">Anaconda Platform</a></li>
# <li class="toctree-l1"><a class="reference external" href="http://docs.continuum.io">– Welcome</a></li>
# <li class="toctree-l1 current"><a class="reference internal" href="./">– Anaconda</a><ul class="current">
# <li class="toctree-l2"><a class="reference internal" href="./#navigator-or-conda">Navigator or conda?</a></li>
# <li class="toctree-l2"><a class="reference internal" href="./#product-specifications">Product specifications</a></li>
# <li class="toctree-l2"><a class="reference internal" href="./#packages-available-in-anaconda">Packages available in Anaconda</a></li>
# <li class="toctree-l2"><a class="reference internal" href="./#high-performance">High performance</a></li>
# <li class="toctree-l2"><a class="reference internal" href="./#what-s-new-in-anaconda-4-3">What’s new in Anaconda 4.3?</a></li>
# <li class="toctree-l2"><a class="reference internal" href="./#previous-versions">Previous versions</a></li>
# <li class="toctree-l2"><a class="reference internal" href="./#product-archive">Product archive</a></li>
# <li class="toctree-l2 current"><a class="reference internal" href="./#support">Support</a><ul class="current">
# <li class="toctree-l3"><a class="reference internal" href="install">Anaconda install</a></li>
# <li class="toctree-l3"><a class="reference internal" href="hashes/">Anaconda installer file hashes</a></li>
# <li class="toctree-l3 current"><a class="current reference internal" href="#">Anaconda package list</a></li>
# <li class="toctree-l3"><a class="reference internal" href="r-language-pkg-docs">R language packages for Anaconda</a></li>
# <li class="toctree-l3"><a class="reference internal" href="glossary">Anaconda glossary</a></li>
# <li class="toctree-l3"><a class="reference internal" href="changelog">Anaconda changelog</a></li>
# <li class="toctree-l3"><a class="reference internal" href="navigator/">Anaconda Navigator</a></li>
# <li class="toctree-l3"><a class="reference internal" href="ide_integration">How to set up an IDE to use Anaconda</a></li>
# <li class="toctree-l3"><a class="reference internal" href="jupyter-notebook-extensions">Jupyter Notebook Extensions</a></li>
# <li class="toctree-l3"><a class="reference internal" href="r_language">Using R Language with Anaconda</a></li>
# <li class="toctree-l3"><a class="reference internal" href="images">Anaconda integrations</a></li>
# <li class="toctree-l3"><a class="reference internal" href="excel">Excel plug-ins for Anaconda</a></li>
# <li class="toctree-l3"><a class="reference internal" href="oldpkglists">Old package lists</a></li>
# <li class="toctree-l3"><a class="reference internal" href="eula">Anaconda End User License Agreement</a></li>
# <li class="toctree-l3"><a class="reference internal" href="faq">Anaconda FAQ</a></li>
# <li class="toctree-l3"><a class="reference internal" href="troubleshooting">Troubleshooting</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="toctree-l1"><a class="reference internal" href="../anaconda-repository/">– Anaconda Repository</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../accelerate/">– Anaconda Accelerate</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../anaconda-adam/">– Anaconda Adam</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../ae-notebooks/">– Anaconda Enterprise Notebooks</a></li>
# <li class="toctree-l1"><a class="reference internal" href="fusion/">– Anaconda Fusion</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../anaconda-scale/">– Anaconda Scale</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../anaconda-cloud/">– Anaconda Cloud</a></li>
# <li class="toctree-l1"><a class="reference external" href="https://continuum.io/open-source-core-modern-software">Continuum-sponsored OSS programs</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../docs_oss/blaze/">– Blaze</a></li>
# <li class="toctree-l1"><a class="reference external" href="http://bokeh.pydata.org/">– Bokeh</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../docs_oss/conda/">– Conda</a></li>
# <li class="toctree-l1"><a class="reference external" href="http://dask.readthedocs.org/en/latest/">– dask</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../docs_oss/llvmlite/">– llvmlite</a></li>
# <li class="toctree-l1"><a class="reference external" href="https://phosphorjs.github.io/docs">– PhosphorJS</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../docs_oss/numba/">– Numba</a></li>
# <li class="toctree-l1"><a class="reference internal" href="../docs_oss/">Top OSS programs</a></li>
# </ul>
# </div></div></div> </div>
# </div>
# </aside>
# <main class="layout-two-col__first" role="main">
# <div class="panel-pane pane-entity-view pane-node">
# <div class="pane-content">
# <article about="/anaconda/pkg-docs" class="node-page" typeof="sioc:Item foaf:Document">
# <h1 class="main-headline">Anaconda package list</h1>
# <span class="rdf-meta element-hidden" content="Anaconda package list" property="dc:title"></span>
# <div class="field field-name-body field-type-text-with-summary field-label-hidden"><div class="field-items"><div class="field-item even" property="content:encoded">
# <div class="documentwrapper">
# <div class="bodywrapper">
# <div class="body" role="main">
# <div class="section" id="anaconda-package-list">
# <p><a class="reference external" href="https://www.continuum.io/downloads">Anaconda 4.3.1</a> includes an easy
# installation of Python (2.7.13, 3.4.5, 3.5.2, and/or 3.6.0) and updates of over
# 100 pre-built and tested scientific and analytic Python packages. These packages
# include NumPy, Pandas, SciPy, Matplotlib, and Jupyter. Over 620 more packages
# are available. You can install any of them with just one command:</p>
# <div class="highlight-default"><div class="highlight"><pre><span></span><span class="n">conda</span> <span class="n">install</span> <span class="n">package</span><span class="o">-</span><span class="n">name</span>
# </pre></div>
# </div>
# <p>NOTE: Replace “package-name” with the name of the package to install.</p>
# <p>Anaconda includes several open source development environments such as
# Jupyter/IPython, Spyder and <a class="reference external" href="https://www.visualstudio.com/vs/python/">Visual Studio</a>,
# and is supported by Sublime Text 2 and PyCharm. Packages are regularly added.
# Anaconda is available for Linux, macOS and Windows, and is always proudly
# free and Open Source. Packages that are only available for some operating systems are noted with
# <code class="docutils literal"><span class="pre">Linux</span></code> and/or <code class="docutils literal"><span class="pre">Windows</span></code> and/or <code class="docutils literal"><span class="pre">Mac</span></code> listed in superscript next to the package name.</p>
# <ul class="simple">
# <li>All packages in the current version of Anaconda can be found in
# the <a class="reference external" href="http://repo.continuum.io/pkgs/">package repository</a>.</li>
# <li>An <a class="reference external" href="http://repo.continuum.io/pkgs/rss.xml">RSS feed</a> is updated each time
# a new package is added to the Anaconda package repository.</li>
# <li>Lists of packages for prior versions of Anaconda are available on <a class="reference internal" href="oldpkglists.html"><span class="doc">Old
# package lists</span></a>.</li>
# </ul>
# <p>A full list of packages available in the latest release of Anaconda is below.
# Click the tabs to see which packages are available for each version of Python.</p>
# <p>If you need a package that’s not availble on this page, please go to
# the <a class="reference external" href="https://github.com/ContinuumIO/anaconda-issues/issues">Anaconda issues page</a>
# and click the Submit button to request one.</p>
# <div class="tab-python-packages container" id="python-packages">
# <ul class="tabs" data-tab="">
# <li class="tab-title active">
# <a data-toggle="tab" href="#python-2-7">
#       Python version: 2.7
#     </a>
# </li>
# <li class="tab-title">
# <a data-toggle="tab" href="#python-3-4">
#       Python version: 3.4
#     </a>
# </li>
# <li class="tab-title">
# <a data-toggle="tab" href="#python-3-5">
#       Python version: 3.5
#     </a>
# </li>
# <li class="tab-title">
# <a data-toggle="tab" href="#python-3-6">
#       Python version: 3.6
#     </a>
# </li>
# </ul><div class="tabs-content container" id="tabs-content-packages">
# <div class="content active container" id="python-2-7">
# <p>Python version: 2.7</p>
# <p>Number of supported packages: 521</p>
# <table border="1" class="docutils">
# <tr class="row-odd">
# <th>Name</th>
# <th>Version</th>
# <th>Summary / License</th>
# <th>In Installer</th>
# </tr>
# <tr>
# <td><a href="https://github.com/sgillies/affine">affine</a></td>
# <td>2.0.0</td>
# <td>Matrices describing affine transformation of the plane. / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.sphinx-doc.org/en/stable/index.html">alabaster</a></td>
# <td>0.7.9</td>
# <td>Configurable, Python 2+3 compatible Sphinx theme / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.alpacajs.org/">alpaca_static</a></td>
# <td>1.5.17</td>
# <td>Easy Forms for jQuery / Apache License 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ContinuumIO/anaconda-clean">anaconda-clean</a></td>
# <td>1.1.0</td>
# <td>Delete Anaconda configuration files / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://anaconda.org">anaconda-client</a></td>
# <td>1.6.0</td>
# <td>anaconda.org command line client library / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ContinuumIO/navigator">anaconda-navigator</a></td>
# <td>1.5.0</td>
# <td>Anaconda Navigator / proprietary - Continuum Analytics, Inc.</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Anaconda-Platform/anaconda-project/">anaconda-project</a></td>
# <td>0.4.1</td>
# <td>reproducible, executable project directories / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ContinuumIO/anaconda-verify">anaconda-verify</a></td>
# <td>1.3.2</td>
# <td>tool for (passively) verifying conda recipes and conda packages / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://pypi.python.org/pypi/ansi2html">ansi2html</a></td>
# <td>1.1.1</td>
# <td>Convert text with ANSI color codes to HTML or to LaTeX. / GPLv3+</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://github.com/ActiveState/appdirs">appdirs</a></td>
# <td>1.4.0</td>
# <td>Python module for determining appropriate platform-specific dirs / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://github.com/minrk/appnope">appnope</a> <sup>Mac</sup></td>
# <td>0.1.0</td>
# <td>Disable App Nap on OS X 10.9 / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://appscript.sourceforge.net/">appscript</a> <sup>Mac</sup></td>
# <td>1.0.1</td>
# <td>Control AppleScriptable applications from Python / Public-Domain</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/enthought/apptools">apptools</a></td>
# <td>4.4.0</td>
# <td>Includes packages useful for creating applications / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://apr.apache.org/">apr</a></td>
# <td>1.5.2</td>
# <td>Maintains a consistent API with predictable behaviour / Apache License 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://argcomplete.readthedocs.org/en/latest/">argcomplete</a></td>
# <td>1.0.0</td>
# <td>Bash tab completion of arguments for Python scripts / Apache</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://www.astroid.org/">astroid</a></td>
# <td>1.4.9</td>
# <td>abstract syntax tree for Python with inference support / LGPL</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.astropy.org/">astropy</a></td>
# <td>1.3</td>
# <td>Community-developed Python Library for Astronomy / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/nucleic/atom">atom</a></td>
# <td>0.3.10</td>
# <td>Framework for creating memory efficient Python objects / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://attrs.readthedocs.org/">attrs</a></td>
# <td>15.2.0</td>
# <td>Implement attribute-related object protocols without boilerplate / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.gnu.org/software/autoconf/">autoconf</a> <sup>Linux Mac</sup></td>
# <td>2.69</td>
# <td>M4 Macros to automatically configure software source code / GPL3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.gnu.org/software/automake/">automake</a> <sup>Linux Mac</sup></td>
# <td>1.15</td>
# <td>Tool to automatically generate Makefile.in files / GPL3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Azure/azure-sdk-for-python">azure</a></td>
# <td>1.0.2</td>
# <td>Microsoft Azure SDK for Python / Apache License 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://babel.pocoo.org/">babel</a></td>
# <td>2.3.4</td>
# <td>Utilities to internationalize and localize Python applications / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="None">backports</a></td>
# <td>1.0</td>
# <td> / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/cython/backports_abc">backports_abc</a></td>
# <td>0.5</td>
# <td>backport of recent additions to the 'collections.abc' module / PSF</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://matplotlib.org/basemap/">basemap</a></td>
# <td>1.0.7</td>
# <td>Plot data on map projections with matplotlib / PSF</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://bcolz.blosc.org/">bcolz</a></td>
# <td>1.0.0</td>
# <td>provides columnar, chunked and compressable data containers. / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/pyca/bcrypt/">bcrypt</a></td>
# <td>3.1.2</td>
# <td>modern password hashing for your software and your servers / Apache License, Version 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.crummy.com/software/BeautifulSoup/">beautifulsoup4</a></td>
# <td>4.5.3</td>
# <td>Python library designed for screen-scraping / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://biopython.org/">biopython</a></td>
# <td>1.68</td>
# <td>Freely available tools for biological computation / BSD-like</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ilanschnell/bitarray">bitarray</a></td>
# <td>0.8.1</td>
# <td>efficient representation of arrays of booleans -- C extension / PSF</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://blaze.pydata.org">blaze</a></td>
# <td>0.10.1</td>
# <td>NumPy and Pandas interface to big data / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/mozilla/bleach">bleach</a></td>
# <td>1.5.0</td>
# <td>easy whitelist-based HTML-sanitizing tool / Apache Software License</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://stutzbachenterprises.com/blist/">blist</a></td>
# <td>1.3.6</td>
# <td>Replacement for Python lists with better performance / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://bokeh.pydata.org/">bokeh</a></td>
# <td>0.12.4</td>
# <td>Python interactive visualization library for modern web browsers / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.boost.org/">boost</a></td>
# <td>1.61.0</td>
# <td>Boost provides free peer-reviewed portable C++ source libraries. / <a href="http://www.boost.org/users/license.html">Boost license</a></td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/boto/boto/">boto</a></td>
# <td>2.45.0</td>
# <td>Amazon Web Services Library / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://aws.amazon.com/sdk-for-python/">boto3</a></td>
# <td>1.4.3</td>
# <td>Amazon Web Services SDK for Python / Apache License 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://aws.amazon.com/sdk-for-python/">botocore</a></td>
# <td>1.4.90</td>
# <td>low-level, core functionality of boto3 / <a href="http://aws.amazon.com/apache2.0/">Apache License 2.0</a></td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/biolab/bottlechest">bottlechest</a></td>
# <td>0.7.1</td>
# <td>fast NumPy array functions specialized for use in Orange / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://berkeleyanalytics.com/bottleneck">bottleneck</a></td>
# <td>1.2.0</td>
# <td>Fast NumPy array functions written in Cython. / Simplified BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://docs.python.org/2/library/bsddb.html">bsddb</a> <sup>Linux Mac</sup></td>
# <td>1.0</td>
# <td>The bsddb module provides an interface to the Berkeley DB library / PSF</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ilanschnell/bsdiff4">bsdiff4</a></td>
# <td>1.1.5</td>
# <td>binary diff and patch using the BSDIFF4-format / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://packages.python.org/BTrees">btrees</a></td>
# <td>4.3.2</td>
# <td>scalable persistent object containers / ZPL 2.1</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/nvawda/bz2file">bz2file</a></td>
# <td>0.98</td>
# <td>library for reading and writing bzip2-compressed files / Apache License, Version 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.bzip.org/">bzip2</a></td>
# <td>1.0.6</td>
# <td>high-quality data compressor / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ionrock/cachecontrol">cachecontrol</a></td>
# <td>0.11.7</td>
# <td>httplib2 caching algorithms for use with requests / Apache Software License</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/pydanny/cached-property">cached-property</a></td>
# <td>1.3.0</td>
# <td>A decorator for caching properties in classes / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://caffe.berkeleyvision.org/">caffe</a> <sup>Linux</sup></td>
# <td>1.0.0rc3</td>
# <td>A deep learning framework made with expression, speed, and modularity in mind. / BSD 2-Clause</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://cairographics.org/">cairo</a> <sup>Linux</sup></td>
# <td>1.14.8</td>
# <td>A 2D graphics library with support for multiple output devices / LGPL 2.1, MPL 1.1</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/enthought/casuarius">casuarius</a></td>
# <td>1.1</td>
# <td>Cython bindings for the Cassowary Constraint Solving Toolkit / LGPL</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.bytereef.org/mpdecimal/index.html">cdecimal</a></td>
# <td>2.3</td>
# <td>Fast drop-in replacement for decimal.py / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://certifi.io">certifi</a></td>
# <td>2016.2.28</td>
# <td>Python package for providing Mozilla's CA Bundle. / ISC</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://cffi.readthedocs.org">cffi</a></td>
# <td>1.9.1</td>
# <td>C Foreign Function Interface for Python / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Anaconda-Server/chalmers">chalmers</a></td>
# <td>0.8.0</td>
# <td>Monitor and control a number of processes on any operating system / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://chameleon.readthedocs.org">chameleon</a></td>
# <td>2.24</td>
# <td>HTML/XML template engine for Python / BSD-like</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/chardet/chardet">chardet</a></td>
# <td>2.3.0</td>
# <td>Universal character encoding detector / GNU Library or Lesser General Public License</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.cheetahtemplate.org/">cheetah</a></td>
# <td>2.4.4</td>
# <td>Cheetah is a template engine and code generation tool. / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.cherrypy.org">cherrypy</a></td>
# <td>3.8.0</td>
# <td>Pythonic, object-oriented web framework / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ContinuumIO/chest">chest</a></td>
# <td>0.2.3</td>
# <td>A dictionary that writes its contents to disk / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://packages.qa.debian.org/c/chrpath.html">chrpath</a> <sup>Linux</sup></td>
# <td>0.16</td>
# <td>Tool to edit the rpath in ELF binaries / GPL2</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://click.pocoo.org/">click</a></td>
# <td>6.7</td>
# <td>Command line interface creation kit / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/click-contrib/click-plugins">click-plugins</a></td>
# <td>1.0.3</td>
# <td>extension module for click to enable registering CLI commands / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/mapbox/cligj">cligj</a></td>
# <td>0.4.0</td>
# <td>Click-based argument and option decorators / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/cloudpipe/cloudpickle">cloudpickle</a></td>
# <td>0.2.2</td>
# <td>Extended pickling support for Python objects / <a href="https://github.com/cloudpipe/cloudpickle/blob/master/LICENSE">BSD</a></td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Anaconda-Server/clyent">clyent</a></td>
# <td>1.2.2</td>
# <td>Command line client library for windows and posix / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.cmake.org/">cmake</a> <sup>Linux Mac</sup></td>
# <td>3.6.3</td>
# <td>CMake is an extensible, open-source system that manages the build process / BSD 3-clause</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Pylons/colander">colander</a></td>
# <td>1.2</td>
# <td>A serialization, deserialization, and validation library / <a href="http://www.repoze.org/LICENSE.txt">BSD-like</a></td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/tartley/colorama">colorama</a></td>
# <td>0.3.7</td>
# <td>Cross-platform colored terminal text in Python / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/bokeh/colorcet">colorcet</a></td>
# <td>0.9.1</td>
# <td>collection of perceptually uniform colormaps / Creative Commons Attribution 4.0 International Public License</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://starship.python.net/crew/theller/comtypes/">comtypes</a> <sup>Windows</sup></td>
# <td>1.1.2</td>
# <td>pure Python COM package / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://conda.pydata.org/">conda</a></td>
# <td>4.3.14</td>
# <td>OS-agnostic, system-level binary package and environment manager. / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/conda/conda-build">conda-build</a></td>
# <td>2.1.2</td>
# <td>Commands and tools for building conda packages / BSD 3-clause</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="None">conda-env</a></td>
# <td>2.6.0</td>
# <td> / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/conda/conda-verify">conda-verify</a></td>
# <td>2.0.0</td>
# <td>tool for (passively) verifying conda recipes and conda packages / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/zorro3/ConfigArgParse">configargparse</a></td>
# <td>0.11.0</td>
# <td>allowing options to be set via config files and/or env vars / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.voidspace.org.uk/python/configobj.html">configobj</a></td>
# <td>5.0.6</td>
# <td>Config file reading, writing and validation / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://docs.python.org/3/library/configparser.html">configparser</a></td>
# <td>3.5.0</td>
# <td>brings the updated configparser from Python 3.5 to Python 2.6-3.5 / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/twisted/constantly">constantly</a></td>
# <td>15.1.0</td>
# <td>symbolic constants in Python / MIT License</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/conda/constructor">constructor</a></td>
# <td>1.5.2</td>
# <td>Tool for  creating installers for conda packages / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://contextlib2.readthedocs.org/">contextlib2</a></td>
# <td>0.5.4</td>
# <td>backports and enhancements for the contextlib module / PSF</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/sashahart/cookies">cookies</a></td>
# <td>2.2.1</td>
# <td>Friendlier RFC 6265-compliant cookie parser/renderer / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://cornice.readthedocs.org/">cornice</a></td>
# <td>1.2.1</td>
# <td>build and document Web Services with Pyramid / MPL 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://coverage.readthedocs.org">coverage</a></td>
# <td>4.2</td>
# <td>Code coverage measurement for Python / Apache 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://cryptography.io">cryptography</a></td>
# <td>1.7.1</td>
# <td>Provides cryptographic recipes and primitives to Python developers / Apache</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://packages.python.org/cssselect/">cssselect</a></td>
# <td>1.0.0</td>
# <td>cssselect parses CSS3 Selectors and translates them to XPath 1.0 / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://csvkit.rtfd.org/">csvkit</a></td>
# <td>0.9.1</td>
# <td>utilities for working with CSV, the king of tabular file formats / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://cubes.databrewery.org/">cubes</a></td>
# <td>1.1</td>
# <td>A light-weight Python OLAP framework for data warehouses / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://curl.haxx.se/">curl</a></td>
# <td>7.52.1</td>
# <td>Tool and library for transferring data with URL syntax / <a href="http://curl.haxx.se/docs/copyright.html">MIT/X derivate</a></td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/jacklzhu/CVXcanon">cvxcanon</a></td>
# <td>0.0.23.3</td>
# <td>Low-level library to perform the matrix building step in CVXPY / GPL3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://cvxopt.org/">cvxopt</a> <sup>Linux Mac</sup></td>
# <td>1.1.8</td>
# <td>Library for convex optimization / GPL</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://matplotlib.org/cycler/">cycler</a></td>
# <td>0.10.0</td>
# <td>Composable style cycles / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/syllog1sm/cymem">cymem</a> <sup>Linux Mac</sup></td>
# <td>1.31.2</td>
# <td>Manage calls to malloc/free through Cython / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.cython.org/">cython</a></td>
# <td>0.25.2</td>
# <td>The Cython compiler for writing C extensions for the Python language / Apache version 2.0</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/pytoolz/cytoolz">cytoolz</a></td>
# <td>0.8.2</td>
# <td>Cython implementation of Toolz, high performance functional utilities / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://dask.pydata.org/en/latest/">dask</a></td>
# <td>0.13.0</td>
# <td>Task scheduling and blocked algorithms for parallel processing / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/bokeh/datashader">datashader</a></td>
# <td>0.4.0</td>
# <td>graphics pipeline system for creating representations of large amounts / New BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://datashape.pydata.org">datashape</a></td>
# <td>0.5.4</td>
# <td>Language defining a data description protocol / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/kmike/datrie/">datrie</a></td>
# <td>0.7.1</td>
# <td>Super-fast, efficiently stored Trie for Python, uses libdatrie / LGPLv2</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.oracle.com/us/products/database/berkeley-db/index.html">db</a> <sup>Linux Mac</sup></td>
# <td>5.3.28</td>
# <td>Embeddable Databases / AGPLv3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://pypi.python.org/pypi/dbf">dbf</a></td>
# <td>0.96.003</td>
# <td>Reading/writing dBase, FoxPro, and Visual FoxPro .dbf files / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.freedesktop.org/wiki/Software/dbus/">dbus</a> <sup>Linux</sup></td>
# <td>1.10.10</td>
# <td>message bus system, a simple way for applications to talk to one another / GPL2</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://pypi.python.org/pypi/decorator">decorator</a></td>
# <td>4.0.11</td>
# <td>Better living through Python with decorators / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.cacr.caltech.edu/~mmckerns/dill.htm">dill</a></td>
# <td>0.2.5</td>
# <td>Serialize all of python (almost) / 3-clause BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://distributed.readthedocs.org/en/latest/">distributed</a></td>
# <td>1.15.1</td>
# <td>Lightweight library for distributed computing in Python / BSD 3-Clause</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.djangoproject.com/">django</a></td>
# <td>1.10.5</td>
# <td>Web framework that encourages rapid development / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.dnspython.org/">dnspython</a></td>
# <td>1.14.0</td>
# <td>DNS toolkit for Python / <a href="http://www.dnspython.org/LICENSE">BSD-style</a></td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://docopt.org/">docopt</a></td>
# <td>0.6.2</td>
# <td>Command-line interface description language / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://docutils.sourceforge.net">docutils</a></td>
# <td>0.13.1</td>
# <td>Utilities for general- and special-purpose documentation / Public-Domain, PSF, 2-clause BSD, GPLv3</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/warner/python-ecdsa">ecdsa</a></td>
# <td>0.13</td>
# <td>ECDSA cryptographic signature library (pure Python) / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://www.embotech.com/ECOS">ecos</a></td>
# <td>2.0.4</td>
# <td>Embedded Conic Solver (ECOS) / GPL3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/takluyver/entrypoints">entrypoints</a></td>
# <td>0.2.2</td>
# <td> / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://pypi.python.org/pypi/enum34">enum34</a></td>
# <td>1.1.6</td>
# <td>Robust enumerated type support in Python / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://code.enthought.com/projects/envisage/">envisage</a></td>
# <td>4.5.1</td>
# <td>Extensible application framework / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://rhodesmill.org/pyephem/">ephem</a> <sup>Linux Mac</sup></td>
# <td>3.7.6.0</td>
# <td>Basic astronomical computations for Python / LGPL</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://sourceforge.net/projects/essbasepy/">essbasepy</a></td>
# <td>11.1.2012.0514</td>
# <td>access to Oracle Essbase multi-dimensional databases using MaxL / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://bitbucket.org/openpyxl/et_xmlfile">et_xmlfile</a></td>
# <td>1.0.1</td>
# <td>Low memory library for creating large XML files / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://codespeak.net/execnet">execnet</a></td>
# <td>1.3.0</td>
# <td>rapid multi-Python deployment / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://expat.sourceforge.net">expat</a> <sup>Linux Mac</sup></td>
# <td>2.1.0</td>
# <td>XML parser library written in C / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://databrewery.org">expressions</a></td>
# <td>0.2.3</td>
# <td>extensible arithmetic expression parser and compiler / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://fabfile.org">fabric</a></td>
# <td>1.13.1</td>
# <td>A  simple, Pythonic tool for remote execution and deployment / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/pbrady/fastcache">fastcache</a></td>
# <td>1.0.2</td>
# <td>C implementation of Python 3 functools.lru_cache / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/kurtmckee/feedparser">feedparser</a></td>
# <td>5.2.1</td>
# <td>parse feeds in Python / OSI Approved</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://s3fs.readthedocs.org/en/latest/">filelock</a></td>
# <td>2.0.7</td>
# <td> / Public Domain</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://github.com/Toblerity/Fiona">fiona</a> <sup>Linux Mac</sup></td>
# <td>1.7.0</td>
# <td>OGR's neat, nimble, no-nonsense API for Python programmers / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://bitbucket.org/tarek/flake8">flake8</a></td>
# <td>2.5.1</td>
# <td>Modular source code checker for pep8, pyflakes and co / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://flask.pocoo.org/">flask</a></td>
# <td>0.12</td>
# <td>A microframework based on Werkzeug, Jinja2 and good intentions / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/corydolphin/flask-cors">flask-cors</a></td>
# <td>3.0.2</td>
# <td>Flask extension adding a decorator for CORS support / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/maxcountryman/flask-login">flask-login</a></td>
# <td>0.3.2</td>
# <td>User session management for Flask / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://github.com/lepture/flask-wtf">flask-wtf</a></td>
# <td>0.12</td>
# <td>Simple integration of Flask and WTForms / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.freedesktop.org/wiki/Software/fontconfig/">fontconfig</a> <sup>Linux</sup></td>
# <td>2.12.1</td>
# <td>A library for configuring and customizing font access / BSD</td>
# ...
# <td>Statistical computations and models / 3-clause BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/stripe/stripe-python">stripe</a></td>
# <td>1.37.0</td>
# <td>Stripe python bindings / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://bitbucket.org/jurko/suds">suds-jurko</a></td>
# <td>0.6</td>
# <td>Lightweight SOAP client (Jurko's fork) / GNU Library or Lesser General Public License LGPL</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://subversion.apache.org/">svn</a></td>
# <td>1.9.4</td>
# <td>Enterprise-class centralized version control for the masses / Apache Software License V.2</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.swig.org/">swig</a></td>
# <td>3.0.10</td>
# <td>A compiler that integrates C and C++ with a variety of languages / GPL3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://sympy.org">sympy</a></td>
# <td>1.0</td>
# <td>Python library for symbolic mathematics / 3-clause BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ionelmc/python-tblib">tblib</a></td>
# <td>1.3.0</td>
# <td>Traceback fiddling library for Python / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://pythonpaste.org/tempita/">tempita</a></td>
# <td>0.5.3</td>
# <td>A small templating language / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://github.com/teradata/PyTd">teradata</a></td>
# <td>15.10.0.20</td>
# <td>Script powerful interactions with Teradata Database / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/takluyver/terminado">terminado</a> <sup>Linux Mac</sup></td>
# <td>0.6</td>
# <td>Terminals served to term.js using Tornado websockets / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/syllog1sm/thinc">thinc</a> <sup>Linux Mac</sup></td>
# <td>5.0.8</td>
# <td>super sparse multi-class machine learning / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.tcl.tk/">tk</a></td>
# <td>8.5.18</td>
# <td>Dynamic programming language with GUI elements / BSD-like</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://toolz.readthedocs.org/en/latest/">toolz</a></td>
# <td>0.8.2</td>
# <td>List processing tools and functional utilities / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.tornadoweb.org/">tornado</a></td>
# <td>4.4.2</td>
# <td>A Python web framework and asynchronous networking library / Apache</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/ipython/traitlets">traitlets</a></td>
# <td>4.3.1</td>
# <td>Configuration system for Python applications / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/enthought/traits">traits</a></td>
# <td>4.6.0</td>
# <td>Explicitly typed attributes for Python / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/enthought/traitsui">traitsui</a></td>
# <td>5.1.0</td>
# <td>Traits-capable windowing framework / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://zodb.readthedocs.org/en/latest/transactions.html">transaction</a></td>
# <td>1.6.1</td>
# <td>Transaction management for Python / ZPL 2.1</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://docs.pylonsproject.org/projects/translationstring/en/latest/">translationstring</a></td>
# <td>1.3</td>
# <td>Utility library for i18n / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/haypo/trollius">trollius</a></td>
# <td>2.1</td>
# <td>port of the Tulip project (asyncio module, PEP 3156) / Apache</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://twistedmatrix.com/">twisted</a></td>
# <td>16.6.0</td>
# <td>Event-driven networking engine / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.esn.me/">ujson</a></td>
# <td>1.35</td>
# <td>Ultra fast JSON encoder and decoder for Python / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/jdunck/python-unicodecsv">unicodecsv</a></td>
# <td>0.14.1</td>
# <td>Drop-in replacement for csv module which supports unicode strings / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://pypi.python.org/pypi/Unidecode">unidecode</a></td>
# <td>0.04.19</td>
# <td>ASCII transliterations of Unicode text / GPL2</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.unixodbc.org/">unixodbc</a> <sup>Linux Mac</sup></td>
# <td>2.3.4</td>
# <td>ODBC (Open Database Connectivity) implementation for Unix / LGPLv2</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://unxutils.sourceforge.net/">unxutils</a> <sup>Windows</sup></td>
# <td>14.04.03</td>
# <td>Ports of common GNU utilities to native Win32 / GPL3</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/conda/conda/wiki/VC-features">vc</a> <sup>Windows</sup></td>
# <td>14</td>
# <td>A meta-package to track VC features. / Modified BSD License (3-clause)</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/habnabit/vcversioner">vcversioner</a></td>
# <td>2.16.0.0</td>
# <td>take version numbers from version control / ISC</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://docs.pylonsproject.org/projects/venusian/en/latest/">venusian</a></td>
# <td>1.0</td>
# <td>A library for deferring decorator actions / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.microsoft.com">vs2015_runtime</a> <sup>Windows</sup></td>
# <td>14.0.25123</td>
# <td>Bundles of the MSVC 14 (VS 2015) runtime / Proprietary</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/scrapy/w3lib">w3lib</a></td>
# <td>1.16.0</td>
# <td>Library of web-related functions / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Pylons/waitress">waitress</a></td>
# <td>0.9.0</td>
# <td>Production-quality WSGI server with very acceptable performance / ZPL 2.1</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/jquast/wcwidth">wcwidth</a></td>
# <td>0.1.7</td>
# <td>measures number of Terminal column cells of wide-character codes / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://webob.org/">webob</a></td>
# <td>1.6.1</td>
# <td>WSGI request and response object / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://webtest.pythonpaste.org/">webtest</a></td>
# <td>2.0.23</td>
# <td>helper to test WSGI applications / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://werkzeug.pocoo.org/">werkzeug</a></td>
# <td>0.11.15</td>
# <td>A WSGI utility library for Python / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://bitbucket.org/techtonik/python-wget/">wget</a></td>
# <td>2.2</td>
# <td>Pure Python download utility / Public-Domain</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://bitbucket.org/pypa/wheel/">wheel</a></td>
# <td>0.29.0</td>
# <td>Built-package format for Python / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://bitbucket.org/mchaput/whoosh">whoosh</a></td>
# <td>2.7.4</td>
# <td>Full-text indexing and searching library / Two-clause BSD license</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://ipython.org">widgetsnbextension</a></td>
# <td>1.2.6</td>
# <td>IPython HTML widgets for Jupyter / BSD 3-clause</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/Drekin/win-unicode-console">win_unicode_console</a> <sup>Windows</sup></td>
# <td>0.5</td>
# <td>enable Unicode input and display when running Python from Windows console / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/shazow/workerpool">workerpool</a></td>
# <td>0.9.4</td>
# <td>Python multithreaded job distribution module / MIT</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/GrahamDumpleton/wrapt">wrapt</a></td>
# <td>1.10.8</td>
# <td>Module for decorators, wrappers and monkey patching / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://wtforms.simplecodes.com/">wtforms</a></td>
# <td>2.1</td>
# <td>A flexible forms validation and rendering library for Python / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://xarray.pydata.org/en/stable/">xarray</a></td>
# <td>0.8.2</td>
# <td>N-D labeled arrays and datasets in Python / Apache</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://xerces.apache.org/xerces-c/">xerces-c</a></td>
# <td>3.1.4</td>
# <td>A validating XML parser written in a portable subset of C++ / Apache 2.0</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://www.lexicon.net/sjmachin/xlrd.htm">xlrd</a></td>
# <td>1.0.0</td>
# <td>Extract data from Microsoft Excel spreadsheet files / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="https://github.com/jmcnamara/XlsxWriter">xlsxwriter</a></td>
# <td>0.9.6</td>
# <td>A Python module for creating Excel XLSX files / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://xlwings.org/">xlwings</a> <sup>Mac Windows</sup></td>
# <td>0.10.2</td>
# <td>Interact with Excel from Python and vice versa / 3-clause BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.python-excel.org/">xlwt</a></td>
# <td>1.2.0</td>
# <td>Writing data and formatting information to Excel files / BSD</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://tukaani.org/xz/">xz</a> <sup>Linux Mac</sup></td>
# <td>5.2.2</td>
# <td>Data compression software with high compression ratio / Public-Domain, GPL</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://www.yaml.org/">yaml</a> <sup>Linux Mac</sup></td>
# <td>0.1.6</td>
# <td>A human friendly data serialization standard / MIT</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://yt-project.org/">yt</a> <sup>Linux Mac</sup></td>
# <td>3.3.2</td>
# <td>An analysis and visualization toolkit for volumetric data / BSD 3-clause</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://zeromq.org">zeromq</a> <sup>Linux</sup></td>
# <td>4.1.5</td>
# <td>Distributed messaging / LGPL</td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="http://github.com/mrocklin/zict/">zict</a></td>
# <td>0.1.1</td>
# <td>mutable mapping tools / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://zlib.net/">zlib</a></td>
# <td>1.2.8</td>
# <td>Unobtrusive compression library / <a href="http://zlib.net/zlib_license.html">zlib</a></td>
# <td><i class="fa fa-check"></i></td>
# </tr>
# <tr>
# <td><a href="None">zope</a></td>
# <td>1.0</td>
# <td> / BSD</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://pypi.python.org/pypi/zope.deprecation">zope.deprecation</a></td>
# <td>4.2.0</td>
# <td>Zope Deprecation Infrastructure / ZPL 2.1</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://docs.zope.org/zope.interface/">zope.interface</a></td>
# <td>4.3.3</td>
# <td>Interfaces for Python / ZPL 2.1</td>
# <td></td>
# </tr>
# <tr>
# <td><a href="http://pypi.python.org/pypi/zope.sqlalchemy">zope.sqlalchemy</a></td>
# <td>0.7.7</td>
# <td>Minimal Zope/SQLAlchemy transaction integration / ZPL 2.1</td>
# <td></td>
# </tr>
# </table><table class="docutils field-list" frame="void" rules="none">
# <col class="field-name"></col>
# <col class="field-body"></col>
# <tbody valign="top">
# <tr class="field-odd field"><th class="field-name">orphan:</th><td class="field-body"></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div></div></div>
# </article>
# </div>
# </div>
# <div class="panel-pane pane-block pane-webform-client-block-100 helpful-form">
# <h2 class="pane-title">
#       Was this helpful?    </h2>
# <div class="pane-content">
# <form accept-charset="UTF-8" action="/anaconda/pkg-docs" class="webform-client-form webform-client-form-100" id="webform-client-form-100" method="post"><div><div class="form-item webform-component webform-component-radios webform-component--was-this-helpful">
# <label class="element-invisible" for="edit-submitted-was-this-helpful">Was this helpful? <span class="form-required" title="This field is required.">*</span></label>
# <div class="form-radios" id="edit-submitted-was-this-helpful"><div class="form-item form-type-radio form-item-submitted-was-this-helpful">
# <input class="form-radio" id="edit-submitted-was-this-helpful-1" name="submitted[was_this_helpful]" required="required" type="radio" value="Yes"/> <label class="option" for="edit-submitted-was-this-helpful-1">Yes </label>
# </div>
# <div class="form-item form-type-radio form-item-submitted-was-this-helpful">
# <input class="form-radio" id="edit-submitted-was-this-helpful-2" name="submitted[was_this_helpful]" required="required" type="radio" value="No"/> <label class="option" for="edit-submitted-was-this-helpful-2">No </label>
# </div>
# </div>
# </div>
# <div class="form-item webform-component webform-component-email webform-component--email">
# <label class="element-invisible" for="edit-submitted-email">Email </label>
# <input class="email form-text form-email" id="edit-submitted-email" name="submitted[email]" placeholder="Email (optional)" size="60" type="email"/>
# </div>
# <div class="form-item webform-component webform-component-textarea webform-component--how-to-improve-this-page">
# <label for="edit-submitted-how-to-improve-this-page">Please let us know how to improve this page </label>
# <div class="form-textarea-wrapper resizable"><textarea class="form-textarea" cols="60" id="edit-submitted-how-to-improve-this-page" name="submitted[how_to_improve_this_page]" rows="3"></textarea></div>
# </div>
# <div class="form-item webform-component webform-component-hidden webform-component--page-referrer" style="display: none">
# <input name="submitted[page_referrer]" type="hidden" value="https://docs.continuum.io/anaconda/pkg-docs"/>
# </div>
# <input name="details[sid]" type="hidden"/>
# <input name="details[page_num]" type="hidden" value="1"/>
# <input name="details[page_count]" type="hidden" value="1"/>
# <input name="details[finished]" type="hidden" value="0"/>
# <input name="form_build_id" type="hidden" value="form-c07h2JjQxQ_6cNH-FKRkjsuhcRVtXwTShnoLa9jG1bk"/>
# <input name="form_id" type="hidden" value="webform_client_form_100"/>
# <div class="url-textfield"><div class="form-item form-type-textfield form-item-url">
# <label for="edit-url">Leave this field blank </label>
# <input autocomplete="off" class="form-text" id="edit-url" maxlength="128" name="url" size="20" type="text" value=""/>
# </div>
# </div><button class="webform-submit button-primary small form-submit" name="op" type="submit" value="Submit">Submit</button>
# </div></form> </div>
# </div>
# </main>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </main>
# <footer class="brand-footer">
# <div class="content-wrapper">
# <div class="light-on-dark-copy row show-for-large-up">
# <div class="columns large-4 text-center"><a href="">Docs Home</a></div><div class="columns large-4 text-center"><a href="https://www.continuum.io/">Continuum Analytics Home</a></div><div class="columns large-4 text-center"><a href="https://www.continuum.io/support">More Help &amp; Support</a></div> </div>
# <div class="light-on-dark-copy row">
# <div class="columns small-8 small-centered medium-4 medium-uncentered large-3">
# <a aria-label="Continuum Analytics" class="image-link " href="https://continuum.io" role="button">
# <img aria-hidden="true" class="logo" src="/sites/all/themes/continuum_docs/assets/images/logos/logo-continuum-white.svg"/>
# </a>
# </div>
# <!-- add social / "connect" icons -->
# <div class="columns small-12 small-centered medium-8 medium-uncentered large-9 copyright">
# <div class="copyright">
# <i class="fa fa-copyright"></i>
# <span>2017 Continuum Analytics, Inc. </span>
# <br class="hide-for-large-up">
# <span>All Rights Reserved. </span>
# <br class="hide-for-large-up">
# <a href="https://continuum.io/privacy-policy" target="_blank">Privacy Policy </a>  |  <a href="/anaconda/eula"> EULA</a>
# </br></br></div>
# </div>
# </div>
# </div>
# </footer>
# <script src="https://docs.continuum.io/sites/default/files/js/js_Rk5YIkK6m2gKTGH-GrMu0pM_PlMKXnI0ktQUgXw1XgA.js" type="text/javascript"></script>
# </div>
# </div>
# <script>
#   (function ($, Drupal, window, document, undefined) {
#     $(document).foundation();
#   })(jQuery, Drupal, this, this.document);
# </script> <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"605677dd16","applicationID":"32604310","transactionName":"MgNVYhQEVhYAVEQIVwtJYkQPShcMD1NVGRYVDkc=","queueTime":0,"applicationTime":13,"atts":"HkRWFFweRRg=","errorBeacon":"bam.nr-data.net","agent":""}</script></body>
# </html>

# %%
#obtem os links de cada pacote
links = []

for table in soup.find_all("table"):
    for registro in table.find_all("tr"):
        for link in registro.contents[1].find_all("a", href = True):
            links.append(link['href'])

# %% [markdown]
# Associando os links ao pacote correspondente

# %%
pkgs_py27['link'] = links[0:521]
pkgs_py34['link'] = links[521:(521+476)]
pkgs_py35['link'] = links[(521+476):(521+476+474)]
pkgs_py36['link'] = links[(521+476+474):(521+476+474+453)]

# %%
def arruma_df(pkg):

    pkg.columns = ['pkg', 'version', 'summary', 'in_installer', 'link']

    pkg = pkg.drop('in_installer', axis = 1)

    return pkg

# %%
pkgs_py27 = arruma_df(pkgs_py27)
pkgs_py34 = arruma_df(pkgs_py34)
pkgs_py35 = arruma_df(pkgs_py35)
pkgs_py36 = arruma_df(pkgs_py36)

# %% [markdown]
# Sample do resultado

# %%
pkgs_py36.sample(10)
# Out:
#                     pkg  version  \
# 61             colorcet    0.9.1
# 217      more-itertools      2.2
# 5    anaconda-navigator    1.5.0
# 270                petl    1.1.0
# 48            chameleon     2.24
# 354         ruamel_yaml  0.11.14
# 42         cachecontrol   0.11.7
# 317               pysal   1.12.0
# 13                  apr    1.5.2
# 332             pywin32      220
#
#                                                summary  \
# 61   collection of perceptually uniform colormaps /...
# 217  more routines for operating on iterables, beyo...
# 5    Anaconda Navigator / proprietary - Continuum A...
# 270                                              / MIT
# 48      HTML/XML template engine for Python / BSD-like
# 354  patched copy of ruamel.yaml (a yaml parser) / MIT
# 42   httplib2 caching algorithms for use with reque...
# 317  library of spatial analysis functions / 3-clau...
# 13   Maintains a consistent API with predictable be...
# 332                Python extensions for Windows / PSF
#
#                                            link
# 61             http://github.com/bokeh/colorcet
# 217  https://github.com/erikrose/more-itertools
# 5      https://github.com/ContinuumIO/navigator
# 270           https://github.com/alimanfoo/petl
# 48            https://chameleon.readthedocs.org
# 354           https://bitbucket.org/ruamel/yaml
# 42      https://github.com/ionrock/cachecontrol
# 317                            http://pysal.org
# 13                       http://apr.apache.org/
# 332    http://sourceforge.net/projects/pywin32/

# %% [markdown]
# Verificação se alguns pacotes principais tem o link do github referênciado

# %%
print(pkgs_py36[pkgs_py36['pkg'] == 'pandas'])
print(pkgs_py36[pkgs_py36['pkg'] == 'numpy'])
print(pkgs_py36[pkgs_py36['pkg'] == 'scikit-learn'])
# Out:
#         pkg version                                            summary  \
# 252  pandas  0.19.2  Powerful data structures and data analysis too...
#
#                           link
# 252  http://pandas.pydata.org/
#        pkg version                                            summary  \
# 243  numpy  1.11.3  array processing for numbers, strings, records...
#
#                         link
# 243  http://numpy.scipy.org/
#               pkg version                                            summary  \
# 361  scikit-learn  0.18.1  set of python modules for machine learning and...
#
#                                 link
# 361  http://scikit-learn.org/stable/

# %% [markdown]
# Aparentemente pacotes importantes não estão como github associado. Trocaremos os links manualmente.

# %%
def corrige_link(pkg, url):
    
    pkgs_py36['link'][pkgs_py36['pkg'] == pkg] = url

# %%
corrige_link('pandas', 'https://github.com/pandas-dev/pandas')
corrige_link('numpy', 'https://github.com/numpy/numpy')
corrige_link('scikit-learn', 'https://github.com/scikit-learn/scikit-learn')
corrige_link('scikit-image', 'https://github.com/scikit-image/scikit-image')
corrige_link('scipy', 'https://github.com/scipy/scipy')
corrige_link('sympy', 'https://github.com/sympy/sympy')
corrige_link('plotly', 'https://github.com/plotly/plotly.py')
corrige_link('chest', 'https://github.com/blaze/chest')
corrige_link('clyent', 'https://github.com/Anaconda-Platform/clyent')
corrige_link('configargparse', 'https://github.com/bw2/ConfigArgParse')
corrige_link('cvxcanon', 'https://github.com/cvxgrp/CVXcanon')
corrige_link('cymem', 'https://github.com/explosion/cymem')
corrige_link('datrie', 'https://github.com/pytries/datrie')
corrige_link('incremental', 'https://github.com/twisted/incremental')
corrige_link('ipywidgets', 'https://github.com/jupyter-widgets/ipywidgets')
corrige_link('pickleshare', 'https://github.com/pickleshare/pickleshare')
corrige_link('preshed', 'https://github.com/explosion/preshed')
corrige_link('smart_open', 'https://github.com/RaRe-Technologies/smart_open')
corrige_link('zict', 'https://github.com/dask/zict')
corrige_link('chalmers', 'https://github.com/Anaconda-Platform/chalmers')

# %% [markdown]
# 3 pacotes deram problema no link obtido devido ao comprimento da string. No primeiro momento esses links serão removidos.

# %%
#retira links quebras
corrige_link('anaconda-navigator', '')
corrige_link('sputnik', '')
corrige_link('semantic_version', '') #https://github.com/rbarrois/python-semanticversion

# %% [markdown]
# Resultado da coleta dos meta dados dos pacotes

# %%
print('py{} : {} / {} pacotes com endereço do git'.format( 
    "27",str(len(pkgs_py27[pkgs_py27['link'].str.contains("//github")])),str(len(pkgs_py27))))
print('py{} : {} / {} pacotes com endereço do git'.format( 
    "34",str(len(pkgs_py34[pkgs_py34['link'].str.contains("//github")])),str(len(pkgs_py34))))
print('py{} : {} / {} pacotes com endereço do git'.format( 
    "35",str(len(pkgs_py35[pkgs_py35['link'].str.contains("//github")])),str(len(pkgs_py35))))
print('py{} : {} / {} pacotes com endereço do git'.format( 
    "36",str(len(pkgs_py36[pkgs_py36['link'].str.contains("//github")])),str(len(pkgs_py36))))
# Out:
# py27 : 183 / 521 pacotes com endereço do git
# py34 : 167 / 476 pacotes com endereço do git
# py35 : 165 / 474 pacotes com endereço do git
# py36 : 162 / 453 pacotes com endereço do git

# %% [markdown]
# Para todas as versões do Python, cerca de 1/3 tem o seu GitHub referênciado na documentação do Anaconda. Vamos crawlear esses pacotes.

# %% [markdown]
# ### 1.2. Scraping das Dependências dos Pacotes

# %% [markdown]
# Definição das funções para scraping

# %%
#Coleção de Funções que serão utilizadas no git_code_crawler

## Função para acessar a API
def git_code_qry(repository, keyword, language = 'python', results_per_page = 100, page = 1):
    headers = {
        'Accept': 'application/vnd.github.v3.text-match+json',
    }

    params = (
        ('q', keyword + ' language:' + language + ' repo:' + repository),
        ('per_page', str(results_per_page)),
        ('page', str(page)),
    )

    return requests.get('https://api.github.com/search/code', headers=headers, params=params)

## A API do GitHub retorna 100 resultados por consulta. Para casos onde há mais resultados será necessário uma
## que verifica a quantidade de páginas com resultado. Essa informação será parâmetro da consulta em eventuais 
## casos onde há mais de 100 resultados
##Função para obtenção da quantidade de páginas retornadas na consulta
def page_qtt(query):
    try:
        last_page = int(query.headers['Link'].split(';')[1][-2])
    except:    
        last_page = 1
    
    return last_page


##Função para obter a setença com onde foi encotrada a palavra chave
def get_text(query):
    
    imports = []
    
    for item in json.loads(query.text)['items']:
        for text in (item['text_matches']):
            imports.append(text['fragment'])
    
    return imports


##Função para limpar o texto que retornou da consulta
def remove_regex(qry_text):
    #remover regex
    qry_text_noregex = []
    
    for sentence in qry_text:
        sentence_noregex = sentence
        sentence_noregex = sentence_noregex.replace("  ", " ")
        sentence_noregex = sentence_noregex.replace("\n", " ")
        sentence_noregex = sentence_noregex.replace("\r", " ")
        qry_text_noregex.append(sentence_noregex)
    
    return qry_text_noregex

# %%
##Função que acessa a API e retorna o json

def git_code_crawler(repository, keyword, language = 'python', results_per_page = 100):
    
    results = []
    
    #first query
    qry = git_code_qry(repository, keyword, language, results_per_page, 1)
    
    results.extend(get_text(qry))
    results_qtt = len(json.loads(qry.text)['items'])
    
    #Verify if query return more than one page
    if page_qtt(qry) != 1:
        
        for i in range(2, page_qtt(qry) + 1):
            
            qry = git_code_qry(repository, keyword, language, results_per_page, i)
            
            results.extend(get_text(qry))
            results_qtt += len(json.loads(qry.text)['items'])

    #print('{} : {} resultados encontrados!'.format(repository, results_qtt))
    
    return results

# %%
#Função para obter do json a informação dos pacotes acessados pelo repositório
def get_pkgs(qry_text, most_common = 1000):
    
    #remover regex
    qry_text_noregex = []
    for sentence in qry_text:
        qry_text_noregex.append(sentence.replace("  ", " ").replace("\n", " "))
    
    #splita as lista
    qry_split = []

    for sentence in qry_text_noregex:
        qry_split.append(sentence.split(" "))
        
    #remove valores vazios da lista
    qry_no_blank_space = []
    
    chars = set('"#`_-()')
    
    for sentence in qry_split:
        for word in sentence:
            if word != "" and word != "#" and word != "," and word != '"""' and word != '"':
                if not any((c in chars) for c in word):
                    word = word.replace(",", "")
                    qry_no_blank_space.append(word)
    
    #obtem os pacotes
    pacotes = []

    for i in range(0,len(qry_no_blank_space)-1):
        
        if qry_no_blank_space[i] == 'from':
            pacotes.append(qry_no_blank_space[i+1])
        
        elif qry_no_blank_space[i] == 'import' and qry_no_blank_space[i - 2] != 'from':
            pacotes.append(qry_no_blank_space[i+1])
            
        elif qry_no_blank_space[i] == 'cimport' and qry_no_blank_space[i - 2] != 'from':
            pacotes.append(qry_no_blank_space[i+1])
    
    #Limpa a os pacotes filhos
    pacotes_limpos = [] 
    
    for pkg in pacotes:
        if pkg.find('.') > 0:
            pacotes_limpos.append(pkg[0:pkg.find('.')])
        elif pkg[0] != '.' and pkg[0] != '-' and pkg[0] != '`' and pkg[0] != '('  and pkg[0] != '#'  and pkg[0] != '"' and pkg[0] != '_' and pkg[0:2] != 'is' and pkg[0].islower() and pkg != 'import' and pkg != 'from' and pkg != 'the' and pkg != 'division':
            pacotes_limpos.append(pkg)
    
    return collections.Counter(pacotes_limpos).most_common(most_common)

# %% [markdown]
# Funções do crawler todas definidas.
#
# Agora será obtido o nome do repositório a partir da url do github. Essa informação é um dos parâmetros para consulta na API.

# %%
repositorios = []

for repositorio in pkgs_py36[pkgs_py36['link'].str.contains("//github")]['link']:
    
    if repositorio.find('https')>-1:
        pacote = repositorio.replace("https://github.com/", "")
    
        if pacote[-1] == '/':
            pacote = pacote[:-1]
            repositorios.append(pacote)
        else:
            repositorios.append(pacote) 
              
    else:
        pacote = repositorio.replace("http://github.com/", "")
        
        if pacote[-1] == '/':
            pacote = pacote[:-1]
            repositorios.append(pacote)
        else:
            repositorios.append(pacote)

# %% [markdown]
# Execução do crawler.
#
# Os parâmetros utilizados são:
#
# 1) Nome do repositório buscado
#
# 2) Palavra 'import' no código
#
# 3) Estar escrito em py

# %%
pacote_pacote = {}

# %%
for repo in tqdm.tqdm(repositorios):
        #print(repo)
        pkg_name = repo[repo.find('/')+1 : ]
        result = git_code_crawler(repo, "import", language = 'python')
        dependencies = get_pkgs(result)
        
        pacote_pacote[pkg_name] = dependencies
        
        time.sleep(15)
# Out:
# 100%|██████████| 1/1 [00:21<00:00, 21.56s/it]

# %% [markdown]
# Salva o pickle da consulta

# %%
pickle.dump(pacote_pacote,open("dependencias.p", 'wb'))

# %%
pacote_pacote = pickle.load(open('dependencias.p', 'rb'))

# %% [markdown]
# Visualização do resultado do Crawler.
#
# Os valores são a quantidade de menções ao pacote dentro do repositório

# %%
pacote_pacote
# Out:
# {'CVXcanon': [('numpy', 34),
#   ('cvxpy', 30),
#   ('time', 21),
#   ('matplotlib', 17),
#   ('copy', 6),
#   ('math', 5),
#   ('os', 3),
#   ('mpl_toolkits', 3),
#   ('scipy', 3),
#   ('glob', 1),
#   ('subprocess', 1),
#   ('heapq', 1),
#   ('setuptools', 1),
#   ('huge_testman', 1),
#   ('unittest', 1),
#   ('again', 1),
#   ('collections', 1),
#   ('sys', 1),
#   ('imp', 1)],
#  'ConfigArgParse': [('sys', 3),
#   ('logging', 2),
#   ('os', 2),
#   ('argparse', 2),
#   ('types', 2),
#   ('setuptools', 1),
#   ('setup', 1),
#   ('configargparse', 1),
#   ('functools', 1),
#   ('inspect', 1),
#   ('tempfile', 1),
#   ('unittest2', 1),
#   ('glob', 1),
#   ('re', 1),
#   ('io', 1)],
#  'Fiona': [('fiona', 102),
#   ('logging', 37),
#   ('sys', 34),
#   ('os', 25),
#   ('click', 22),
#   ('json', 20),
#   ('pytest', 19),
#   ('unittest', 18),
#   ('tempfile', 15),
#   ('shutil', 14),
#   ('cligj', 9),
#   ('six', 6),
#   ('collections', 5),
#   ('subprocess', 5),
#   ('warnings', 4),
#   ('re', 4),
#   ('functools', 4),
#   ('argparse', 3),
#   ('timeit', 3),
#   ('osgeo', 3),
#   ('collection', 3),
#   ('datetime', 3),
#   ('pkg_resources', 2),
#   ('code', 2),
#   ('matplotlib', 2),
#   ('descartes', 2),
#   ('itertools', 2),
#   ('distutils', 2),
#   ('ordereddict', 1),
#   ('/test_layer', 1),
#   ('shapely', 1),
#   ('binascii', 1),
#   ('pyproj', 1),
#   ('math', 1),
#   ('munch', 1),
#   ('sys;sys', 1),
#   ('tarfile', 1),
#   ('zipfile', 1),
#   ('setuptools', 1),
#   ('pprint', 1)],
#  'PyHive': [('pyhive', 13),
#   ('builtins', 9),
#   ('distutils', 4),
#   ('sqlalchemy', 4),
#   ('setuptools', 2),
#   ('future', 2),
#   ('contextlib', 2),
#   ('unittest', 1),
#   ('sys', 1),
#   ('subprocess', 1),
#   ('time', 1),
#   ('absolute_import', 1),
#   ('os', 1),
#   ('datetime', 1),
#   ('re', 1)],
#  'PyMySQL': [('pymysql', 42),
#   ('unittest2', 13),
#   ('unittest', 10),
#   ('sys', 8),
#   ('warnings', 8),
#   ('time', 7),
#   ('datetime', 6),
#   ('io', 4),
#   ('os', 3),
#   ('re', 3),
#   ('gc', 2),
#   ('struct', 2),
#   ('json', 2),
#   ('errno', 2),
#   ('functools', 2),
#   ('atexit', 1),
#   ('cStringIO', 1),
#   ('setuptools', 1),
#   ('a', 1),
#   ('socket', 1),
#   ('decimal', 1),
#   ('hashlib', 1)],
#  'PyTd': [('sys', 10),
#   ('teradata', 10),
#   ('os', 6),
#   ('unittest', 6),
#   ('logging', 5),
#   ('json', 4),
#   ('decimal', 4),
#   ('re', 4),
#   ('atexit', 3),
#   ('time', 3),
#   ('datetime', 3),
#   ('io', 2),
#   ('codecs', 2),
#   ('collections', 2),
#   ('getpass', 2),
#   ('platform', 2),
#   ('threading', 2),
#   ('base64', 1),
#   ('ssl', 1),
#   ('setuptools', 1),
#   ('string', 1),
#   ('subprocess', 1),
#   ('argparse', 1),
#   ('inspect', 1),
#   ('copy', 1),
#   ('random', 1),
#   ('math', 1),
#   ('ctypes', 1)],
#  'Shapely': [('shapely', 186),
#   ('matplotlib', 22),
#   ('figures', 22),
#   ('ctypes', 20),
#   ('sys', 18),
#   ('descartes', 16),
#   ('re', 9),
#   ('absolute_import', 8),
#   ('pytest', 7),
#   ('os', 7),
#   ('itertools', 6),
#   ('numpy', 5),
#   ('functools', 5),
#   ('math', 5),
#   ('pylab', 4),
#   ('pyparsing', 4),
#   ('pickle', 3),
#   ('warnings', 3),
#   ('random', 3),
#   ('inspect', 3),
#   ('glob', 2),
#   ('logging', 2),
#   ('subprocess', 2),
#   ('docutils', 2),
#   ('pygments', 2),
#   ('cPickle', 1),
#   ('unittest2', 1),
#   ('unittest', 1),
#   ('threading', 1),
#   ('binascii', 1),
#   ('operation', 1),
#   ('doctest', 1),
#   ('dissolving', 1),
#   ('locale', 1),
#   ('loads', 1),
#   ('string', 1),
#   ('struct', 1),
#   ('hashlib', 1),
#   ('md5', 1),
#   ('errno', 1),
#   ('wraps', 1),
#   ('lgeos', 1),
#   ('operator', 1),
#   ('platform', 1),
#   ('array', 1),
#   ('docscrape_sphinx', 1),
#   ('objects', 1),
#   ('xml', 1),
#   ('a2b_hex', 1),
#   ('atexit', 1),
#   ('heapq', 1),
#   ('collections', 1),
#   ('and', 1),
#   ('docscrape', 1),
#   ('textwrap', 1),
#   ('pydoc', 1),
#   ('abc', 1)],
#  'XlsxWriter': [('unittest', 94),
#   ('datetime', 8),
#   ('sys', 2),
#   ('io', 2),
#   ('decimal', 1),
#   ('subprocess', 1),
#   ('warnings', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('urllib', 1),
#   ('os', 1),
#   ('xlsxwriter', 1)],
#  'affine': [('affine', 3),
#   ('math', 3),
#   ('pickle', 1),
#   ('multiprocessing', 1),
#   ('codecs', 1),
#   ('setuptools', 1),
#   ('unittest', 1),
#   ('textwrap', 1),
#   ('nose', 1),
#   ('collections', 1)],
#  'anaconda-clean': [('sys', 2),
#   ('os', 2),
#   ('distutils', 1),
#   ('time', 1),
#   ('optparse', 1)],
#  'anaconda-project': [('anaconda_project', 149),
#   ('os', 69),
#   ('sys', 25),
#   ('platform', 21),
#   ('codecs', 19),
#   ('absolute_import', 17),
#   ('pytest', 16),
#   ('tornado', 13),
#   ('copy', 11),
#   ('errno', 9),
#   ('json', 9),
#   ('shutil', 8),
#   ('collections', 8),
#   ('subprocess', 7),
#   ('zipfile', 6),
#   ('uuid', 5),
#   ('abc', 5),
#   ('re', 5),
#   ('logging', 4),
#   ('bokeh', 4),
#   ('socket', 3),
#   ('tempfile', 3),
#   ('with_directory_contents', 3),
#   ('shlex', 2),
#   ('urllib', 2),
#   ('functools', 2),
#   ('pandas', 2),
#   ('bs4', 2),
#   ('argparse', 2),
#   ('tarfile', 2),
#   ('difflib', 2),
#   ('time', 2),
#   ('distutils', 2),
#   ('pprint', 2),
#   ('contextlib', 2),
#   ('print_function', 1),
#   ('setup_atomic_replace', 1),
#   ('yapf', 1),
#   ('webbrowser', 1),
#   ('unicodedata', 1),
#   ('user', 1),
#   ('pipes', 1),
#   ('numpy', 1),
#   ('sqlite3', 1),
#   ('inspect', 1),
#   ('load_project', 1),
#   ('falcon', 1),
#   ('gunicorn', 1),
#   ('multiprocessing', 1),
#   ('requests', 1),
#   ('threading', 1),
#   ('ruamel_yaml', 1),
#   ('hashlib', 1),
#   ('getpass', 1),
#   ('with_file_contents', 1),
#   ('SOFTWARE', 1),
#   ('email', 1),
#   ('mimetypes', 1),
#   ('urllib3', 1),
#   ('fnmatch', 1),
#   ('io', 1),
#   ('glob', 1),
#   ('random', 1),
#   ('that', 1),
#   ('stat', 1),
#   ('place', 1)],
#  'anaconda-verify': [('anaconda_verify', 6),
#   ('os', 5),
#   ('re', 4),
#   ('sys', 2),
#   ('collections', 2),
#   ('optparse', 1),
#   ('distutils', 1),
#   ('yaml', 1),
#   ('json', 1),
#   ('shlex', 1),
#   ('tarfile', 1)],
#  'appdirs': [('sys', 3),
#   ('os', 3),
#   ('setuptools', 1),
#   ('appdirs', 1),
#   ('unittest2', 1),
#   ('unittest', 1),
#   ('platform', 1)],
#  'appnope': [('distutils', 3),
#   ('sys', 2),
#   ('platform', 2),
#   ('setuptools', 2),
#   ('contextlib', 2),
#   ('ctypes', 2)],
#  'apptools': [('traits', 143),
#   ('apptools', 85),
#   ('pyface', 51),
#   ('os', 39),
#   ('logging', 35),
#   ('traitsui', 29),
#   ('sys', 17),
#   ('unittest', 16),
#   ('numpy', 13),
#   ('context', 9),
#   ('pickle', 8),
#   ('package_globals', 7),
#   ('envisage', 7),
#   ('api', 5),
#   ('exception', 5),
#   ('contextlib', 5),
#   ('reference', 5),
#   ('inspect', 5),
#   ('errno', 5),
#   ('types', 5),
#   ('tables', 5),
#   ('pkg_resources', 5),
#   ('abstract_type_system', 4),
#   ('subprocess', 4),
#   ('wx', 4),
#   ('binding', 4),
#   ('socket', 4),
#   ('i_preferences_page', 3),
#   ('dict_context_adapter', 3),
#   ('i_bind_event', 3),
#   ('i_user_storage', 3),
#   ('permissions', 3),
#   ('list_context_adapter', 3),
#   ('nose', 3),
#   ('object_factory', 3),
#   ('re', 3),
#   ('address', 3),
#   ('cPickle', 3),
#   ('abstract_adapter_factory', 2),
#   ('abstract_factory', 2),
#   ('logger', 2),
#   ('instance_context_adapter', 2),
#   ('imutable_template', 2),
#   ('any_context_data_name_item', 2),
#   ('adapter_base', 2),
#   ('i_policy_manager', 2),
#   ('i_user', 2),
#   ('i_user_manager', 2),
#   ('tempfile', 2),
#   ('i_help_code', 2),
#   ('i_help_doc', 2),
#   ('context_monitor', 2),
#   ('context_node_type', 2),
#   ('i_policy_storage', 2),
#   ('login_action', 2),
#   ('setuptools', 2),
#   ('itemplate_choice', 2),
#   ('pandas', 2),
#   ('traceback', 2),
#   ('itemplate', 2),
#   ('state_factory', 2),
#   ('email', 2),
#   ('io', 2),
#   ('cStringIO', 2),
#   ('zipfile', 2),
#   ('context_test_case', 2),
#   ('collections', 2),
#   ('itemplate_data_context', 2),
#   ('imports', 2),
#   ('xmlrpclib', 2),
#   ('persistent', 2),
#   ('model', 2),
#   ('base64', 2),
#   ('time', 2),
#   ('preferences_manager', 1),
#   ('preferences_page', 1),
#   ('lru_cache', 1),
#   ('adaptable', 1),
#   ('log_point', 1),
#   ('filtering_handler', 1),
#   ('null_handler', 1),
#   ('dict_context_adapter_factory', 1),
#   ('template_traits', 1),
#   ('full_version', 1),
#   ('any_data_name_item', 1),
#   ('context_data_name_item', 1),
#   ('help_code', 1),
#   ('help_doc', 1),
#   ('help_plugin', 1),
#   ('explorer', 1),
#   ('naming_node_manager', 1),
#   ('create_scriptable_type', 1),
#   ('i_script_manager', 1),
#   ('i_user_database', 1),
#   ('naming_traits', 1),
#   ('initial_context_factory', 1),
#   ('object_serializer', 1),
#   ('pyfs_context', 1),
#   ('logout_action', 1),
#   ('user_menu_manager', 1),
#   ('template_impl', 1),
#   ('update1', 1),
#   ('trait_dict_context_adapter', 1),
#   ('trait_list_context_adapter', 1),
#   ('get_permissions_manager', 1),
#   ('provides', 1),
#   ('example_script_window', 1),
#   ('stop_recording_action', 1),
#   ('tuple_context_adapter', 1),
#   ('adapter_manager', 1),
#   ('enable', 1),
#   ('abc', 1),
#   ('naming_tree', 1),
#   ('split', 1),
#   ('dump', 1),
#   ('naming_manager', 1),
#   ('referenceable', 1),
#   ('file', 1),
#   ('naming_tree_model', 1),
#   ('sweet_pickle', 1),
#   ('threading', 1),
#   ('ordereddict', 1),
#   ('imp', 1),
#   ('which', 1),
#   ('thread', 1),
#   ('datetime', 1),
#   ('tree_item', 1),
#   ('bind_event', 1),
#   ('scriptable_type', 1),
#   ('and', 1),
#   ('random', 1),
#   ('array', 1),
#   ('codetools', 1),
#   ('any', 1),
#   ('json', 1),
#   ('helper', 1),
#   ('path_for', 1),
#   ('proxy_server', 1),
#   ('script_manager', 1),
#   ('doc_action', 1),
#   ('util', 1),
#   ('ring_buffer', 1),
#   ('itemplate_data_source', 1),
#   ('new', 1),
#   ('scriptable', 1),
#   ('optparse', 1),
#   ('permission', 1),
#   ('math', 1),
#   ('shelve', 1),
#   ('weakref', 1),
#   ('warnings', 1),
#   ('functools', 1),
#   ('mimetypes', 1),
#   ('state_pickler', 1),
#   ('gzip', 1)],
#  'azure-sdk-for-python': [('msrest', 1)],
#  'backports.shutil_get_terminal_size': [('os', 2),
#   ('sys', 2),
#   ('pkgutil', 1),
#   ('subprocess', 1),
#   ('pytest', 1),
#   ('backports', 1),
#   ('struct', 1),
#   ('collections', 1),
#   ('windll', 1),
#   ('setuptools', 1)],
#  'bcrypt': [('os', 3),
#   ('setuptools', 3),
#   ('io', 2),
#   ('six', 2),
#   ('getpass', 1),
#   ('time', 1),
#   ('clint', 1),
#   ('invoke', 1),
#   ('requests', 1),
#   ('re', 1),
#   ('warnings', 1),
#   ('cffi', 1),
#   ('platform', 1),
#   ('sys', 1),
#   ('distutils', 1),
#   ('pytest', 1),
#   ('bcrypt', 1)],
#  'bitarray': [('bitarray', 12),
#   ('os', 4),
#   ('numpy', 3),
#   ('time', 2),
#   ('hashlib', 2),
#   ('re', 2),
#   ('random', 2),
#   ('scipy', 1),
#   ('math', 1),
#   ('distutils', 1),
#   ('bz2', 1),
#   ('doctest', 1),
#   ('cStringIO', 1),
#   ('huffman', 1),
#   ('collections', 1),
#   ('heapq', 1),
#   ('sys', 1),
#   ('unittest', 1),
#   ('tempfile', 1),
#   ('shutil', 1)],
#  'bleach': [('bleach', 13),
#   ('html5lib', 9),
#   ('pytest', 5),
#   ('re', 4),
#   ('os', 3),
#   ('six', 3),
#   ('json', 2),
#   ('collections', 2),
#   ('urllib', 2),
#   ('argparse', 1),
#   ('fnmatch', 1),
#   ('sys', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('webbrowser', 1),
#   ('datetime', 1),
#   ('decimal', 1),
#   ('types', 1),
#   ('xml', 1),
#   ('functools', 1)],
#  'boto': [('boto', 1181),
#   ('tests', 238),
#   ('time', 81),
#   ('os', 68),
#   ('unittest', 59),
#   ('datetime', 34),
#   ('xml', 28),
#   ('sys', 26),
#   ('mock', 23),
#   ('re', 22),
#   ('base64', 20),
#   ('hashlib', 14),
#   ('json', 13),
#   ('socket', 13),
#   ('uuid', 12),
#   ('nose', 12),
#   ('random', 9),
#   ('optparse', 8),
#   ('tempfile', 8),
#   ('copy', 8),
#   ('logging', 7),
#   ('errno', 7),
#   ('binascii', 7),
#   ('threading', 6),
#   ('urllib', 6),
#   ('decimal', 6),
#   ('httpretty', 6),
#   ('math', 6),
#   ('argparse', 5),
#   ('requests', 5),
#   ('itertools', 4),
#   ('SOFTWARE', 4),
#   ('getopt', 4),
#   ('unittest\r', 3),
#   ('common', 3),
#   ('attr', 3),
#   ('urlparse', 3),
#   ('shutil', 3),
#   ('subprocess', 3),
#   ('operator', 3),
#   ('string', 3),
#   ('functools', 3),
#   ('types', 3),
#   ('unittest2', 2),
#   ('glob', 2),
#   ('create_hit_with_qualifications', 2),
#   ('os\r', 2),
#   ('collections', 2),
#   ('paramiko', 2),
#   ('docutils', 2),
#   ('imp', 2),
#   ('ssl', 2),
#   ('hmac', 2),
#   ('mimetypes', 2),
#   ('inspect', 2),
#   ('warnings', 2),
#   ('traceback', 2),
#   ('httplib', 2),
#   ('codecs', 2),
#   ('layer1', 2),
#   ('email', 2),
#   ('textwrap', 2),
#   ('doctest', 1),
#   ('create_hit_test', 1),
#   ('create_hit_external', 1),
#   ('doctest\r', 1),
#   ('uuid\r', 1),
#   ('datetime\r', 1),
#   ('pickle\r', 1),
#   ('functools\r', 1),
#   ('termios', 1),
#   ('tty', 1),
#   ('selenium', 1),
#   ('of', 1),
#   ('stat', 1),
#   ('pwd', 1),
#   ('sha', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('platform', 1),
#   ('connect', 1),
#   ('iteritems', 1),
#   ('notify', 1),
#   ('propget', 1),
#   ('yaml', 1),
#   ('telnetlib', 1),
#   ('locale', 1),
#   ('readline', 1),
#   ('functions', 1),
#   ('smtplib', 1),
#   ('bdb', 1),
#   ('tree_hash_from_str', 1),
#   ('find_class', 1),
#   ('authentication', 1),
#   ('interactive_shell', 1),
#   ('pickle', 1),
#   ('cgi', 1),
#   ('exception', 1),
#   ('AWS', 1),
#   ('dynamize_value', 1),
#   ('etree', 1),
#   ('six', 1)],
#  'bottlechest': [],
#  'bsdiff4': [('os', 4),
#   ('bsdiff4', 4),
#   ('cStringIO', 2),
#   ('sys', 2),
#   ('re', 1),
#   ('distutils', 1),
#   ('random', 1),
#   ('shutil', 1),
#   ('unittest', 1),
#   ('tempfile', 1),
#   ('bz2', 1),
#   ('io', 1),
#   ('optparse', 1)],
#  'bz2file': [('bz2file', 2),
#   ('io', 2),
#   ('threading', 2),
#   ('distutils', 1),
#   ('unittest', 1),
#   ('bz2', 1),
#   ('os', 1),
#   ('platform', 1),
#   ('sys', 1),
#   ('warnings', 1)],
#  'cachecontrol': [('cachecontrol', 28),
#   ('requests', 18),
#   ('pytest', 9),
#   ('mock', 6),
#   ('datetime', 5),
#   ('time', 4),
#   ('sys', 3),
#   ('os', 3),
#   ('calendar', 3),
#   ('email', 3),
#   ('logging', 2),
#   ('argparse', 2),
#   ('pprint', 2),
#   ('msgpack', 2),
#   ('io', 2),
#   ('Interface', 1),
#   ('urllib', 1),
#   ('urlparse', 1),
#   ('cPickle', 1),
#   ('pickle', 1),
#   ('multiprocessing', 1),
#   ('wsgiref', 1),
#   ('string', 1),
#   ('random', 1),
#   ('hashlib', 1),
#   ('textwrap', 1),
#   ('types', 1),
#   ('functools', 1),
#   ('threading', 1),
#   ('socket', 1),
#   ('cherrypy', 1),
#   ('base64', 1),
#   ('json', 1),
#   ('zlib', 1),
#   ('setuptools', 1),
#   ('re', 1)],
#  'cached-property': [('time', 2),
#   ('threading', 2),
#   ('os', 1),
#   ('sys', 1),
#   ('codecs', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('unittest', 1),
#   ('freezegun', 1),
#   ('cached_property', 1)],
#  'chardet': [('chardet', 11),
#   ('sys', 4),
#   ('os', 4),
#   ('re', 3),
#   ('logging', 3),
#   ('argparse', 2),
#   ('stdin', 1),
#   ('textwrap', 1),
#   ('difflib', 1),
#   ('io', 1),
#   ('setuptools', 1),
#   ('codecs', 1),
#   ('collections', 1),
#   ('string', 1)],
#  'chest': [('chest', 3),
#   ('os', 3),
#   ('re', 3),
#   ('shutil', 2),
#   ('contextlib', 2),
#   ('setuptools', 1),
#   ('json', 1),
#   ('pickle', 1),
#   ('numpy', 1),
#   ('collections', 1),
#   ('functools', 1),
#   ('threading', 1),
#   ('sys', 1),
#   ('tempfile', 1)],
#  'click-plugins': [('click', 7),
#   ('pkg_resources', 5),
#   ('setuptools', 5),
#   ('click_plugins', 3),
#   ('pytest', 2),
#   ('os', 2),
#   ('codecs', 1),
#   ('with_plugins', 1),
#   ('sys', 1),
#   ('traceback', 1)],
#  'cligj': [('click', 4),
#   ('pytest', 2),
#   ('json', 2),
#   ('cligj', 2),
#   ('os', 2),
#   ('codecs', 1),
#   ('setuptools', 1),
#   ('sys', 1),
#   ('itertools', 1),
#   ('re', 1)],
#  'cloudpickle': [('pickle', 3),
#   ('sys', 3),
#   ('cloudpickle', 2),
#   ('unittest', 2),
#   ('os', 2),
#   ('io', 2),
#   ('subprocess', 2),
#   ('imp', 2),
#   ('functools', 2),
#   ('itertools', 2),
#   ('tempfile', 1),
#   ('shutil', 1),
#   ('suprocess', 1),
#   ('pytest', 1),
#   ('random', 1),
#   ('platform', 1),
#   ('textwrap', 1),
#   ('base64', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('dis', 1),
#   ('opcode', 1),
#   ('operator', 1)],
#  'clyent': [('os', 8),
#   ('sys', 6),
#   ('clyent', 4),
#   ('logging', 4),
#   ('argparse', 2),
#   ('io', 1),
#   ('unittest', 1),
#   ('setuptools', 1),
#   ('versioneer', 1),
#   ('contextlib', 1),
#   ('collections', 1),
#   ('imp', 1),
#   ('json', 1),
#   ('string', 1),
#   ('it', 1),
#   ('time', 1),
#   ('errno', 1),
#   ('re', 1),
#   ('subprocess', 1)],
#  'colander': [('colander', 3),
#   ('sys', 2),
#   ('unittest', 2),
#   ('datetime', 2),
#   ('setuptools', 2),
#   ('iso8601', 1),
#   ('cPickle', 1),
#   ('os', 1),
#   ('pkg_resources', 1),
#   ('coding=utf-8', 1),
#   ('decimal', 1),
#   ('functools', 1),
#   ('time', 1),
#   ('itertools', 1),
#   ('pprint', 1),
#   ('re', 1),
#   ('translationstring', 1),
#   ('warnings', 1),
#   ('types', 1)],
#  'colorama': [('sys', 10),
#   ('colorama', 8),
#   ('fixpath', 7),
#   ('os', 4),
#   ('unittest2', 4),
#   ('ctypes', 3),
#   ('contextlib', 2),
#   ('mock', 2),
#   ('re', 2),
#   ('unittest', 2),
#   ('random', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('atexit', 1),
#   ('io', 1)],
#  'colorcet': [('matplotlib', 4),
#   ('collections', 3),
#   ('colorcet;', 1),
#   ('setuptools', 1),
#   ('on', 1)],
#  'conda-build': [('os', 118),
#   ('conda_build', 83),
#   ('sys', 52),
#   ('json', 28),
#   ('glob', 25),
#   ('pytest', 22),
#   ('subprocess', 13),
#   ('logging', 13),
#   ('re', 12),
#   ('collections', 11),
#   ('setuptools', 9),
#   ('distutils', 9),
#   ('yaml', 6),
#   ('locale', 6),
#   ('conda_build_test', 4),
#   ('argparse', 4),
#   ('functools', 4),
#   ('io', 4),
#   ('contextlib', 4),
#   ('shutil', 3),
#   ('fnmatch', 3),
#   ('itertools', 3),
#   ('copy', 3),
#   ('`sys', 2),
#   ('noarch_test_package', 2),
#   ('unittest', 2),
#   ('pkg_resources', 2),
#   ('tarfile', 2),
#   ('csv', 2),
#   ('time', 2),
#   ('codecs', 2),
#   ('cython', 1),
#   ('click', 1),
#   ('foo', 1),
#   ('pkg1', 1),
#   ('pkg2', 1),
#   ('/licenses/BSD-3-Clause', 1),
#   ('importlib', 1),
#   ('pkgutil', 1),
#   ('noarch_python_test_package', 1),
#   ('on_win', 1),
#   ('sys\r', 1),
#   ('string', 1),
#   ('versioneer', 1),
#   ('keyword', 1),
#   ('bz2', 1),
#   ('download', 1),
#   ('base64', 1),
#   ('shlex', 1),
#   ('operator', 1),
#   ('filelock', 1),
#   ('jinja2', 1),
#   ('more', 1),
#   ('mock', 1),
#   ('stat', 1),
#   ('zipfile', 1),
#   ('multiprocessing', 1),
#   ('six', 1),
#   ('textwrap', 1),
#   ('read_configuration', 1),
#   ('math', 1),
#   ('pprint', 1),
#   ('absolute_import', 1),
#   ('getargspec', 1),
#   ('tempfile', 1),
#   ('hashlib', 1),
#   ('uuid', 1),
#   ('conda', 1),
#   ('it', 1),
#   ('errno', 1),
#   ('setup', 1),
#   ('_version', 1)],
#  'conda-verify': [('conda_verify', 21),
#   ('os', 7),
#   ('re', 4),
#   ('sys', 3),
#   ('join', 1),
#   ('setuptools', 1),
#   ('optparse', 1),
#   ('pkgutil', 1),
#   ('collections', 1),
#   ('yaml', 1),
#   ('tarfile', 1),
#   ('shlex', 1),
#   ('get_bad_seq', 1)],
#  'conda/wiki/VC-features': [('os', 110),
#   ('conda', 100),
#   ('logging', 76),
#   ('sys', 37),
#   ('unittest', 37),
#   ('collections', 29),
#   ('json', 19),
#   ('functools', 16),
#   ('conda_env', 15),
#   ('itertools', 14),
#   ('re', 14),
#   ('tempfile', 14),
#   ('pytest', 13),
#   ('argparse', 13),
#   ('operator', 12),
#   ('errno', 12),
#   ('contextlib', 10),
#   ('textwrap', 7),
#   ('datetime', 7),
#   ('mock', 6),
#   ('subprocess', 6),
#   ('binstar_client', 6),
#   ('glob', 6),
#   ('io', 6),
#   ('random', 5),
#   ('inspect', 4),
#   ('types', 4),
#   ('time', 4),
#   ('copy', 4),
#   ('setuptools', 3),
#   ('shlex', 3),
#   ('signal', 3),
#   ('genericpath', 3),
#   ('absolute_import', 3),
#   ('base64', 3),
#   ('enum', 3),
#   ('abc', 3),
#   ('requests', 2),
#   ('warnings', 2),
#   ('within', 2),
#   ('distutils', 2),
#   ('nbformat', 2),
#   ('hashlib', 2),
#   ('tests', 2),
#   ('auxlib', 2),
#   ('bz2', 2),
#   ('print_function', 2),
#   ('bisect', 2),
#   ('everything', 1),
#   ('email', 1),
#   ('mimetypes', 1),
#   ('sysconfig', 1),
#   ('uuid', 1),
#   ('initialize_logging', 1),
#   ('importlib', 1),
#   ('ctypes', 1),
#   ('responses', 1),
#   ('features', 1),
#   ('add_parser_json', 1),
#   ('platform', 1),
#   ('ourselves', 1),
#   ('getpass', 1),
#   ('this', 1),
#   ('shutil', 1),
#   ('url_pat', 1),
#   ('hmac', 1),
#   ('Crypto', 1),
#   ('difflib', 1),
#   ('struct', 1),
#   ('threading', 1),
#   ('fcntl', 1),
#   ('array', 1),
#   ('termios', 1),
#   ('themselves', 1),
#   ('a', 1),
#   ('for', 1),
#   ('ast', 1),
#   ('cgi', 1),
#   ('ftplib', 1),
#   ('rm_rf', 1),
#   ('math', 1),
#   ('typeutils', 1),
#   ('heapq', 1),
#   ('pycosat', 1)],
#  'constantly': [('os', 3),
#   ('sys', 2),
#   ('constantly', 2),
#   ('codecs', 1),
#   ('versioneer', 1),
#   ('setuptools', 1),
#   ('it', 1),
#   ('time', 1),
#   ('errno', 1),
#   ('re', 1),
#   ('subprocess', 1),
#   ('shlex', 1),
#   ('functools', 1),
#   ('itertools', 1),
#   ('operator', 1),
#   ('twisted', 1)],
#  'constructor': [('os', 18),
#   ('sys', 12),
#   ('constructor', 7),
#   ('re', 5),
#   ('shutil', 4),
#   ('tempfile', 3),
#   ('libconda', 2),
#   ('distutils', 1),
#   ('constructor/__init__', 1),
#   ('tarfile', 1),
#   ('traceback', 1),
#   ('hashlib', 1),
#   ('collections', 1),
#   ('random', 1),
#   ('ctypes', 1),
#   ('winreg', 1),
#   ('any', 1),
#   ('json', 1),
#   ('stat', 1),
#   ('yaml', 1),
#   ('unittest', 1)],
#  'cookies': [('sys', 3),
#   ('re', 2),
#   ('logging', 2),
#   ('urllib', 2),
#   ('setuptools', 1),
#   ('cookies', 1),
#   ('pytest', 1),
#   ('datetime', 1),
#   ('unicodedata', 1),
#   ('show', 1),
#   ('unicode_literals', 1)],
#  'cymem': [('os', 2),
#   ('sys', 2),
#   ('subprocess', 2),
#   ('distutils', 2),
#   ('cymem', 1),
#   ('print_function', 1),
#   ('json', 1),
#   ('hashlib', 1),
#   ('Cython', 1),
#   ('shutil', 1),
#   ('contextlib', 1)],
#  'cytoolz': [('cytoolz', 42),
#   ('operator', 6),
#   ('functools', 4),
#   ('toolz', 4),
#   ('dev_skip_test', 4),
#   ('inspect', 3),
#   ('itertools', 3),
#   ('sys', 2),
#   ('tlz', 2),
#   ('types', 2),
#   ('collections', 2),
#   ('pickle', 2),
#   ('nose', 1),
#   ('import_module', 1),
#   ('difflib', 1),
#   ('os', 1),
#   ('setuptools', 1),
#   ('Cython', 1),
#   ('doctest', 1),
#   ('random', 1),
#   ('platform', 1)],
#  'datashader': [('numpy', 14),
#   ('datashader', 12),
#   ('bokeh', 11),
#   ('pandas', 8),
#   ('pytest', 7),
#   ('datashape', 6),
#   ('dask', 6),
#   ('xarray', 6),
#   ('os', 5),
#   ('toolz', 5),
#   ('collections', 4),
#   ('numba', 3),
#   ('io', 3),
#   ('sys', 2),
#   ('uuid', 2),
#   ('datashader;', 1),
#   ('download_sample_data', 1),
#   ('setuptools', 1),
#   ('itertools', 1),
#   ('rasterio', 1),
#   ('math', 1),
#   ('inspect', 1),
#   ('argparse', 1),
#   ('yaml', 1),
#   ('odo', 1),
#   ('json', 1),
#   ('any', 1),
#   ('time', 1),
#   ('warnings', 1)],
#  'datrie': [('datrie', 5),
#   ('string', 4),
#   ('pickle', 2),
#   ('sys', 2),
#   ('os', 2),
#   ('random', 2),
#   ('glob', 1),
#   ('setuptools', 1),
#   ('timeit', 1),
#   ('zipfile', 1),
#   ('tempfile', 1),
#   ('pytest', 1)],
#  'entrypoints': [('os', 3),
#   ('sys', 2),
#   ('warnings', 2),
#   ('contextmanager', 1),
#   ('glob', 1),
#   ('importlib', 1),
#   ('io', 1),
#   ('itertools', 1),
#   ('re', 1),
#   ('zipfile', 1),
#   ('pytest', 1),
#   ('entrypoints', 1),
#   ('shlex', 1)],
#  'fastcache': [('fastcache', 6),
#   ('itertools', 3),
#   ('random', 3),
#   ('sys', 2),
#   ('unittest', 2),
#   ('print_function', 1),
#   ('functools', 1),
#   ('timeit', 1),
#   ('lru_cache', 1),
#   ('os', 1),
#   ('distutils', 1),
#   ('python', 1),
#   ('abc', 1),
#   ('collections', 1),
#   ('pickle', 1),
#   ('threading', 1),
#   ('pytest', 1),
#   ('warnings', 1)],
#  'feedparser': [('re', 13),
#   ('datetime', 5),
#   ('absolute_import', 5),
#   ('urllib', 3),
#   ('time', 2),
#   ('xml', 2),
#   ('sys', 2),
#   ('codecs', 2),
#   ('copy', 2),
#   ('rfc822', 1),
#   ('email', 1),
#   ('io', 1),
#   ('gzip', 1),
#   ('struct', 1),
#   ('zlib', 1),
#   ('sgmllib', 1),
#   ('setuptools', 1),
#   ('urlparse', 1),
#   ('glob', 1),
#   ('operator', 1),
#   ('html', 1),
#   ('htmlentitydefs', 1),
#   ('cgi', 1),
#   ('collections', 1),
#   ('escape', 1)],
#  'flask-cors': [('flask_cors', 29),
#   ('flask', 19),
#   ('logging', 4),
#   ('flask-cors', 3),
#   ('re', 3),
#   ('datetime', 2),
#   ('sys', 2),
#   ('unittest2', 2),
#   ('unittest', 2),
#   ('os', 2),
#   ('cross_origin', 1),
#   ('setup', 1),
#   ('functools', 1),
#   ('collections', 1),
#   ('six', 1),
#   ('werkzeug', 1),
#   ('serve', 1),
#   ('request', 1)],
#  'flask-login': [('sys', 4),
#   ('werkzeug', 3),
#   ('datetime', 3),
#   ('os', 2),
#   ('pygments', 2),
#   ('urlparse', 1),
#   ('setuptools', 1),
#   ('hmac', 1),
#   ('hashlib', 1),
#   ('functools', 1),
#   ('warnings', 1),
#   ('flask', 1),
#   ('text_type', 1),
#   ('unittest2', 1),
#   ('unittest', 1),
#   ('base64', 1),
#   ('collections', 1),
#   ('contextlib', 1)],
#  'flask-wtf': [('flask_wtf', 17),
#   ('wtforms', 16),
#   ('flask', 15),
#   ('pytest', 6),
#   ('werkzeug', 6),
#   ('warnings', 5),
#   ('os', 3),
#   ('flask_babel', 2),
#   ('sys', 2),
#   ('urllib', 2),
#   ('"wtforms', 1),
#   ('babel', 1),
#   ('flask_babelex', 1),
#   ('urllib2', 1),
#   ('json', 1),
#   ('io', 1),
#   ('jinja2', 1),
#   ('collections', 1),
#   ('flaskr', 1),
#   ('unittest', 1),
#   ('tempfile', 1),
#   ('markupsafe', 1),
#   ('hashlib', 1),
#   ('logging', 1),
#   ('functools', 1),
#   ('itsdangerous', 1),
#   ('setuptools', 1),
#   ('datetime', 1),
#   ('pkg_resources', 1)],
#  'greenlet': [('sys', 13),
#   ('greenlet', 13),
#   ('unittest', 12),
#   ('distutils', 4),
#   ('gc', 4),
#   ('weakref', 3),
#   ('time', 3),
#   ('threading', 3),
#   ('os', 2),
#   ('pip', 1),
#   ('tests', 1),
#   ('optparse', 1),
#   ('setuptools', 1),
#   ('glob', 1),
#   ('my_build_ext', 1),
#   ('abc', 1)],
#  'hs2client': [('os', 6),
#   ('sys', 4),
#   ('numpy', 3),
#   ('six', 3),
#   ('pandas', 2),
#   ('re', 2),
#   ('hs2client', 2),
#   ('itertools', 1),
#   ('cPickle', 1),
#   ('shutil', 1),
#   ('Cython', 1),
#   ('cythonize', 1),
#   ('setuptools', 1),
#   ('getpass', 1),
#   ('guid', 1),
#   ('perfect', 1),
#   ('codecs', 1),
#   ('copy', 1),
#   ('getopt', 1),
#   ('math', 1),
#   ('sre_compile', 1)],
#  'html5lib-python': [('html5lib', 21),
#   ('six', 18),
#   ('re', 10),
#   ('sys', 8),
#   ('pytest', 8),
#   ('codecs', 7),
#   ('xml', 7),
#   ('collections', 6),
#   ('os', 6),
#   ('json', 5),
#   ('genshi', 5),
#   ('urllib', 4),
#   ('warnings', 4),
#   ('ordereddict', 2),
#   ('itertools', 2),
#   ('lxml', 2),
#   ('types', 2),
#   ('io', 2),
#   ('platform', 1),
#   ('datrie', 1),
#   ('mock', 1),
#   ('pkg_resources', 1),
#   ('bisect', 1),
#   ('glob', 1),
#   ('ast', 1),
#   ('setuptools', 1),
#   ('profiling', 1),
#   ('traceback', 1),
#   ('optparse', 1),
#   ('spider', 1),
#   ('md5', 1),
#   ('absolute_import', 1),
#   ('difflib', 1),
#   ('weakref', 1),
#   ('webencodings', 1),
#   ('string', 1)],
#  'idna': [('sys', 7),
#   ('unittest', 5),
#   ('idna', 4),
#   ('os', 3),
#   ('re', 3),
#   ('bisect', 2),
#   ('UTS46', 1),
#   ('intranges_from_list', 1),
#   ('urllib', 1),
#   ('urllib2', 1),
#   ('xml', 1),
#   ('gzip', 1),
#   ('codecs', 1),
#   ('io', 1),
#   ('setuptools', 1),
#   ('unicodedata', 1)],
#  'imagesize_py': [('os', 2),
#   ('imagesize', 2),
#   ('timeit', 1),
#   ('unittest', 1),
#   ('setuptools', 1),
#   ('setup', 1),
#   ('struct', 1)],
#  'impyla': [('sys', 17),
#   ('impala', 14),
#   ('thrift', 12),
#   ('six', 11),
#   ('absolute_import', 8),
#   ('pytest', 7),
#   ('os', 6),
#   ('sqlalchemy', 6),
#   ('pprint', 6),
#   ('urlparse', 6),
#   ('re', 4),
#   ('logging', 3),
#   ('subprocess', 3),
#   ('datetime', 3),
#   ('time', 3),
#   ('unittest2', 2),
#   ('unittest', 2),
#   ('getpass', 2),
#   ('requests', 2),
#   ('decimal', 1),
#   ('json', 1),
#   ('simplejson', 1),
#   ('ez_setup', 1),
#   ('setuptools', 1),
#   ('versioneer', 1),
#   ('warnings', 1),
#   ('string', 1),
#   ('random', 1),
#   ('connect', 1),
#   ('use_setuptools', 1),
#   ('shutil', 1),
#   ('tempfile', 1),
#   ('zipfile', 1),
#   ('optparse', 1),
#   ('puresasl', 1),
#   ('contextlib', 1),
#   ('textwrap', 1),
#   ('argparse', 1),
#   ('llvm', 1),
#   ('hdfs', 1),
#   ('it', 1),
#   ('socket', 1),
#   ('operator', 1),
#   ('bitarray', 1),
#   ('errno', 1),
#   ('setup', 1),
#   ('_version', 1)],
#  'incremental': [('incremental', 6),
#   ('twisted', 4),
#   ('os', 3),
#   ('setuptools', 2),
#   ('sys', 2),
#   ('datetime', 2),
#   ('click', 1),
#   ('Distribution', 1),
#   ('distutils', 1),
#   ('operator', 1)],
#  'inflection': [('inflection', 3),
#   ('setuptools', 1),
#   ('sys', 1),
#   ('re', 1),
#   ('unicodedata', 1),
#   ('pytest', 1)],
#  'ipywidgets': [('traitlets', 14),
#   ('IPython', 4),
#   ('sys', 4),
#   ('os', 3),
#   ('ipywidgets', 2),
#   ('nose', 2),
#   ('ipykernel', 2),
#   ('datetime', 2),
#   ('unittest', 2),
#   ('collections', 2),
#   ('base64', 1),
#   ('register', 1),
#   ('subprocess', 1),
#   ('dirname', 1),
#   ('array', 1),
#   ('ipython_genutils', 1),
#   ('mock', 1),
#   ('inspect', 1),
#   ('re', 1),
#   ('contextlib', 1),
#   ('itertools', 1)],
#  'isort': [('os', 7),
#   ('sys', 6),
#   ('setuptools', 3),
#   ('absolute_import', 3),
#   ('re', 2),
#   ('definitions', 2),
#   ('kate', 2),
#   ('subprocess', 2),
#   ('isort', 1),
#   ('codecs', 1),
#   ('shutil', 1),
#   ('tempfile', 1),
#   ('pylama', 1),
#   ('copy', 1),
#   ('io', 1),
#   ('itertools', 1),
#   ('fnmatch', 1),
#   ('collections', 1),
#   ('abc', 1),
#   ('functools', 1),
#   ('numbers', 1),
#   ('argparse', 1),
#   ('glob', 1),
#   ('order', 1),
#   ('base64', 1),
#   ('imp', 1),
#   ('zlib', 1),
#   ('types', 1)],
#  'jdcal': [('jdcal', 2),
#   ('math', 2),
#   ('setuptools', 1),
#   ('pytest', 1),
#   ('jcal2jd', 1),
#   ('random', 1)],
#  'kerberos-sspi': [('base64', 2),
#   ('sys', 2),
#   ('logging', 2),
#   ('kerberos_sspi', 1),
#   ('struct', 1),
#   ('setuptools', 1),
#   ('win32security', 1),
#   ('sspicon', 1),
#   ('sspi', 1)],
#  'keyring': [('sys', 8),
#   ('keyring', 8),
#   ('logging', 5),
#   ('unittest', 4),
#   ('os', 4),
#   ('getpass', 3),
#   ('platform', 3),
#   ('string', 3),
#   ('pkg_resources', 3),
#   ('contextlib', 2),
#   ('functools', 2),
#   ('abc', 2),
#   ('ctypes', 2),
#   ('pluggy', 1),
#   ('configparser', 1),
#   ('random', 1),
#   ('of', 1),
#   ('importlib', 1),
#   ('urllib2', 1),
#   ('operator', 1),
#   ('print_function', 1),
#   ('optparse', 1),
#   ('secretstorage', 1),
#   ('re', 1),
#   ('io', 1),
#   ('setuptools', 1),
#   ('pytest', 1),
#   ('collections', 1),
#   ('struct', 1)],
#  'ldap3': [('ldap3', 59),
#   ('unittest', 46),
#   ('test', 33),
#   ('pyasn1', 27),
#   ('os', 22),
#   ('datetime', 16),
#   ('time', 14),
#   ('json', 7),
#   ('socket', 7),
#   ('binascii', 5),
#   ('sys', 5),
#   ('threading', 5),
#   ('random', 4),
#   ('re', 4),
#   ('unicodedata', 3),
#   ('platform', 3),
#   ('hashlib', 3),
#   ('base64', 3),
#   ('collections', 3),
#   ('://www', 2),
#   ('queue', 2),
#   ('io', 2),
#   ('uuid', 2),
#   ('hmac', 2),
#   ('copy', 2),
#   ('urllib', 2),
#   ('struct', 2),
#   ('string', 2),
#   ('types', 1),
#   ('future', 1),
#   ('validate_simple_password', 1),
#   ('ctypes', 1),
#   ('build_control', 1),
#   ('to_raw', 1),
#   ('stringprep', 1),
#   ('gssapi', 1),
#   ('logging', 1),
#   ('pprint', 1),
#   ('referrals_to_list', 1),
#   ('backports', 1),
#   ('setuptools', 1),
#   ('calendar', 1),
#   ('functools', 1),
#   ('format_time', 1),
#   ('python', 1),
#   ('safe_rdn', 1),
#   ('escape_bytes', 1),
#   ('test_user', 1),
#   ('ssl', 1)],
#  'libconda': [('libconda', 11),
#   ('os', 9),
#   ('logging', 8),
#   ('sys', 6),
#   ('json', 5),
#   ('unittest', 4),
#   ('itertools', 3),
#   ('io', 2),
#   ('urllib', 2),
#   ('hashlib', 2),
#   ('collections', 2),
#   ('functools', 2),
#   ('re', 2),
#   ('math', 2),
#   ('types', 1),
#   ('configparser', 1),
#   ('conda', 1),
#   ('bz2', 1),
#   ('shutil', 1),
#   ('tempfile', 1),
#   ('platform', 1),
#   ('mimetypes', 1),
#   ('email', 1),
#   ('cgi', 1),
#   ('signal', 1),
#   ('time', 1),
#   ('fcntl', 1),
#   ('array', 1),
#   ('distutils', 1),
#   ('contextlib', 1),
#   ('datetime', 1),
#   ('abc', 1),
#   ('tests', 1),
#   ('operator', 1),
#   ('pytest', 1),
#   ('pycosat', 1)],
#  'line_profiler': [('distutils', 4),
#   ('os', 2),
#   ('unittest', 2),
#   ('setuptools', 1),
#   ('cPickle', 1),
#   ('pickle', 1),
#   ('cStringIO', 1),
#   ('functools', 1),
#   ('optparse', 1),
#   ('sys', 1),
#   ('of', 1),
#   ('kernprof', 1),
#   ('line_profiler', 1)],
#  'locket.py': [('os', 3),
#   ('sys', 2),
#   ('locket', 2),
#   ('time', 2),
#   ('contextlib', 1),
#   ('tempfile', 1),
#   ('shutil', 1),
#   ('setuptools', 1),
#   ('errno', 1),
#   ('threading', 1),
#   ('weakref', 1),
#   ('fcntl', 1),
#   ('msvcrt', 1),
#   ('functools', 1),
#   ('io', 1),
#   ('signal', 1),
#   ('nose', 1),
#   ('spur', 1)],
#  'luigi': [('luigi', 405),
#   ('helpers', 80),
#   ('os', 66),
#   ('logging', 56),
#   ('datetime', 31),
#   ('tempfile', 29),
#   ('mock', 28),
#   ('time', 28),
#   ('sys', 25),
#   ('warnings', 22),
#   ('unittest', 19),
#   ('random', 18),
#   ('subprocess', 16),
#   ('json', 15),
#   ('collections', 12),
#   ('abc', 12),
#   ('shutil', 11),
#   ('pickle', 10),
#   ('re', 10),
#   ('itertools', 8),
#   ('threading', 8),
#   ('signal', 8),
#   ('contextlib', 8),
#   ('functools', 7),
#   ('io', 7),
#   ('nose', 6),
#   ('multiprocessing', 6),
#   ('cPickle', 4),
#   ('socket', 4),
#   ('oauth2client', 4),
#   ('googleapiclient', 4),
#   ('operator', 4),
#   ('argparse', 3),
#   ('tarfile', 3),
#   ('psutil', 3),
#   ('getpass', 3),
#   ('hashlib', 3),
#   ('urlparse', 3),
#   ('six', 3),
#   ('mysql', 3),
#   ('pykube', 3),
#   ('select', 2),
#   ('snakebite', 2),
#   ('boto', 2),
#   ('glob', 2),
#   ('posixpath', 2),
#   ('httplib2', 2),
#   ('redis', 2),
#   ('ftplib', 2),
#   ('print_function', 2),
#   ('boto3', 2),
#   ('textwrap', 2),
#   ('configparser', 2),
#   ('hypothesis', 2),
#   ('target_test', 2),
#   ('sqlalchemy', 2),
#   ('elasticsearch', 2),
#   ('enum', 2),
#   ('minicluster', 1),
#   ('snakebite_client', 1),
#   ('moto', 1),
#   ('traceback', 1),
#   ('webhdfs_minicluster', 1),
#   ('contrib', 1),
#   ('attr', 1),
#   ('scheduler_api_test', 1),
#   ('server_test', 1),
#   ('absolute_import', 1),
#   ('SGETask', 1),
#   ('decimal', 1),
#   ('sparkey', 1),
#   ('cStringIO', 1),
#   ('gc', 1),
#   ('GCS', 1),
#   ('importlib', 1),
#   ('atexit', 1),
#   ('local', 1),
#   ('dataproc', 1),
#   ('email', 1),
#   ('shlex', 1),
#   ('string', 1),
#   ('tmppath', 1),
#   ('bz2', 1),
#   ('gzip', 1),
#   ('errno', 1),
#   ('uuid', 1),
#   ('mimetypes', 1),
#   ('below:', 1),
#   ('sqla', 1),
#   ('pipes', 1),
#   ('sphinx', 1),
#   ('docutils', 1),
#   ('get_source_line', 1),
#   ('pkg_resources', 1),
#   ('doctest', 1),
#   ('heapq', 1),
#   ('locale', 1),
#   ('types', 1),
#   ('setuptools', 1),
#   ('xml', 1),
#   ('csv', 1),
#   ('pymongo', 1),
#   ('inspect', 1),
#   ('fnmatch', 1)],
#  'meld3': [('xml', 5),
#   ('sys', 4),
#   ('re', 3),
#   ('html', 1),
#   ('htmlentitydefs', 1),
#   ('setuptools', 1),
#   ('unittest', 1),
#   ('email', 1)],
#  'menuinst': [('os', 14),
#   ('sys', 9),
#   ('menuinst', 4),
#   ('ctypes', 4),
#   ('shutil', 3),
#   ('logging', 2),
#   ('subprocess', 2),
#   ('re', 2),
#   ('time', 2),
#   ('json', 1),
#   ('optparse', 1),
#   ('pytest', 1),
#   ('distutils', 1),
#   ('versioneer', 1),
#   ('plistlib', 1),
#   ('utils', 1),
#   ('xml', 1),
#   ('pywintypes', 1),
#   ('uuid', 1),
#   ('it', 1),
#   ('errno', 1)],
#  'mistune': [('mistune', 5),
#   ('re', 3),
#   ('os', 2),
#   ('pygments', 2),
#   ('time', 1),
#   ('functools', 1),
#   ('multiprocessing', 1),
#   ('setuptools', 1),
#   ('copy', 1),
#   ('sys', 1),
#   ('inspect', 1)],
#  'mkl-service': [('sys', 2),
#   ('os', 2),
#   ('distutils', 2),
#   ('mkl', 2),
#   ('re', 1),
#   ('doctest', 1),
#   ('cStringIO', 1),
#   ('io', 1),
#   ('unittest', 1)],
#  'mongo-python-driver': [('bson', 125),
#   ('pymongo', 110),
#   ('sys', 66),
#   ('datetime', 30),
#   ('os', 25),
#   ('threading', 21),
#   ('test', 18),
#   ('warnings', 18),
#   ('collections', 17),
#   ('time', 16),
#   ('re', 15),
#   ('copy', 10),
#   ('socket', 9),
#   ('struct', 8),
#   ('contextlib', 8),
#   ('random', 8),
#   ('pickle', 7),
#   ('json', 7),
#   ('uuid', 7),
#   ('weakref', 6),
#   ('gridfs', 6),
#   ('urllib', 6),
#   ('codecs', 5),
#   ('functools', 5),
#   ('gc', 4),
#   ('binascii', 4),
#   ('ssl', 4),
#   ('itertools', 4),
#   ('platform', 3),
#   ('module', 3),
#   ('traceback', 3),
#   ('calendar', 3),
#   ('glob', 2),
#   ('decimal', 2),
#   ('getopt', 2),
#   ('optparse', 2),
#   ('atexit', 2),
#   ('simplejson', 2),
#   ('select', 2),
#   ('shutil', 2),
#   ('subprocess', 2),
#   ('hashlib', 2),
#   ('signal', 2),
#   ('ipaddress', 2),
#   ('sphinx', 2),
#   ('integer_types', 2),
#   ('monotime', 1),
#   ('monotonic', 1),
#   ('io', 1),
#   ('cdecimal', 1),
#   ('gevent', 1),
#   ('urllib2', 1),
#   ('multiprocessing', 1),
#   ('certifi', 1),
#   ('errno', 1),
#   ('hmac', 1),
#   ('winkerberos', 1),
#   ('kerberos', 1),
#   ('object_hook', 1),
#   ('tempfile', 1),
#   ('zipfile', 1),
#   ('maxStalenessSeconds', 1),
#   ('testing', 1),
#   ('monitor', 1),
#   ('stat', 1),
#   ('SONManipulators', 1),
#   ('b', 1),
#   ('extensions', 1),
#   ('docutils', 1),
#   ('pypi', 1),
#   ('queue', 1),
#   ('base64', 1),
#   ('rs_or_single_client_noauth', 1),
#   ('replica_set_connection', 1),
#   ('math', 1),
#   ('iterate', 1),
#   ('ha_tools', 1),
#   ('utilities', 1),
#   ('a', 1),
#   ('logging', 1),
#   ('definitions', 1),
#   ('common', 1)],
#  'more-itertools': [('more_itertools', 3),
#   ('itertools', 3),
#   ('random', 2),
#   ('six', 2),
#   ('functools', 2),
#   ('multiprocessing', 1),
#   ('setuptools', 1),
#   ('deque', 1),
#   ('operator', 1),
#   ('collections', 1),
#   ('heapq', 1),
#   ('decimal', 1),
#   ('fractions', 1),
#   ('io', 1),
#   ('unittest', 1),
#   ('nose', 1),
#   ('sys', 1),
#   ('sphinx_rtd_theme', 1)],
#  'multipledispatch': [('multipledispatch', 6),
#   ('warnings', 3),
#   ('inspect', 2),
#   ('os', 1),
#   ('setuptools', 1),
#   ('contextlib', 1),
#   ('functools', 1),
#   ('sys', 1)],
#  'munch': [],
#  'natsort': [('natsort', 28),
#   ('pytest', 6),
#   ('math', 5),
#   ('operator', 5),
#   ('locale', 4),
#   ('sys', 4),
#   ('unicodedata', 4),
#   ('hypothesis', 3),
#   ('functools', 3),
#   ('re', 3),
#   ('pathlib', 2),
#   ('os', 2),
#   ('itertools', 2),
#   ('unittest', 1),
#   ('cProfile', 1),
#   ('warnings', 1),
#   ('setuptools', 1),
#   ('string', 1),
#   ('compat', 1),
#   ('unicode_literals', 1),
#   ('collections', 1)],
#  'nb_anacondacloud': [('os', 4),
#   ('binstar_client', 4),
#   ('json', 3),
#   ('notebook', 3),
#   ('unittest', 2),
#   ('mock', 2),
#   ('logging', 2),
#   ('tornado', 2),
#   ('subprocess', 2),
#   ('platform', 1),
#   ('re', 1),
#   ('io', 1),
#   ('time', 1),
#   ('yaml', 1),
#   ('glob', 1),
#   ('shutil', 1)],
#  'nb_conda': [('os', 4),
#   ('notebook', 4),
#   ('subprocess', 3),
#   ('unittest', 2),
#   ('re', 2),
#   ('pkg_resources', 2),
#   ('setuptools', 1),
#   ('glob', 1),
#   ('mock', 1),
#   ('platform', 1),
#   ('json', 1),
#   ('tempfile', 1),
#   ('traitlets', 1),
#   ('requests', 1)],
#  'nb_conda_kernels': [('os', 4),
#   ('unittest', 3),
#   ('subprocess', 3),
#   ('notebook', 2),
#   ('json', 2),
#   ('traitlets', 2),
#   ('setuptools', 1),
#   ('test_kernelspecs_api', 1),
#   ('argparse', 1),
#   ('logging', 1),
#   ('re', 1),
#   ('sys', 1),
#   ('time', 1),
#   ('exists', 1),
#   ('jupyter_client', 1),
#   ('glob', 1),
#   ('mock', 1),
#   ('platform', 1)],
#  'nbpresent': [('sys', 10),
#   ('os', 8),
#   ('subprocess', 7),
#   ('nbbrowserpdf', 3),
#   ('platform', 3),
#   ('codecs', 3),
#   ('shutil', 2),
#   ('nbconvert', 2),
#   ('glob', 2),
#   ('nbpresent', 2),
#   ('notebook', 2),
#   ('socket', 1),
#   ('tempfile', 1),
#   ('json', 1),
#   ('collections', 1),
#   ('multiprocessing', 1),
#   ('importlib', 1),
#   ('argparse', 1),
#   ('time', 1),
#   ('ghost', 1),
#   ('unittest', 1),
#   ('mock', 1),
#   ('setuptools', 1)],
#  'neon': [('neon', 419),
#   ('numpy', 137),
#   ('builtins', 55),
#   ('os', 52),
#   ('itertools', 39),
#   ('logging', 27),
#   ('pytest', 22),
#   ('pycuda', 20),
#   ('future', 16),
#   ('sys', 14),
#   ('utils', 11),
#   ('collections', 11),
#   ('h5py', 10),
#   ('re', 8),
#   ('math', 8),
#   ('grad_funcs', 6),
#   ('glob', 5),
#   ('subprocess', 5),
#   ('bokeh', 5),
#   ('struct', 4),
#   ('gen_backend', 4),
#   ('copy', 4),
#   ('json', 4),
#   ('functools', 4),
#   ('scipy', 3),
#   ('argparse', 3),
#   ('atexit', 3),
#   ('zipfile', 3),
#   ('configargparse', 3),
#   ('tarfile', 3),
#   ('operator', 3),
#   ('zip', 3),
#   ('shutil', 2),
#   ('tempfile', 2),
#   ('yaml', 2),
#   ('print_function', 2),
#   ('tqdm', 2),
#   ('util', 2),
#   ('gzip', 2),
#   ('timeit', 2),
#   ('ctypes', 2),
#   ('generate_anchors', 2),
#   ('set_trace', 2),
#   ('root', 1),
#   ('aeon', 1),
#   ('://github', 1),
#   ('input', 1),
#   ('str', 1),
#   ('warnings', 1),
#   ('build_data_train', 1),
#   ('this', 1),
#   ('importlib', 1),
#   ('pkgutil', 1),
#   ('appdirs', 1),
#   ('objectlocalization', 1),
#   ('past', 1),
#   ('xml', 1),
#   ('bilingual', 1),
#   ('proposal_layer_ref', 1),
#   ('setuptools', 1),
#   ('jinja2', 1),
#   ('tensors_allclose', 1),
#   ('convert_xml_to_json', 1),
#   ('pdb;pdb', 1),
#   ('command', 1),
#   ('inspect', 1),
#   ('pprint', 1),
#   ('traceback', 1),
#   ('round', 1),
#   ('https', 1),
#   ('time', 1),
#   ('which', 1),
#   ('abc', 1)],
#  'numexpr': [('numexpr', 17),
#   ('numpy', 13),
#   ('sys', 10),
#   ('os', 6),
#   ('timeit', 5),
#   ('time', 5),
#   ('subprocess', 2),
#   ('platform', 2),
#   ('warnings', 2),
#   ('threading', 2),
#   ('cpuinfo', 1),
#   ('arange', 1),
#   ('scipy', 1),
#   ('datetime', 1),
#   ('shutil', 1),
#   ('distutils', 1),
#   ('contextlib', 1),
#   ('operator', 1),
#   ('pkg_resources', 1),
#   ('inspect', 1)],
#  'numpy': [('numpy', 398),
#   ('sys', 136),
#   ('os', 100),
#   ('warnings', 53),
#   ('distutils', 42),
#   ('re', 38),
#   ('operator', 18),
#   ('itertools', 15),
#   ('subprocess', 14),
#   ('functools', 12),
#   ('tempfile', 11),
#   ('shutil', 10),
#   ('copy', 10),
#   ('unittest', 9),
#   ('math', 8),
#   ('textwrap', 8),
#   ('platform', 8),
#   ('collections', 8),
#   ('util', 7),
#   ('pickle', 7),
#   ('io', 7),
#   ('setuptools', 6),
#   ('types', 6),
#   ('glob', 5),
#   ('genapi', 4),
#   ('numbers', 4),
#   ('code_generators', 3),
#   ('optparse', 3),
#   ('gc', 3),
#   ('time', 3),
#   ('datetime', 3),
#   ('numpy_api', 2),
#   ('atexit', 2),
#   ('ast', 2),
#   ('fileinput', 2),
#   ('hashlib', 2),
#   ('random', 2),
#   ('inspect', 2),
#   ('nose', 2),
#   ('struct', 2),
#   ('locale', 2),
#   ('pprint', 2),
#   ('shlex', 2),
#   ('timeit', 2),
#   ('until', 2),
#   ('threading', 2),
#   ('decimal', 2),
#   ('local', 1),
#   ('it', 1),
#   ('Cython', 1),
#   ('importlib', 1),
#   ('assert_equal', 1),
#   ('egg_info', 1),
#   ('floatint', 1),
#   ('install_headers', 1),
#   ('jiffies', 1),
#   ('occurrences', 1),
#   ('pathlib', 1),
#   ('using', 1),
#   ('contextlib', 1),
#   ('six', 1),
#   ('xml', 1),
#   ('operation', 1),
#   ('codecs', 1),
#   ('git', 1),
#   ('github', 1),
#   ('parent_path', 1),
#   ('read_config', 1),
#   ('mmap', 1),
#   ('sphinx', 1),
#   ('doctest', 1),
#   ('struggling', 1),
#   ('alloc_hook', 1),
#   ('matrix', 1),
#   ('plex', 1),
#   ('binascii', 1),
#   ('fortran', 1),
#   ('clapack_scrub', 1),
#   ('and', 1),
#   ('times', 1),
#   ('bdist_mpkg', 1),
#   ('ndarray', 1),
#   ('ctypes', 1),
#   ('weakref', 1),
#   ('absolute_import', 1),
#   ('urllib', 1),
#   ('html', 1),
#   ('sysconfig', 1),
#   ('long', 1),
#   ('option', 1),
#   ('commands', 1),
#   ('traceback', 1),
#   ('ufunc_docstrings', 1),
#   ('gzip', 1),
#   ('abc', 1),
#   ('builtins', 1),
#   ('fnmatch', 1),
#   ('string', 1),
#   ('matplotlib', 1),
#   ('Numeric', 1)],
#  'numpydoc': [('sys', 4),
#   ('re', 3),
#   ('inspect', 3),
#   ('pydoc', 3),
#   ('distutils', 2),
#   ('textwrap', 2),
#   ('collections', 2),
#   ('jinja2', 2),
#   ('setuptools', 1),
#   ('os', 1),
#   ('sphinx', 1),
#   ('io', 1),
#   ('numpydoc', 1)],
#  'pandas': [('pandas', 994),
#   ('numpy', 348),
#   ('pytest', 193),
#   ('datetime', 132),
#   ('warnings', 118),
#   ('os', 57),
#   ('sys', 57),
#   ('re', 40),
#   ('collections', 38),
#   ('itertools', 37),
#   ('distutils', 33),
#   ('operator', 23),
#   ('pytz', 21),
#   ('dateutil', 18),
#   ('string', 17),
#   ('functools', 17),
#   ('matplotlib', 15),
#   ('time', 11),
#   ('textwrap', 11),
#   ('copy', 11),
#   ('inspect', 10),
#   ('io', 10),
#   ('random', 9),
#   ('csv', 9),
#   ('subprocess', 8),
#   ('struct', 7),
#   ('numpydoc', 6),
#   ('locale', 6),
#   ('types', 6),
#   ('contextlib', 6),
#   ('platform', 5),
#   ('importlib', 5),
#   ('codecs', 5),
#   ('json', 5),
#   ('vbench', 4),
#   ('data', 4),
#   ('timeit', 4),
#   ('ast', 4),
#   ('argparse', 4),
#   ('math', 4),
#   ('coding=utf-8', 4),
#   ('la', 3),
#   ('ctypes', 3),
#   ('gc', 3),
#   ('scipy', 3),
#   ('glob', 3),
#   ('moment_plots', 3),
#   ('sqlite3', 3),
#   ('sqlalchemy', 3),
#   ('calendar', 3),
#   ('util', 2),
#   ('array', 2),
#   ('pydoc', 2),
#   ('abc', 2),
#   ('mmap', 2),
#   ('print_function', 2),
#   ('logging', 2),
#   ('coding:', 2),
#   ('pygments', 2),
#   ('shutil', 2),
#   ('sphinx', 2),
#   ('cStringIO', 2),
#   ('tokenize', 2),
#   ('requests', 2),
#   ('numbers', 2),
#   ('tempfile', 2),
#   ('uuid', 2),
#   ('testing', 2),
#   ('relativedelta', 2),
#   ('decimal', 2),
#   ('pylint:', 2),
#   ('nose', 1),
#   ('threading', 1),
#   ('flake8:', 1),
#   ('psutil', 1),
#   ('factorize', 1),
#   ('period', 1),
#   ('numexpr', 1),
#   ('rands', 1),
#   ('choice', 1),
#   ('slow', 1),
#   ('imp', 1),
#   ('optparse', 1),
#   ('defaultdict', 1),
#   ('pyperclip', 1),
#   ('s3fs', 1),
#   ('botocore', 1),
#   ('multiprocessing', 1),
#   ('get_terminal_size', 1),
#   ('zip', 1),
#   ('for', 1),
#   ('script', 1),
#   ('openpyxl', 1),
#   ('astor', 1),
#   ('xml', 1),
#   ('map', 1),
#   ('generic', 1),
#   ('pprint_thing', 1),
#   ('xmlrpclib', 1),
#   ('gtk', 1),
#   ('on', 1),
#   ('pandas_gbq', 1),
#   ('pickle', 1),
#   ('compiler', 1),
#   ('range', 1),
#   ('pprint', 1),
#   ('conf', 1),
#   ('zipfile', 1),
#   ('six', 1),
#   ('being', 1),
#   ('git', 1),
#   ('pysftp', 1),
#   ('independent', 1),
#   ('statements', 1),
#   ('thread', 1),
#   ('miscellaneous', 1),
#   ('test_groupby', 1),
#   ('""":func:`~pandas', 1),
#   ('it', 1),
#   ('concat', 1),
#   ('test', 1),
#   ('assert_series_equal', 1),
#   ('simplejson', 1),
#   ('long', 1),
#   ('errno', 1),
#   ('pdb;', 1),
#   ('weakref', 1)],
#  'pandas-datareader': [('pandas', 71),
#   ('pandas_datareader', 56),
#   ('numpy', 15),
#   ('pytest', 13),
#   ('datetime', 12),
#   ('os', 8),
#   ('requests', 6),
#   ('warnings', 5),
#   ('re', 4),
#   ('time', 4),
#   ('json', 3),
#   ('zipfile', 3),
#   ('collections', 2),
#   ('csv', 2),
#   ('sys', 2),
#   ('ftplib', 2),
#   ('dateutil', 1),
#   ('io', 1),
#   ('distutils', 1),
#   ('requests_file', 1),
#   ('requests_ftp', 1),
#   ('itertools', 1),
#   ('functools', 1),
#   ('zlib', 1),
#   ('various', 1),
#   ('get_oanda_currency_historical_rates', 1),
#   ('tempfile', 1),
#   ('ast', 1),
#   ('setuptools', 1),
#   ('gzip', 1)],
#  'pandasql': [('pandas', 5),
#   ('pandasql', 4),
#   ('re', 2),
#   ('pytest', 2),
#   ('os', 1),
#   ('distutils', 1),
#   ('setuptools', 1),
#   ('sklearn', 1),
#   ('inspect', 1),
#   ('contextlib', 1),
#   ('sqlalchemy', 1),
#   ('warnings', 1),
#   ('string', 1)],
#  'parsel': [('parsel', 5),
#   ('cssselect', 4),
#   ('six', 3),
#   ('re', 2),
#   ('unittest', 2),
#   ('sys', 2),
#   ('w3lib', 1),
#   ('setuptools', 1),
#   ('lxml', 1),
#   ('os', 1),
#   ('weakref', 1)],
#  'partd': [('partd', 19),
#   ('os', 13),
#   ('shutil', 11),
#   ('pandas', 5),
#   ('pickle', 4),
#   ('contextlib', 4),
#   ('toolz', 4),
#   ('functools', 3),
#   ('numpy', 3),
#   ('pytest', 3),
#   ('threading', 3),
#   ('struct', 2),
#   ('locket', 2),
#   ('string', 2),
#   ('time', 2),
#   ('bisect', 2),
#   ('operator', 2),
#   ('tempfile', 2),
#   ('sys', 1),
#   ('io', 1),
#   ('queue', 1),
#   ('math', 1),
#   ('snappy', 1),
#   ('absolute_import', 1),
#   ('zlib', 1),
#   ('setuptools', 1),
#   ('zmq', 1),
#   ('logging', 1),
#   ('itertools', 1),
#   ('socket', 1),
#   ('collections', 1),
#   ('atexit', 1)],
#  'path.py': [('sys', 2),
#   ('io', 1),
#   ('setuptools', 1),
#   ('path', 1),
#   ('warnings', 1),
#   ('codecs', 1),
#   ('os', 1),
#   ('shutil', 1),
#   ('time', 1),
#   ('ntpath', 1),
#   ('posixpath', 1),
#   ('textwrap', 1)],
#  'patsy': [('patsy', 41),
#   ('numpy', 19),
#   ('six', 15),
#   ('sys', 8),
#   ('os', 3),
#   ('tokenize', 3),
#   ('re', 2),
#   ('print_function', 2),
#   ('numbers', 2),
#   ('itertools', 2),
#   ('nose', 2),
#   ('of', 1),
#   ('setuptools', 1),
#   ('somewhere', 1),
#   ('collections', 1),
#   ('inspect', 1),
#   ('ast', 1),
#   ('other', 1),
#   ('get_ident', 1),
#   ('fails', 1),
#   ('wraps', 1),
#   ('warnings', 1),
#   ('http://www', 1)],
#  'petl': [('petl', 265),
#   ('tempfile', 21),
#   ('sys', 18),
#   ('operator', 17),
#   ('itertools', 13),
#   ('logging', 12),
#   ('datetime', 11),
#   ('os', 10),
#   ('io', 10),
#   ('collections', 8),
#   ('json', 4),
#   ('csv', 4),
#   ('sqlite3', 4),
#   ('locale', 4),
#   ('gzip', 4),
#   ('pkg_resources', 2),
#   ('ast', 2),
#   ('bz2', 2),
#   ('zipfile', 2),
#   ('time', 2),
#   ('eq_', 2),
#   ('contextlib', 2),
#   ('next', 2),
#   ('re', 2),
#   ('heapq', 2),
#   ('glob', 1),
#   ('optparse', 1),
#   ('pickle', 1),
#   ('numpy', 1),
#   ('nose', 1),
#   ('inspect', 1),
#   ('codecs', 1),
#   ('setuptools', 1),
#   ('object', 1),
#   ('shelve', 1),
#   ('tables', 1),
#   ('random', 1),
#   ('functools', 1),
#   ('petl;', 1),
#   ('psycopg2', 1),
#   ('lxml', 1),
#   ('gc', 1),
#   ('cStringIO', 1),
#   ('text_type', 1),
#   ('long', 1),
#   ('xlwt', 1)],
#  'pickleshare': [('pickleshare', 4),
#   ('os', 1),
#   ('timesys', 1),
#   ('setuptools', 1),
#   ('because', 1),
#   ('print_function', 1),
#   ('pathlib', 1)],
#  'pivottablejs': [('distutils', 1), ('IPython', 1)],
#  'plotly.py': [('plotly', 203),
#   ('unittest', 31),
#   ('nose', 31),
#   ('requests', 27),
#   ('warnings', 21),
#   ('six', 12),
#   ('matplotlib', 11),
#   ('absolute_import', 9),
#   ('os', 9),
#   ('numpy', 7),
#   ('numbers', 6),
#   ('random', 5),
#   ('math', 5),
#   ('collections', 5),
#   ('copy', 5),
#   ('datetime', 4),
#   ('mock', 4),
#   ('pkg_resources', 4),
#   ('decimal', 4),
#   ('string', 3),
#   ('itertools', 3),
#   ('utils', 3),
#   ('time', 3),
#   ('re', 3),
#   ('sys', 2),
#   ('nbconvert', 2),
#   ('graph_objs', 2),
#   ('base64', 2),
#   ('json', 2),
#   ('io', 2),
#   ('uuid', 2),
#   ('pytz', 2),
#   ('importlib', 1),
#   ('builtins', 1),
#   ('functools', 1),
#   ('pandas', 1),
#   ('imghdr', 1),
#   ('tempfile', 1),
#   ('vincent', 1),
#   ('nbformat', 1),
#   ('ipykernel', 1),
#   ('images', 1),
#   ('build_url', 1),
#   ('inspect', 1),
#   ('IPython', 1),
#   ('attr', 1),
#   ('setuptools', 1),
#   ('threading', 1),
#   ('decorator', 1),
#   ('grids', 1),
#   ('webbrowser', 1),
#   ('ssl', 1),
#   ('urlparse', 1),
#   ('contextlib', 1),
#   ('textwrap', 1),
#   ('pprint', 1),
#   ('mpl', 1),
#   ('a', 1)],
#  'preshed': [('os', 6),
#   ('pytest', 2),
#   ('preshed', 2),
#   ('sys', 2),
#   ('subprocess', 2),
#   ('distutils', 2),
#   ('random', 1),
#   ('fabric', 1),
#   ('fabtools', 1),
#   ('print_function', 1),
#   ('json', 1),
#   ('hashlib', 1),
#   ('Cython', 1),
#   ('contextlib', 1)],
#  'psutil': [('psutil', 57),
#   ('os', 37),
#   ('sys', 35),
#   ('errno', 19),
#   ('socket', 15),
#   ('contextlib', 14),
#   ('time', 14),
#   ('collections', 12),
#   ('functools', 11),
#   ('subprocess', 9),
#   ('datetime', 9),
#   ('re', 8),
#   ('traceback', 5),
# ...
#   ('pairwise_kernels', 1),
#   ('mmap', 1),
#   ('stat', 1),
#   ('atexit', 1),
#   ('distance', 1),
#   ('cStringIO', 1),
#   ('os\r', 1),
#   ('re\r', 1),
#   ('xml', 1),
#   ('parse_path\r', 1),
#   ('load_iris', 1),
#   ('decimal', 1),
#   ('csv', 1),
#   ('listdir', 1),
#   ('<arnaud', 1),
#   ('compatibility', 1),
#   ('generate', 1),
#   ('more', 1),
#   ('posixpath', 1),
#   ('shelve', 1),
#   ('builtins', 1),
#   ('load_files', 1),
#   ('keyword', 1),
#   ('linecache', 1),
#   ('pathlib', 1),
#   ('serve', 1),
#   ('u', 1),
#   ('defaultdict', 1),
#   ('@inria', 1),
#   ('results', 1),
#   ('def', 1),
#   ('@normalesup', 1),
#   ('fundamental', 1),
#   ('heapq', 1),
#   ('assert_raise_message', 1),
#   ('docutils', 1),
#   ('sphinx', 1),
#   ('split_explicit_title', 1),
#   ('coding:', 1),
#   ('pyparsing', 1),
#   ('/mixture/dpgmm', 1),
#   ('<s8wu@uwaterloo', 1),
#   ('V', 1),
#   ('dist_metrics', 1),
#   ('generators\r', 1)],
#  'scipy': [('numpy', 669),
#   ('scipy', 279),
#   ('warnings', 103),
#   ('os', 79),
#   ('sys', 67),
#   ('math', 27),
#   ('re', 24),
#   ('itertools', 22),
#   ('subprocess', 15),
#   ('collections', 15),
#   ('io', 13),
#   ('tempfile', 11),
#   ('time', 10),
#   ('matplotlib', 10),
#   ('threading', 9),
#   ('shutil', 9),
#   ('functools', 9),
#   ('join', 8),
#   ('operator', 8),
#   ('glob', 7),
#   ('inspect', 7),
#   ('distutils', 7),
#   ('nose', 6),
#   ('copy', 6),
#   ('assert_array_almost_equal', 5),
#   ('assert_equal', 4),
#   ('mpmath', 4),
#   ('assert_allclose', 4),
#   ('random', 3),
#   ('ctypes', 3),
#   ('json', 3),
#   ('argparse', 3),
#   ('sympy', 3),
#   ('textwrap', 3),
#   ('assert_', 3),
#   ('sphinx', 3),
#   ('hashlib', 3),
#   ('zlib', 3),
#   ('optparse', 3),
#   ('gc', 3),
#   ('pickle', 3),
#   ('dec', 2),
#   ('unittest', 2),
#   ('tnc', 2),
#   ('contextlib', 2),
#   ('run_module_suite', 2),
#   ('datetime', 2),
#   ('bisect', 2),
#   ('timeit', 2),
#   ('weakref', 2),
#   ('lu_factor', 2),
#   ('struct', 2),
#   ('assert_raises', 1),
#   ('of', 1),
#   ('pathlib', 1),
#   ('gammainc', 1),
#   ('use_solver', 1),
#   ('setup', 1),
#   ('six', 1),
#   ('_root', 1),
#   ('numpy_nodepr_api', 1),
#   ('sysconfig', 1),
#   ('errno', 1),
#   ('if', 1),
#   ('pade', 1),
#   ('cs_graph_components', 1),
#   ('csv', 1),
#   ('convert', 1),
#   ('a', 1),
#   ('functions', 1),
#   ('given', 1),
#   ('importlib', 1),
#   ('assert_array_equal', 1),
#   ('better!', 1),
#   ('build', 1),
#   ('constants', 1),
#   ('norm', 1),
#   ('csr_matrix', 1),
#   ('urllib2', 1),
#   ('documentation', 1),
#   ('getpass', 1),
#   ('svd', 1),
#   ('test_continuous_basic', 1),
#   ('decorator', 1),
#   ('rand', 1),
#   ('newer', 1),
#   ('iterative', 1),
#   ('numbers', 1),
#   ('eig', 1),
#   ('doctest', 1),
#   ('docutils', 1),
#   ('nodes', 1),
#   ('absolute_import', 1),
#   ('directed_hausdorff', 1),
#   ('print_function', 1),
#   ('set_gc_state', 1),
#   ('there:', 1),
#   ('traceback', 1),
#   ('common_tests', 1),
#   ('zipfile', 1),
#   ('lib', 1),
#   ('lstsq', 1),
#   ('paver', 1),
#   ('xrange', 1),
#   ('matfile', 1),
#   ('enthoughtinterpolate', 1),
#   ('one::', 1),
#   ('by', 1),
#   ('heapq', 1),
#   ('to', 1),
#   (':mod:`scipy', 1),
#   ('cpython', 1),
#   ('sin', 1),
#   ('minpack', 1),
#   ('cython', 1),
#   ('libc', 1),
#   ('linear_sum_assignment', 1),
#   ('minpack2', 1),
#   ('decimal', 1)],
#  'service_identity': [('cryptography', 6),
#   ('pytest', 3),
#   ('service_identity', 3),
#   ('re', 3),
#   ('attr', 2),
#   ('warnings', 2),
#   ('pyasn1', 2),
#   ('codecs', 2),
#   ('os', 2),
#   ('sys', 1),
#   ('string', 1),
#   ('OpenSSL', 1),
#   ('load_pem_x509_certificate', 1),
#   ('nicer', 1),
#   ('them', 1),
#   ('__init__', 1),
#   ('load_certificate', 1),
#   ('absolute_import', 1),
#   ('setuptools', 1),
#   ('serve', 1),
#   ('datetime', 1),
#   ('sphinx_rtd_theme', 1)],
#  'setuptools_scm': [('setuptools_scm', 20),
#   ('os', 11),
#   ('sys', 5),
#   ('pytest', 5),
#   ('pkg_resources', 4),
#   ('warnings', 4),
#   ('subprocess', 3),
#   ('datetime', 2),
#   ('tox', 1),
#   ('itertools', 1),
#   ('shlex', 1),
#   ('io', 1),
#   ('platform', 1),
#   ('py', 1),
#   ('print_function', 1),
#   ('setuptools', 1),
#   ('parse_pkginfo', 1),
#   ('re', 1),
#   ('distutils', 1)],
#  'simplejson': [('simplejson', 51),
#   ('unittest', 32),
#   ('sys', 13),
#   ('decimal', 5),
#   ('re', 4),
#   ('textwrap', 3),
#   ('os', 3),
#   ('subprocess', 3),
#   ('http://json', 3),
#   ('urllib', 2),
#   ('operator', 2),
#   ('tempfile', 1),
#   ('test', 1),
#   ('doctest', 1),
#   ('json', 1),
#   ('math', 1),
#   ('setuptools', 1),
#   ('distutils', 1),
#   ('collections', 1),
#   ('make_scanner', 1),
#   ('struct', 1),
#   ('codecs', 1),
#   ('unichr', 1)],
#  'smart_open': [('io', 5),
#   ('os', 4),
#   ('sys', 3),
#   ('logging', 3),
#   ('unittest', 2),
#   ('hashlib', 2),
#   ('mock', 2),
#   ('setuptools', 1),
#   ('smart_open', 1),
#   ('zlib', 1),
#   ('subprocess', 1),
#   ('requests', 1),
#   (')', 1),
#   ('tempfile', 1),
#   ('boto', 1),
#   ('moto', 1),
#   ('responses', 1),
#   ('ssl', 1)],
#  'smhasher': [],
#  'snappy': [],
#  'snowball_py': [('sys', 2),
#   ('re', 2),
#   ('snowballstemmer', 2),
#   ('codecs', 1),
#   ('setuptools', 1),
#   ('setup', 1)],
#  'snuggs': [('collections', 2),
#   ('codecs', 1),
#   ('setuptools', 1),
#   ('functools', 1),
#   ('itertools', 1),
#   ('operator', 1),
#   ('re', 1),
#   ('sys', 1),
#   ('pyparsing', 1),
#   ('numpy', 1),
#   ('pytest', 1),
#   ('snuggs', 1)],
#  'sockjs-tornado': [('sockjs', 32),
#   ('tornado', 18),
#   ('logging', 11),
#   ('sys', 5),
#   ('time', 3),
#   ('socket', 3),
#   ('urllib', 2),
#   ('hashlib', 2),
#   ('random', 2),
#   ('pkgutil', 1),
#   ('os', 1),
#   ('distutils', 1),
#   ('setuptools', 1),
#   ('simplejson', 1),
#   ('multiplex', 1),
#   ('weakref', 1),
#   ('proto', 1),
#   ('urlparse', 1),
#   ('math', 1),
#   ('datetime', 1),
#   ('base', 1),
#   ('heapq', 1),
#   ('collections', 1)],
#  'spyder': [('qtpy', 188),
#   ('spyder', 158),
#   ('os', 113),
#   ('os\r', 51),
#   ('pytest', 50),
#   ('sys\r', 47),
#   ('re\r', 26),
#   ('sys', 18),
#   ('time\r', 14),
#   ('re', 9),
#   ('ipykernel', 8),
#   ('numpy', 7),
#   ('tempfile', 7),
#   ('time', 7),
#   ('shutil', 6),
#   ('mock', 5),
#   ('imp\r', 5),
#   ('distutils', 5),
#   ('traceback\r', 5),
#   ('inspect\r', 5),
#   ('socket\r', 5),
#   ('shutil\r', 5),
#   ('threading\r', 5),
#   ('textwrap', 4),
#   ('codecs', 4),
#   ('errno\r', 4),
#   ('print_function\r', 4),
#   ('collections', 4),
#   ('pickle', 3),
#   ('ast', 3),
#   ('jedi', 3),
#   ('pytestqt', 3),
#   ('qtconsole', 3),
#   ('ctypes', 3),
#   ('flaky', 3),
#   ('rope', 3),
#   ('imp', 3),
#   ('struct\r', 3),
#   ('subprocess\r', 3),
#   ('atexit\r', 3),
#   ('codecs\r', 3),
#   ('locale\r', 3),
#   ('numpy\r', 2),
#   ('unittest', 2),
#   ('io', 2),
#   ('logging', 2),
#   ('traceback', 2),
#   ('socket', 2),
#   ('gettext_helpers', 2),
#   ('operator', 2),
#   ('itertools', 2),
#   ('uuid', 2),
#   ('xml', 2),
#   ('functools', 2),
#   ('imports', 2),
#   ('weakref', 2),
#   ('keyword\r', 2),
#   ('sre_constants\r', 2),
#   ('unicodedata', 2),
#   ('pyx_script', 1),
#   ('guiqwt', 1),
#   ('matplotlib', 1),
#   ('spam', 1),
#   ('dicom', 1),
#   ('mechanism', 1),
#   ('pylab', 1),
#   ('guidata', 1),
#   ('spyder\r', 1),
#   ('operator\r', 1),
#   ('get_module_source_path\r', 1),
#   ('pkgutil\r', 1),
#   ('zipimport', 1),
#   ('random\r', 1),
#   ('json', 1),
#   ('ssl', 1),
#   ('tokenize', 1),
#   ('pygments', 1),
#   ('windll', 1),
#   ('h5py', 1),
#   ('bdb\r', 1),
#   ('io\r', 1),
#   ('pdb\r', 1),
#   ('shlex\r', 1),
#   ('sympy', 1),
#   ('sourcecode', 1),
#   ('setuptools', 1),
#   ('fileinput', 1),
#   ('tarfile\r', 1),
#   ('warnings\r', 1),
#   ('json\r', 1),
#   ('dis', 1),
#   ('pandas', 1),
#   ('tempfile\r', 1),
#   ('winreg', 1),
#   ('zmq', 1),
#   ('errno', 1),
#   ('psutil\r', 1),
#   ('rope\r', 1),
#   ('subprocess', 1),
#   ('ctypes\r', 1),
#   ('pydoc\r', 1),
#   ('code', 1),
#   ('docutils', 1),
#   ('ast\r', 1),
#   ('library', 1),
#   ('inspect', 1),
#   ('in', 1),
#   ('absolute_import', 1),
#   ('string', 1),
#   ('threading', 1),
#   ('getpass', 1),
#   ('functools\r', 1),
#   ('stat\r', 1),
#   ('any', 1),
#   ('datetime\r', 1),
#   ('gc\r', 1),
#   ('uuid\r', 1),
#   ('jupyter_client', 1),
#   ('signal', 1),
#   ('copy', 1),
#   ('glob\r', 1),
#   ('fnmatch\r', 1),
#   ('math\r', 1),
#   ('config', 1),
#   ('division\r', 1),
#   ('optparse', 1),
#   ('math', 1),
#   ('chardet', 1),
#   ('sphinx', 1),
#   ('debug_print', 1),
#   ('weakref\r', 1),
#   ('print_function', 1),
#   ('https://github', 1)],
#  'sqlparse': [('sqlparse', 68),
#   ('pytest', 8),
#   ('re', 5),
#   ('sys', 4),
#   ('io', 2),
#   ('types', 2),
#   ('six:', 1),
#   ('things', 1),
#   ('os', 1),
#   ('itertools', 1),
#   ('collections', 1),
#   ('contextlib', 1),
#   ('setuptools', 1),
#   ('foo;', 1),
#   ('subprocess', 1),
#   ('datetime', 1),
#   ('print_function', 1)],
#  'stripe-python': [('stripe', 96),
#   ('sys', 14),
#   ('os', 8),
#   ('warnings', 7),
#   ('unittest2', 6),
#   ('time', 5),
#   ('datetime', 5),
#   ('mock', 5),
#   ('re', 3),
#   ('urllib', 3),
#   ('distutils', 2),
#   ('logging', 2),
#   ('flask', 2),
#   ('random', 2),
#   ('urlparse', 2),
#   ('copy', 2),
#   ('setuptools', 1),
#   ('hmac', 1),
#   ('tempfile', 1),
#   ('hashlib', 1),
#   ('io', 1),
#   ('calendar', 1),
#   ('platform', 1),
#   ('collections', 1),
#   ('unittest', 1),
#   ('textwrap', 1),
#   ('email', 1),
#   ('urllib2', 1),
#   ('string', 1),
#   ('optparse', 1),
#   ('subprocess', 1),
#   ('pickle', 1)],
#  'sympy': [('sympy', 118),
#   ('os', 6),
#   ('sys', 6),
#   ('*"', 4),
#   ('foo', 4),
#   ('get_sympy', 2),
#   ('sample', 2),
#   ('timeit', 1),
#   ('setuptools', 1),
#   ('all', 1),
#   ('mpmath', 1),
#   ('trigintegrate', 1),
#   ('solve', 1),
#   ('collections', 1),
#   ('correct', 1),
#   ('e', 1),
#   ('tempfile', 1),
#   ('time', 1),
#   ('timed', 1),
#   ('statements', 1),
#   ('subprocess', 1),
#   ('re', 1),
#   ('warnings', 1),
#   ('io', 1),
#   ('range', 1),
#   ('symengine', 1)],
#  'terminado': [('tornado', 7),
#   ('terminado', 5),
#   ('os', 4),
#   ('logging', 3),
#   ('sys', 3),
#   ('tornado_xstatic', 3),
#   ('absolute_import', 2),
#   ('webbrowser', 1),
#   ('urllib', 1),
#   ('urlparse', 1),
#   ('json', 1),
#   ('distutils', 1),
#   ('unittest\r', 1),
#   ('tornado\r', 1),
#   ('collections', 1),
#   ('itertools', 1)],
#  'thinc': [],
#  'traitlets': [('sys', 10),
#   ('os', 8),
#   ('unittest', 7),
#   ('traitlets', 6),
#   ('re', 5),
#   ('six', 4),
#   ('json', 4),
#   ('inspect', 4),
#   ('copy', 4),
#   ('io', 3),
#   ('contextlib', 3),
#   ('warnings', 3),
#   ('logging', 3),
#   ('types', 3),
#   ('pytest', 3),
#   ('functools', 2),
#   ('pickle', 2),
#   ('enum', 2),
#   ('something', 1),
#   ('cast_bytes_py2', 1),
#   ('errno', 1),
#   ('mock', 1),
#   ('subprocess', 1),
#   ('sphinx', 1),
#   ('collections', 1),
#   ('tempfile', 1),
#   ('argparse', 1),
#   ('ast', 1),
#   ('are', 1),
#   ('shlex', 1),
#   ('and', 1),
#   ('ipython_genutils', 1)],
#  'traits': [('traits', 174),
#   ('sys', 29),
#   ('os', 15),
#   ('unittest', 14),
#   ('re', 11),
#   ('threading', 10),
#   ('time', 9),
#   ('contextlib', 7),
#   ('types', 7),
#   ('numpy', 6),
#   ('interface_definition', 5),
#   ('inspect', 5),
#   ('weakref', 5),
#   ('warnings', 5),
#   ('gc', 4),
#   ('copy', 4),
#   ('string', 4),
#   ('line_functions', 4),
#   ('traitsui', 4),
#   ('cPickle', 3),
#   ('interface_implementation', 3),
#   ('shutil', 3),
#   ('tempfile', 3),
#   ('absolute_import', 3),
#   ('abc', 3),
#   ('datetime', 3),
#   ('definition_items', 3),
#   ('logging', 2),
#   ('adapt', 2),
#   ('tokenize', 2),
#   ('sphinx', 2),
#   ('nose', 2),
#   ('lib2to3', 2),
#   ('traceback', 2),
#   ('random', 2),
#   ('thread', 2),
#   ('functools', 2),
#   ('base_doc', 2),
#   ('doctest_tools', 1),
#   ('nose_tools', 1),
#   ('unittest_tools', 1),
#   ('etsconfig', 1),
#   ('manager', 1),
#   ('symbols', 1),
#   ('custom_traithandler', 1),
#   ('doctest', 1),
#   ('token', 1),
#   ('subprocess', 1),
#   ('setuptools', 1),
#   ('subclassing', 1),
#   ('one', 1),
#   ('decimal', 1),
#   ('pyface', 1),
#   ('cython', 1),
#   ('keyword', 1),
#   ('cStringIO', 1),
#   ('register_factory', 1),
#   ('anything', 1),
#   ('this', 1),
#   ('reset_global_adaptation_manager', 1),
#   ('example', 1),
#   ('pprint', 1),
#   ('type-safe', 1),
#   ('pickle', 1),
#   ('heapq', 1),
#   ('itertools', 1),
#   ('a', 1),
#   ('distutils', 1),
#   ('operator', 1),
#   ('copy_reg', 1),
#   ('capwords', 1),
#   ('collections', 1)],
#  'traitsui': [('traits', 356),
#   ('traitsui', 325),
#   ('pyface', 97),
#   ('wx', 90),
#   ('os', 32),
#   ('editor', 26),
#   ('sys', 14),
#   ('numpy', 12),
#   ('absolute_import', 12),
#   ('time', 11),
#   ('random', 9),
#   ('re', 9),
#   ('logging', 9),
#   ('warnings', 7),
#   ('operator', 7),
#   ('threading', 6),
#   ('datetime', 6),
#   ('helper', 6),
#   ('join', 5),
#   ('unittest', 5),
#   ('nose', 5),
#   ('editor_factory', 5),
#   ('contextlib', 4),
#   ('glob', 4),
#   ('math', 4),
#   ('log10', 4),
#   ('matplotlib', 3),
#   ('ui_editor', 3),
#   ('sleep', 3),
#   ('getsize', 3),
#   ('randint', 3),
#   ('webbrowser', 3),
#   ('constants', 3),
#   ('restore_window', 3),
#   ('ui_panel', 3),
#   ('ui_base', 3),
#   ('collections', 3),
#   ('toolkit', 2),
#   ('print_function', 2),
#   ('enable', 2),
#   ('localtime', 2),
#   ('listdir', 2),
#   ('functools', 2),
#   ('issues', 2),
#   ('open_file', 2),
#   ('do_later', 2),
#   ('date_editor', 2),
#   ('cgi', 2),
#   ('string', 2),
#   ('copy', 2),
#   ('animated_gif_editor_26', 1),
#   ('animated_gif_editor_28', 1),
#   ('subprocess', 1),
#   ('setuptools', 1),
#   ('sqrt', 1),
#   ('widgets', 1),
#   ('convert_bitmap', 1),
#   ('this', 1),
#   ('TableEditor', 1),
#   ('traceback', 1),
#   ('cPickle', 1),
#   ('load', 1),
#   ('tables', 1),
#   ('kiva', 1),
#   ('text_editor', 1),
#   ('color_editor', 1),
#   ('init_wx_handlers', 1),
#   ('getcwd', 1),
#   ('history_control', 1),
#   ('pandas', 1),
#   ('evaluate_trait', 1),
#   ('not_none', 1),
#   ('choice', 1),
#   ('row', 1),
#   ('image_slice', 1),
#   ('paint_parent', 1),
#   ('default_theme', 1),
#   ('fill_panel_for_group', 1),
#   ('shutil', 1),
#   ('tempfile', 1),
#   ('invoke', 1),
#   ('colorsys', 1),
#   ('rgb_to_hls', 1),
#   ('reshape', 1),
#   ('escape', 1),
#   ('shelve', 1),
#   ('traits_home', 1),
#   ('inspect', 1),
#   ('types', 1),
#   ('user_name_for', 1),
#   ('token', 1),
#   ('tokenize', 1),
#   ('walk', 1),
#   ('basename', 1),
#   ('various', 1),
#   ('abspath', 1),
#   ('themed_window', 1),
#   ('capwords', 1)],
#  'trollius': [],
#  'vcversioner': [('vcversioner', 3),
#   ('os', 2),
#   ('setuptools', 1),
#   ('collections', 1),
#   ('subprocess', 1),
#   ('warnings', 1),
#   ('sys', 1),
#   ('vcversioner;', 1),
#   ('pytest', 1)],
#  'w3lib': [('w3lib', 9),
#   ('six', 8),
#   ('unittest', 5),
#   ('warnings', 4),
#   ('collections', 3),
#   ('re', 3),
#   ('base64', 2),
#   ('os', 2),
#   ('cStringIO', 1),
#   ('io', 1),
#   ('setuptools', 1),
#   ('codecs', 1),
#   ('posixpath', 1),
#   ('sys', 1)],
#  'waitress': [('waitress', 27),
#   ('os', 12),
#   ('unittest', 10),
#   ('sys', 8),
#   ('socket', 8),
#   ('time', 7),
#   ('io', 5),
#   ('asyncore', 4),
#   ('errno', 4),
#   ('logging', 3),
#   ('re', 3),
#   ('threading', 3),
#   ('urllib', 2),
#   ('unittest2', 2),
#   ('getopt', 2),
#   ('urllib2', 1),
#   ('types', 1),
#   ('platform', 1),
#   ('warnings', 1),
#   ('urlparse', 1),
#   ('contextlib', 1),
#   ('profile', 1),
#   ('stat', 1),
#   ('calendar', 1),
#   ('setuptools', 1),
#   ('traceback', 1),
#   ('find_double_newline', 1),
#   ('multiprocessing', 1),
#   ('string', 1),
#   ('subprocess', 1),
#   ('pkg_resources', 1),
#   ('pylons_sphinx_themes', 1),
#   ('tempfile', 1)],
#  'wcwidth': [('unicodedata', 2),
#   ('wcwidth', 2),
#   ('setuptools', 2),
#   ('ctypes', 1),
#   ('warnings', 1),
#   ('locale', 1),
#   ('sys', 1),
#   ('os', 1),
#   ('urllib2', 1),
#   ('functools', 1),
#   ('coding:', 1)],
#  'win-unicode-console': [('ctypes', 11),
#   ('sys', 7),
#   ('io', 3),
#   ('traceback', 2),
#   ('win_unicode_console', 1),
#   ('runner', 1),
#   ('platform', 1),
#   ('raw_input', 1),
#   ('unicode_argv', 1),
#   ('os', 1),
#   ('setuptools', 1),
#   ('code', 1),
#   ('warnings', 1),
#   ('argparse', 1),
#   ('tokenize', 1),
#   ('types', 1),
#   ('time', 1),
#   ('codecs', 1),
#   ('re', 1)],
#  'workerpool': [('workerpool', 12),
#   ('six', 6),
#   ('sys', 4),
#   ('os', 2),
#   ('glob', 2),
#   ('unittest', 2),
#   ('pep8', 1),
#   ('pyflakes', 1),
#   ('time', 1),
#   ('boto', 1),
#   ('threading', 1),
#   ('setuptools', 1)],
#  'wrapt': [('wrapt', 33),
#   ('unittest', 21),
#   ('inspect', 13),
#   ('compat', 13),
#   ('imp', 11),
#   ('sys', 11),
#   ('distutils', 4),
#   ('threading', 2),
#   ('operator', 2),
#   ('hook', 1),
#   ('pytest', 1),
#   ('os', 1),
#   ('decorator', 1),
#   ('gc', 1),
#   ('builtins', 1),
#   ('functools', 1),
#   ('weakref', 1),
#   ('sphinx_rtd_theme', 1)],
#  'zict': [('zict', 8),
#   ('os', 7),
#   ('sys', 5),
#   ('collections', 5),
#   ('pytest', 4),
#   ('shutil', 2),
#   ('urllib', 2),
#   ('zipfile', 2),
#   ('itertools', 2),
#   ('gc', 1),
#   ('tempfile', 1),
#   ('setuptools', 1),
#   ('errno', 1),
#   ('random', 1),
#   ('string', 1),
#   ('heapdict', 1)]}

# %% [markdown]
# ### 1.3. Formata o arquivo csv que será carregado no Gephi

# %% [markdown]
# Gera as matriz utilizada no grapho

# %% [markdown]
# Obtém toda a relação de pacotes: dependentes (pais) e depedencias (filhos).
#
# Foi utilizado esse nome devido a a releção hierárquica dentro do dicionário. Essa nomeclatura poderia ser melhorada.

# %%
#obtém o conjunto de todos os pacotes-pai (dependetes)
pacotes_pai = set(pacote_pacote.keys())
print(pacotes_pai)
# Out:
# {'clyent', 'colorama', 'patsy', 'multipledispatch', 'html5lib-python', 'feedparser', 'pyopenssl', 'nb_conda_kernels', 'pandas-datareader', 'conda-verify', 'partd', 'conda/wiki/VC-features', 'cytoolz', 'luigi', 'ConfigArgParse', 'qtpy', 'appnope', 'apptools', 'pyserial', 'scipy', 'azure-sdk-for-python', 'traitsui', 'wrapt', 'queuelib', 'rasterio', 'keyring', 'petl', 'PyTd', 'flask-login', 'bleach', 'libconda', 'PyMySQL', 'pystan', 'CVXcanon', 'traits', 'path.py', 'python-unicodecsv', 'responses', 'XlsxWriter', 'thinc', 'PyHive', 'constantly', 'colander', 'kerberos-sspi', 'smart_open', 'anaconda-clean', 'ipywidgets', 'redis-py', 'nb_anacondacloud', 'stripe-python', 'win-unicode-console', 'greenlet', 'runipy', 'cachecontrol', 'backports.shutil_get_terminal_size', 'wcwidth', 'constructor', 'pyface', 'pytest-cov', 'numpy', 'pandas', 'cloudpickle', 'hs2client', 'trollius', 'traitlets', 'numexpr', 'qtawesome', 'more-itertools', 'numpydoc', 'Shapely', 'rope', 'scikit-image', 'requests-kerberos', 'requests-file', 'python-prompt-toolkit', 'simplejson', 'munch', 'spyder', 'cligj', 'bitarray', 'nbpresent', 'pymc', 'appdirs', 's3transfer', 'locket.py', 'psutil', 'qgrid', 'neon', 'python-lazy-object-proxy', 'preshed', 'ptyprocess', 'incremental', 'natsort', 'bcrypt', 'pivottablejs', 'boto', 'python-tblib', 'setuptools_scm', 'sympy', 'mistune', 'snuggs', 'datashader', 'chest', 'pickleshare', 'cookies', 'python-ecdsa', 'sqlparse', 'conda-build', 'bsdiff4', 'w3lib', 'datrie', 'anaconda-project', 'service_identity', 'line_profiler', 'impyla', 'entrypoints', 'parsel', 'zict', 'mongo-python-driver', 'imagesize_py', 'nb_conda', 'meld3', 'cymem', 'flask-wtf', 'waitress', 'plotly.py', 'Fiona', 'chardet', 'colorcet', 'smhasher', 'python-lz4', 'menuinst', 'bottlechest', 'flask-cors', 'snappy', 'sockjs-tornado', 'workerpool', 'pyzmq', 'snowball_py', 'pycosat', 'vcversioner', 'cached-property', 'fastcache', 'terminado', 'python-semver', 'pandasql', 'idna', 'pykerberos', 'click-plugins', 'ldap3', 'pycparser', 'jdcal', 'bz2file', 'affine', 'anaconda-verify', 'python-semanticversion', 'isort', 'mkl-service', 'scikit-learn', 'inflection'}

# %%
#obtém o conjunto de pacotes filhos (dependencias)
pacotes_filhos = []

for pai in pacote_pacote:
    for filho in pacote_pacote[pai]:
        pacotes_filhos.append(filho[0])

pacotes_filhos = set(pacotes_filhos)

print(len(pacotes_filhos))
print(pacotes_filhos)
# Out:
# 1236
# {'abstract_type_system', 'sha', 'clyent', 'os', 'filtering_handler', 'time\r', 'trait_dict_context_adapter', 'read_config', 'use_solver', 'coding:', 'multipledispatch', 'object', 'urlparse', ':`grid_search`', 'read_configuration', 'do_later', 'match_template', 'intranges_from_list', 'partd', 'gzip', 'alloc_hook', 'UTS46', 'your', 'msrest', 'pkg1', 'pyhive', 'build', 'nodes', 'open_file', 'pyfits', 'escape_bytes', 'SGETask', 'evaluate_trait', 'scipy', 'http://json', 'basename', 'msgpack', 'traitsui', 'provides', 'win32security', 'binarization', ':mod:`scipy', 'json', 'prompt_toolkit', 'assert_raises', 'abstract_adapter_factory', 'weakref\r', 'gen_backend', 'manager', 'contrib', 'fields', 'convert', 'build_control', 'anaconda_project', 'uuid', 'readline', 'iso8601', 'json\r', 'path_for', 'kernprof', 'difflib', 'collections\r', 'load_breast_cancer', 'minpack', 'login_action', 'winreg', 'cryptography', 'exception', 'make_blobs', 'csr_matrix', 'for', 'pdb', 'webencodings', 'local', 'help_doc', 'list_context_adapter', 'pyparsing', 'next', 'coding=utf-8', 'imutable_template', 'naming_node_manager', 'stentseg', 'mysql', 'greenlet', 'base_doc', 'httplib2', 'spectral_clustering', 'dis', 'ipykernel', 'snowballstemmer', 'profile', 'round', 'listdir', 'type-safe', 'pipes', 'pandas', 'pdb\r', 'markupsafe', 'grids', 'integer_types', 'convolve2d', 'there:', 'layer1', 'combobox_focus_handler', 'tables', 'adapt', 'raw_input', 'proposal_layer_ref', 's3fs', 'documentation', 'sys\r', 'iterative', 'comports', 'gridfs', 'package_globals', 'future', 'connect', 'something', 'pypi', 'one', 'request', 'print_tokens', 'load_iris', 'date_editor', 'rgb2gray', 'subprocess', 'itertools', 'cssselect', 'interface_definition', 'proto', 'join', 'tempfile', 'arange', 'asyncore', 'help_plugin', '<alexandre', 'change', 'naming_manager', 'python', 'one::', 'url_pat', 'certifi', 'binascii', 'socket\r', 'yapf', 'get_ident', 'bitarray', 'nbpresent', 'ref', 'io\r', 'bilingual', 'pysftp', 'salmon', 'b', 'adapter_manager', 'libutils', 's3transfer', 'dict_context_adapter_factory', 'threading', 'calendar', 'setup_atomic_replace', 'nbconvert', 'object_serializer', 'sklearn', 'System', 'load_files', 'zipfile', 'incremental', 'i_help_doc', 'clint', 'mimetypes', 'pkg_resources', 'pwd', 'gssapi', 'select', 'enaml_panes', 'codecs', 'parse_path', 'babel', "gdal'", 'composite', 'importlib', 'object_hook', 'test_groupby', 'maxStalenessSeconds', 'enthoughtinterpolate', 'slow', 'period', 'perf', 'correct', 'floatint', 'distance', 'check_skip_network', 'hmac', 'serial', 'line_functions', 'Magic', 'install', 'tree_item', 'datrie', 'fundamental', 'osgeo', 'service_identity', 'urllib3', 'dec', 'warnings\r', 'cast_bytes_py2', 'nicer', 'heapq', 'entrypoints', 'animated_gif_editor_26', 'logging', 'flask', 'pylab', 'pymysql', 'sqlite3', 'this', 'print_function', 'noarch_test_package', 'requests_ftp', 'imghdr', 'getpass', 'proxy_server', 'testing', 'monotime', 'unicodedata', 'results', 'flask_babel', 'host_subplot', 'choice', 'vincent', 'shutil', 'context_test_case', 'persistent', 'llvm', 'run', 'directed_hausdorff', 'list_ports_common', 'optparse', 'adapter_base', 'help_code', 'contributors', 'wsgiref', 'astor', 'profile_line', 'pade', 'restore_window', 'tty', 'ipaddress', 'permissions', 'bdb\r', 'chardet', 'numpy_api', 'any', 'flask_wtf', 'kate', 'teradata', 'create_scriptable_type', 'flask_babelex', 'codeop', 'iterate', 'badsyntax', 'ipython_genutils', 'stringprep', 'cProfile', 'sys', 'example_task', 'profiling', 'editdistance', 'xrange', 'solve', 'array', 'spur', 'trait_list_context_adapter', 'token', 'certgen', 'example', 'os\r', 'plex', 'vcversioner;', 'script_manager', 'time', 'numpy_nodepr_api', 'jdcal', 'string_types', 'doc_action', 'envisage', 'ctypes', 'load_key_bindings_for_prompt', 'pylint:', 'requests_kerberos', 'split_explicit_title', 'atexit', 'until', 'enaml_task', 'getdata', 'pyflakes', 'unicode_argv', 'semver', 'dict_context_adapter', 'all_names', 'smtplib', 'ifftshift', 'tr ...

# %% [markdown]
# Mergea pais e filhos para termos todos os nós

# %%
pacotes_total = pacotes_pai.union(pacotes_filhos)

# %%
pacotes_total2 = list(pacotes_total)
pacotes_total2.sort()
pacotes_total2
# Out:
# ['""":func:`~pandas',
#  '"wtforms',
#  "(r'",
#  ')',
#  '*"',
#  '/kddcup99-mld/kddcup',
#  '/licenses/>',
#  '/licenses/BSD-3-Clause',
#  '/mixture/dpgmm',
#  '/test_layer',
#  '://github',
#  '://pyserial',
#  '://www',
#  ':`grid_search`',
#  ':mod:`scipy',
#  '<alexandre',
#  '<arnaud',
#  '<s8wu@uwaterloo',
#  '@inria',
#  '@normalesup',
#  'AWS',
#  'CVXcanon',
#  'ConfigArgParse',
#  'Crypto',
#  'Cython',
#  'Distribution',
#  'Fiona',
#  'GCS',
#  'IPython',
#  'Interface',
#  'License',
#  'Magic',
#  'Numeric',
#  'Oct',
#  'OpenSSL',
#  'PyHive',
#  'PyMySQL',
#  'PyQt4',
#  'PyQt5',
#  'PySide',
#  'PySide2',
#  'PyTd',
#  'Pyro',
#  'SGETask',
#  'SOFTWARE',
#  'SONManipulators',
#  'Shapely',
#  'System',
#  'TableEditor',
#  'UTS46',
#  'V',
#  'XlsxWriter',
#  '__init__',
#  '_root',
#  '_version',
#  '`',
#  '``PyQt5',
#  '`sys',
#  '`tornado',
#  'a',
#  'a2b_hex',
#  'abc',
#  'absolute_import',
#  'abspath',
#  'abstract_adapter_factory',
#  'abstract_factory',
#  'abstract_type_system',
#  'action',
#  'actions',
#  'adapt',
#  'adaptable',
#  'adapter_base',
#  'adapter_manager',
#  'add_parser_json',
#  'adding',
#  'address',
#  'adjusted_rand_score',
#  'aeon',
#  'affine',
#  'affinity_propagation',
#  'again',
#  'all',
#  'all_names',
#  'alloc_hook',
#  'an',
#  'anaconda-clean',
#  'anaconda-project',
#  'anaconda-verify',
#  'anaconda_project',
#  'anaconda_verify',
#  'and',
#  'animated_gif_editor_26',
#  'animated_gif_editor_28',
#  'any',
#  'any_context_data_name_item',
#  'any_data_name_item',
#  'anything',
#  'api',
#  'apigen',
#  'appdirs',
#  'appnope',
#  'apptools',
#  'arange',
#  'are',
#  'argparse',
#  'array',
#  'arrow',
#  'assert_',
#  'assert_allclose',
#  'assert_array_almost_equal',
#  'assert_array_equal',
#  'assert_equal',
#  'assert_greater',
#  'assert_raise_message',
#  'assert_raises',
#  'assert_series_equal',
#  'ast',
#  'ast\r',
#  'astor',
#  'astropy',
#  'asyncio',
#  'asyncore',
#  'atexit',
#  'atexit\r',
#  'attr',
#  'authentication',
#  'auxlib',
#  'azure-sdk-for-python',
#  'b',
#  'babel',
#  'backports',
#  'backports.shutil_get_terminal_size',
#  'badmodule',
#  'badsyntax',
#  'base',
#  'base64',
#  'base_doc',
#  'basedevice',
#  'basename',
#  'bcrypt',
#  'bdb',
#  'bdb\r',
#  'bdist_mpkg',
#  'because',
#  'being',
#  'below:',
#  'bench_oneshot',
#  'better!',
#  'between',
#  'bilingual',
#  'binarization',
#  'binascii',
#  'bind_event',
#  'binding',
#  'binstar_client',
#  'bisect',
#  'bitarray',
#  'bleach',
#  'bokeh',
#  'boto',
#  'boto3',
#  'botocore',
#  'bottlechest',
#  'bs4',
#  'bsdiff4',
#  'bson',
#  'build',
#  'build_control',
#  'build_data_train',
#  'build_url',
#  'buildutils',
#  'builtins',
#  'bundled',
#  'by',
#  'bz2',
#  'bz2file',
#  'cPickle',
#  'cProfile',
#  'cStringIO',
#  'c_parser',
#  'cachecontrol',
#  'cached-property',
#  'cached_property',
#  'calendar',
#  'can',
#  'canny',
#  'capwords',
#  'cast_bytes_py2',
#  'cdecimal',
#  'certgen',
#  'certifi',
#  'cffi',
#  'cgi',
#  'change',
#  'chardet',
#  'check_skip_network',
#  'cherrypy',
#  'chest',
#  'choice',
#  'clapack_scrub',
#  'class_doc',
#  'classes',
#  'classification',
#  'click',
#  'click-plugins',
#  'click_plugins',
#  'cligj',
#  'clint',
#  'cloudpickle',
#  'clyent',
#  'code',
#  'code_assist',
#  'code_generators',
#  'codecs',
#  'codecs\r',
#  'codeop',
#  'codetools',
#  'coding:',
#  'coding=utf-8',
#  'colander',
#  'collection',
#  'collections',
#  'collections\r',
#  'color_editor',
#  'color_view',
#  'colorama',
#  'colorcet',
#  'colorcet;',
#  'colorsys',
#  'combobox_focus_handler',
#  'command',
#  'commands',
#  'common',
#  'common_tests',
#  'compat',
#  'compatibility',
#  'compiler',
#  'comports',
#  'composite',
#  'concat',
#  'concurrent',
#  'conda',
#  'conda-build',
#  'conda-verify',
#  'conda/wiki/VC-features',
#  'conda_build',
#  'conda_build_test',
#  'conda_env',
#  'conda_verify',
#  'conf',
#  'config',
#  'configargparse',
#  'configparser',
#  'configuration',
#  'connect',
#  'constant_names',
#  'constantly',
#  'constants',
#  'constructor',
#  'constructor/__init__',
#  'context',
#  'context_data_name_item',
#  'context_monitor',
#  'context_node_type',
#  'context_test_case',
#  'contextlib',
#  'contextmanager',
#  'contrib',
#  'contributors',
#  'convert',
#  'convert_bitmap',
#  'convert_xml_to_json',
#  'convex_hull_image',
#  'convolve2d',
#  'cookies',
#  'copy',
#  'copy_reg',
#  'copyreg',
#  'correct',
#  'count',
#  'coverage',
#  'cpuinfo',
#  'cpython',
#  'create_hit_external',
#  'create_hit_test',
#  'create_hit_with_qualifications',
#  'create_scriptable_type',
#  'cross_origin',
#  'cryptography',
#  'cs_graph_components',
#  'csr_matrix',
#  'cssselect',
#  'csv',
#  'ctypes',
#  'ctypes\r',
#  'currently',
#  'curses',
#  'custom_traithandler',
#  'cvxpy',
#  'cymem',
#  'cython',
#  'cythonize',
#  'cytoolz',
#  'dask',
#  'data',
#  'dataproc',
#  'datashader',
#  'datashader;',
#  'datashape',
#  'date_editor',
#  'datetime',
#  'datetime\r',
#  'dateutil',
#  'datrie',
#  'debug_print',
#  'dec',
#  'decimal',
#  'decorator',
#  'def',
#  'default_theme',
#  'defaultdict',
#  'definition_items',
#  'definitions',
#  'deque',
#  'descartes',
#  'dev_skip_test',
#  'dicom',
#  'dict_context_adapter',
#  'dict_context_adapter_factory',
#  'difflib',
#  'directed_hausdorff',
#  'dirname',
#  'dis',
#  'disaster_model',
#  'dissolving',
#  'dist_metrics',
#  'distance',
#  'distutils',
#  'division\r',
#  'django',
#  'do_later',
#  'doc_action',
#  'dock_pane',
#  'dock_sizer',
#  'docscrape',
#  'docscrape_sphinx',
#  'doctest',
#  'doctest\r',
#  'doctest_tools',
#  'documentation',
#  'docutils',
#  'download',
#  'download_sample_data',
#  'dump',
#  'dynamize_value',
#  'e',
#  'ecdsa',
#  'editdistance',
#  'editor',
#  'editor_factory',
#  'egg_info',
#  'eig',
#  'elasticsearch',
#  'email',
#  'enable',
#  'enaml',
#  'enaml_decl_doc',
#  'enaml_panes',
#  'enaml_task',
#  'enthought_sphinx_theme',
#  'enthoughtinterpolate',
#  'entrypoints',
#  'enum',
#  'envisage',
#  'eq_',
#  'errno',
#  'errno\r',
#  'error',
#  'escape',
#  'escape_bytes',
#  'etree',
#  'etsconfig',
#  'evaluate',
#  'evaluate_trait',
#  'everything',
#  'example',
#  'example_script_window',
#  'example_task',
#  'example_workbench',
#  'example_workbench_window',
#  'exception',
#  'exceptions',
#  'exists',
#  'expected_warnings',
#  'explorer',
#  'extensions',
#  'ez_setup',
#  'fabric',
#  'fabtools',
#  'factorize',
#  'fails',
#  'falcon',
#  'fastcache',
#  'fcntl',
#  'features',
#  'feedparser',
#  'fields',
#  'figures',
#  'file',
#  'fileinput',
#  'filelock',
#  'fill_panel_for_group',
#  'filtering_handler',
#  'find_boundaries',
#  'find_class',
#  'find_double_newline',
#  'find_window_for_buffer_name',
#  'fiona',
#  'fixpath',
#  'flake8:',
#  'flaky',
#  'flask',
#  'flask-cors',
#  'flask-login',
#  'flask-wtf',
#  'flask_babel',
#  'flask_babelex',
#  'flask_cors',
#  'flask_wtf',
#  'flaskr',
#  'floatint',
#  'fnmatch',
#  'fnmatch\r',
#  'foo',
#  'foo;',
#  'for',
#  'format_time',
#  'fortran',
#  'fractions',
#  'freezegun',
#  'from_url',
#  'ftplib',
#  'full_version',
#  'function_doc',
#  'functions',
#  'functionutils',
#  'functools',
#  'functools\r',
#  'fundamental',
#  'future',
#  'gabor_kernel',
#  'gammainc',
#  'gc',
#  'gc\r',
#  "gdal'",
#  'gen_backend',
#  'genapi',
#  'generate',
#  'generate_anchors',
#  'generators\r',
#  'generic',
#  'genericpath',
#  'genshi',
#  'get_bad_seq',
#  'get_ident',
#  'get_module_source_path\r',
#  'get_oanda_currency_historical_rates',
#  'get_permissions_manager',
#  'get_source_line',
#  'get_sympy',
#  'get_terminal_size',
#  'get_test_subprocess',
#  'getargspec',
#  'getcwd',
#  'getdata',
#  'getopt',
#  'getpass',
#  'getsize',
#  'gettext_helpers',
#  'gevent',
#  'ghost',
#  'git',
#  'github',
#  'given',
#  'glob',
#  'glob\r',
#  'googleapiclient',
#  'grad_funcs',
#  'graph',
#  'graph_objs',
#  'greenlet',
#  'gridfs',
#  'grids',
#  'gssapi',
#  'gtk',
#  'guid',
#  'guidata',
#  'guiqwt',
#  'gunicorn',
#  'gzip',
#  'h5py',
#  'ha_tools',
#  'hashlib',
#  'hdfs',
#  'heapdict',
#  'heapq',
#  'help_code',
#  'help_doc',
#  'help_plugin',
#  'helper',
#  'helpers',
#  'hiredis',
#  'history_control',
#  'hmac',
#  'hook',
#  'host_subplot',
#  'hs2client',
#  'html',
#  'html5lib',
#  'html5lib-python',
#  'htmlentitydefs',
#  'http',
#  'http://json',
#  'http://www',
#  'httplib',
#  'httplib2',
#  'httpretty',
#  'https',
#  'https://github',
#  'huffman',
#  'huge_testman',
#  'hypothesis',
#  'i_bind_event',
#  'i_help_code',
#  'i_help_doc',
#  'i_policy_manager',
#  'i_policy_storage',
#  'i_preferences_page',
#  'i_script_manager',
#  'i_user',
#  'i_user_database',
#  'i_user_manager',
#  'i_user_storage',
#  'idna',
#  'idockable',
#  'if',
#  'ifftshift',
#  'image_slice',
#  'imageio',
#  'images',
#  'imagesize',
#  'imagesize_py',
#  'imghdr',
#  'imp',
#  'imp\r',
#  'impala',
#  'import_module',
#  'importlib',
#  'imports',
#  'impyla',
#  'imread',
#  'imutable_template',
#  'in',
#  'increasing',
#  'incremental',
#  'independent',
#  'inflection',
#  'init_wx_handlers',
#  'initial_context_factory',
#  'initialize_logging',
#  'input',
#  'inspect',
#  'inspect\r',
#  'install',
#  'install_headers',
#  'instance_context_adapter',
#  'integer_types',
#  'interactive_shell',
#  'interface_definition',
#  'interface_implementation',
#  'intranges_from_list',
#  'invoke',
#  'io',
#  'io\r',
#  'ioloop',
#  'ipaddress',
#  'ipykernel',
#  'ipython_genutils',
#  'ipywidgets',
#  'iso8601',
#  'isort',
#  'issues',
#  'it',
#  'itemplate',
#  'itemplate_choice',
#  'itemplate_data_context',
#  'itemplate_data_source',
#  'iterate',
#  'iterative',
#  'iteritems',
#  'itertools',
#  'itsdangerous',
#  'jcal2jd',
#  'jdcal',
#  'jedi',
#  'jiffies',
#  'jinja2',
#  'join',
#  'join_segmentations',
#  'json',
#  'json\r',
#  'jsonrpclib',
#  'jupyter_client',
#  'kate',
#  'kerberos',
#  'kerberos-sspi',
#  'kerberos_sspi',
#  'kernprof',
#  'keyring',
#  'keyword',
#  'keyword\r',
#  'kiva',
#  'la',
#  'language',
#  'layer1',
#  'ldap3',
#  'lgeos',
#  'lib',
#  'lib2to3',
#  'libc',
#  'libconda',
#  'library',
#  'libutils',
#  'line_functions',
#  'line_profiler',
#  'linear_sum_assignment',
#  'linecache',
#  'list_context_adapter',
#  'list_ports_common',
#  'listdir',
#  'llvm',
#  'load',
#  'load_breast_cancer',
#  'load_certificate',
#  'load_files',
#  'load_iris',
#  'load_key_bindings_for_prompt',
#  'load_pem_x509_certificate',
#  'load_project',
#  'loads',
#  'local',
#  'locale',
#  'locale\r',
#  'locally_linear_embedding',
#  'localtime',
#  'locket',
#  'locket.py',
#  'log10',
#  'log_point',
#  'logger',
#  'logging',
#  'logic',
#  'login_action',
#  'logout_action',
#  'long',
#  'lru_cache',
#  'lstsq',
#  'lu_factor',
#  'luigi',
#  'lxml',
#  'lz4',
#  'lz4")',
#  'main_group',
#  'make_blobs',
#  'make_classification',
#  'make_scanner',
#  'manager',
#  'map',
#  'markupsafe',
#  'marshal',
#  'match_template',
#  'matern',
#  'matfile',
#  'math',
#  'math\r',
#  'matplotlib',
#  'matrix',
#  'maxStalenessSeconds',
#  'md5',
#  'mechanism',
#  'meld3',
#  'menuinst',
#  'might',
#  'mimetypes',
#  'minicluster',
#  'minpack',
#  'minpack2',
#  'miscellaneous',
#  'mistune',
#  'mkdtemp',
#  'mkl',
#  'mkl-service',
#  'mmap',
#  'mock',
#  'model',
#  'models',
#  'module',
#  'moment_plots',
#  'mongo-python-driver',
#  'monitor',
#  'monotime',
#  'monotonic',
#  'more',
#  'more-itertools',
#  'more_itertools',
#  'moto',
#  'mpl',
#  'mpl_toolkits',
#  'mpmath',
#  'msgpack',
#  'msrest',
#  'msvcrt',
#  'multipledispatch',
#  'multiplex',
#  'multiprocessing',
#  'munch',
#  'my_build_ext',
#  'mylib',
#  'mysql',
#  'naming_manager',
#  'naming_node_manager',
#  'naming_traits',
#  'naming_tree',
#  'naming_tree_model',
#  'natsort',
#  'nb_anacondacloud',
#  'nb_conda',
#  'nb_conda_kernels',
#  'nbbrowserpdf',
#  'nbconvert',
#  'nbformat',
#  'nbpresent',
#  'ndarray',
#  'neon',
#  'networkx',
#  'new',
#  'newer',
#  'next',
#  'nicer',
#  'noarch_python_test_package',
#  'noarch_test_package',
#  'nodes',
#  'norm',
#  'nose',
#  'nose_tools',
#  'not_none',
#  'notebook',
#  'notify',
#  'ntpath',
#  'null_handler',
#  'numba',
#  'numbers',
#  'numexpr',
#  'numpy',
#  'numpy\r',
#  'numpy_api',
#  'numpy_nodepr_api',
#  'numpydoc',
#  'oauth2client',
#  'object',
#  'object_factory',
#  'object_hook',
#  'object_serializer',
#  'objectlocalization',
#  'objects',
#  'occurrences',
#  'odo',
#  'of',
#  'on',
#  'on_win',
#  'one',
#  'one::',
#  'opcode',
#  'open_file',
#  'openpyxl',
#  'operation',
#  'operator',
#  'operator\r',
#  'option',
#  'optparse',
#  'or',
#  'order',
#  'ordereddict',
#  'os',
#  'os\r',
#  'osgeo',
#  'other',
#  'ourselves',
#  'package_globals',
#  'packaging',
#  'pade',
#  'paint_parent',
#  'pairwise_kernels',
#  'pandas',
#  'pandas-datareader',
#  'pandas_datareader',
#  'pandas_gbq',
#  'pandasql',
#  'paramiko',
#  'parent_path',
#  'parse_path',
#  'parse_path\r',
#  'parse_pkginfo',
#  'parsel',
#  'partd',
#  'past',
#  'path',
#  'path.py',
#  'path_for',
#  'pathlib',
#  'patsy',
#  'paver',
#  'pdb',
#  'pdb\r',
#  'pdb;',
#  'pdb;pdb',
#  'pep8',
#  'perf',
#  'perfect',
#  'period',
#  'permission',
#  'permissions',
#  'persistent',
#  'petl',
#  'petl;',
#  'pickle',
#  'pickle\r',
#  'pickleshare',
#  'pip',
#  'pipes',
#  'pivottablejs',
#  'pkg1',
#  'pkg2',
#  'pkg_resources',
#  'pkgutil',
#  'pkgutil\r',
#  'place',
#  'platform',
#  'plex',
#  'plistlib',
#  'plotly',
#  'plotly.py',
#  'pluggy',
#  'posixpath',
#  'pprint',
#  'pprint_thing',
#  'preferences_manager',
#  'preferences_page',
#  'preshed',
#  'print_function',
#  'print_function\r',
#  'print_tokens',
#  'profile',
#  'profile_line',
#  'profiling',
#  'prompt_toolkit',
#  'properties',
#  'propget',
#  'proposal_layer_ref',
#  'proto',
#  'provides',
#  'proxy_server',
#  'psutil',
#  'psutil\r',
#  'psycopg2',
#  'pty',
#  'ptyprocess',
#  'puresasl',
#  'pwd',
#  'py',
#  'py2exe',
#  'pyasn1',
#  'pycosat',
#  'pycparser',
#  'pycuda',
#  'pydoc',
#  'pydoc\r',
#  'pydot',
#  'pyface',
#  'pyfits',
#  'pyflakes',
#  'pyfs_context',
#  'pygments',
#  'pyhive',
#  'pykerberos',
#  'pykube',
#  'pylab',
#  'pylama',
#  'pylint:',
#  'pylons_sphinx_themes',
#  'pymc',
#  'pymongo',
#  'pymysql',
#  'pyopenssl',
#  'pyparsing',
#  'pyperclip',
#  'pypi',
#  'pyproj',
#  'pyserial',
#  'pysftp',
#  'pystan',
#  'pytest',
#  'pytest-cov',
#  'pytestqt',
#  'python',
#  'python-ecdsa',
#  'python-lazy-object-proxy',
#  'python-lz4',
#  'python-prompt-toolkit',
#  'python-semanticversion',
#  'python-semver',
#  'python-tblib',
#  'python-unicodecsv',
#  'python3',
#  'python_editor_wx',
#  'pytz',
#  'pywintypes',
#  'pyx_script',
#  'pyzmq',
#  'qgrid',
#  'qtawesome',
#  'qtconsole',
#  'qtpy',
#  'queue',
#  'queuelib',
#  'r2_score',
#  'raise_build_error',
#  'rand',
#  'randint',
#  'random',
#  'random\r',
#  'rands',
#  'range',
#  'rasterio',
#  'raw_input',
#  're',
#  're\r',
#  'read_config',
#  'read_configuration',
#  'readline',
#  'redis',
#  'redis-py',
#  'ref',
#  'reference',
#  'referenceable',
#  'referrals_to_list',
#  'register',
#  'register_factory',
#  'relativedelta',
#  'replica_set_connection',
#  'request',
#  'requests',
#  'requests-file',
#  'requests-kerberos',
#  'requests_file',
#  'requests_ftp',
#  'requests_kerberos',
#  'reset_global_adaptation_manager',
#  'reshape',
#  'resize',
#  'resource',
#  'responses',
#  'restore_window',
#  'results',
#  'rfc822',
#  'rgb2gray',
#  'rgb_to_hls',
#  'ring_buffer',
#  'rm_rf',
#  'root',
#  'rope',
#  'rope\r',
#  'ropetest',
#  'round',
#  'row',
#  'rs_or_single_client_noauth',
#  'ruamel_yaml',
#  'run',
#  'run_module_suite',
#  'runipy',
#  'runner',
#  's3fs',
#  's3transfer',
#  'safe_rdn',
#  'salmon',
#  'salmon_sampler',
#  'sample',
#  'scheduler_api_test',
#  'scikit-image',
#  'scikit-learn',
#  ...]

# %%
indice = list(range(0,len(pacotes_total2)))

# %%
len(indice)
# Out:
# 1302

# %% [markdown]
# Formatação dos dados para o formato que o Gephi recebe.
#
# O Gephi precisa de duas bases diferentes:
#
# 1) Relação dos nós (nodes)
#
# 2) Relação das arestas (edges)

# %%
#cria os nodes:
db_nodes = pd.DataFrame({'ID' : indice, 'Label' : pacotes_total2})
db_nodes
# Out:
#         ID                       Label
# 0        0           """:func:`~pandas
# 1        1                    "wtforms
# 2        2                         (r'
# 3        3                           )
# 4        4                          *"
# 5        5        /kddcup99-mld/kddcup
# 6        6                 /licenses/>
# 7        7      /licenses/BSD-3-Clause
# 8        8              /mixture/dpgmm
# 9        9                 /test_layer
# 10      10                   ://github
# 11      11                 ://pyserial
# 12      12                      ://www
# 13      13              :`grid_search`
# 14      14                 :mod:`scipy
# 15      15                  <alexandre
# 16      16                     <arnaud
# 17      17             <s8wu@uwaterloo
# 18      18                      @inria
# 19      19                 @normalesup
# 20      20                         AWS
# 21      21                    CVXcanon
# 22      22              ConfigArgParse
# 23      23                      Crypto
# 24      24                      Cython
# 25      25                Distribution
# 26      26                       Fiona
# 27      27                         GCS
# 28      28                     IPython
# 29      29                   Interface
# 30      30                     License
# 31      31                       Magic
# 32      32                     Numeric
# 33      33                         Oct
# 34      34                     OpenSSL
# 35      35                      PyHive
# 36      36                     PyMySQL
# 37      37                       PyQt4
# 38      38                       PyQt5
# 39      39                      PySide
# 40      40                     PySide2
# 41      41                        PyTd
# 42      42                        Pyro
# 43      43                     SGETask
# 44      44                    SOFTWARE
# 45      45             SONManipulators
# 46      46                     Shapely
# 47      47                      System
# 48      48                 TableEditor
# 49      49                       UTS46
# 50      50                           V
# 51      51                  XlsxWriter
# 52      52                    __init__
# 53      53                       _root
# 54      54                    _version
# 55      55                           `
# 56      56                     ``PyQt5
# 57      57                        `sys
# 58      58                    `tornado
# 59      59                           a
# 60      60                     a2b_hex
# 61      61                         abc
# 62      62             absolute_import
# 63      63                     abspath
# 64      64    abstract_adapter_factory
# 65      65            abstract_factory
# 66      66        abstract_type_system
# 67      67                      action
# 68      68                     actions
# 69      69                       adapt
# 70      70                   adaptable
# 71      71                adapter_base
# 72      72             adapter_manager
# 73      73             add_parser_json
# 74      74                      adding
# 75      75                     address
# 76      76         adjusted_rand_score
# 77      77                        aeon
# 78      78                      affine
# 79      79        affinity_propagation
# 80      80                       again
# 81      81                         all
# 82      82                   all_names
# 83      83                  alloc_hook
# 84      84                          an
# 85      85              anaconda-clean
# 86      86            anaconda-project
# 87      87             anaconda-verify
# 88      88            anaconda_project
# 89      89             anaconda_verify
# 90      90                         and
# 91      91      animated_gif_editor_26
# 92      92      animated_gif_editor_28
# 93      93                         any
# 94      94  any_context_data_name_item
# 95      95          any_data_name_item
# 96      96                    anything
# 97      97                         api
# 98      98                      apigen
# 99      99                     appdirs
# ...    ...                         ...
# 1202  1202                         two
# 1203  1203                   type-safe
# 1204  1204                    typedefs
# 1205  1205                       types
# 1206  1206                   typeutils
# 1207  1207                           u
# 1208  1208            ufunc_docstrings
# 1209  1209                     ui_base
# 1210  1210                   ui_editor
# 1211  1211                    ui_panel
# 1212  1212                       uint8
# 1213  1213                      unichr
# 1214  1214                unicode_argv
# 1215  1215            unicode_literals
# 1216  1216           unicode_literals"
# 1217  1217                  unicodecsv
# 1218  1218                 unicodedata
# 1219  1219                    unittest
# 1220  1220                  unittest\r
# 1221  1221                   unittest2
# 1222  1222              unittest_tools
# 1223  1223                       until
# 1224  1224                     update1
# 1225  1225                     url_pat
# 1226  1226                      urllib
# 1227  1227                     urllib2
# 1228  1228                     urllib3
# 1229  1229                    urlparse
# 1230  1230              use_setuptools
# 1231  1231                  use_solver
# 1232  1232                        user
# 1233  1233           user_menu_manager
# 1234  1234               user_name_for
# 1235  1235                       using
# 1236  1236                        util
# 1237  1237                   utilities
# 1238  1238                       utils
# 1239  1239                        uuid
# 1240  1240                      uuid\r
# 1241  1241    validate_simple_password
# 1242  1242                     various
# 1243  1243                      vbench
# 1244  1244                 vcversioner
# 1245  1245                vcversioner;
# 1246  1246                  versioneer
# 1247  1247              view_as_blocks
# 1248  1248                     vincent
# 1249  1249                  virtualenv
# 1250  1250                      visvis
# 1251  1251                       w3lib
# 1252  1252                    waitress
# 1253  1253                        walk
# 1254  1254                    warnings
# 1255  1255                  warnings\r
# 1256  1256                   watershed
# 1257  1257                     wcwidth
# 1258  1258                     weakref
# 1259  1259                   weakref\r
# 1260  1260                  webbrowser
# 1261  1261                webencodings
# 1262  1262         webhdfs_minicluster
# 1263  1263                    werkzeug
# 1264  1264                       which
# 1265  1265                     widgets
# 1266  1266                        will
# 1267  1267         win-unicode-console
# 1268  1268               win32security
# 1269  1269         win_unicode_console
# 1270  1270                      windll
# 1271  1271                 winkerberos
# 1272  1272                      winreg
# 1273  1273                        with
# 1274  1274     with_directory_contents
# 1275  1275          with_file_contents
# 1276  1276                with_plugins
# 1277  1277              with_statement
# 1278  1278                      within
# 1279  1279                  workerpool
# 1280  1280                       wraps
# 1281  1281                       wrapt
# 1282  1282                     wsgiref
# 1283  1283                     wtforms
# 1284  1284                          wx
# 1285  1285        wxSerialConfigDialog
# 1286  1286                      xarray
# 1287  1287                  xlsxwriter
# 1288  1288                        xlwt
# 1289  1289                         xml
# 1290  1290               xmlrpc_client
# 1291  1291                   xmlrpclib
# 1292  1292                      xrange
# 1293  1293                        yaml
# 1294  1294                        yapf
# 1295  1295                        your
# 1296  1296                        zict
# 1297  1297                         zip
# 1298  1298                     zipfile
# 1299  1299                   zipimport
# 1300  1300                        zlib
# 1301  1301                         zmq
#
# [1302 rows x 2 columns]

# %% [markdown]
# Aqui observamos que ainda há algumas sujeiras. Elas vieram da relação de filhos (dependencias).
#
# Como aparentam ser poucos, neste momento, serão tratados manualmente dentro do Gephi.

# %%
#cria os edges
db_edges = pd.DataFrame({'Label' : [], 'Label2' : []})
db_edges
# Out:
# Empty DataFrame
# Columns: [Label, Label2]
# Index: []

# %%
#preenche o dataframe de edges

for pai in pacote_pacote:
    for filho in pacote_pacote[pai]:
        #verifica se o pacote se referência a ele mesmo
        if pai != filho[0]:
                db_edges = db_edges.append(pd.DataFrame([[pai, filho[0]]], columns=['Label', 'Label2']))

# %%
db_edges
# Out:
#                   Label                   Label2
# 0                affine                     math
# 0                affine                   pickle
# 0                affine          multiprocessing
# 0                affine                   codecs
# 0                affine               setuptools
# 0                affine                 unittest
# 0                affine                 textwrap
# 0                affine                     nose
# 0                affine              collections
# 0        anaconda-clean                      sys
# 0        anaconda-clean                       os
# 0        anaconda-clean                distutils
# 0        anaconda-clean                     time
# 0        anaconda-clean                 optparse
# 0      anaconda-project         anaconda_project
# 0      anaconda-project                       os
# 0      anaconda-project                      sys
# 0      anaconda-project                 platform
# 0      anaconda-project                   codecs
# 0      anaconda-project          absolute_import
# 0      anaconda-project                   pytest
# 0      anaconda-project                  tornado
# 0      anaconda-project                     copy
# 0      anaconda-project                    errno
# 0      anaconda-project                     json
# 0      anaconda-project                   shutil
# 0      anaconda-project              collections
# 0      anaconda-project               subprocess
# 0      anaconda-project                  zipfile
# 0      anaconda-project                     uuid
# 0      anaconda-project                      abc
# 0      anaconda-project                       re
# 0      anaconda-project                  logging
# 0      anaconda-project                    bokeh
# 0      anaconda-project                   socket
# 0      anaconda-project                 tempfile
# 0      anaconda-project  with_directory_contents
# 0      anaconda-project                    shlex
# 0      anaconda-project                   urllib
# 0      anaconda-project                functools
# 0      anaconda-project                   pandas
# 0      anaconda-project                      bs4
# 0      anaconda-project                 argparse
# 0      anaconda-project                  tarfile
# 0      anaconda-project                  difflib
# 0      anaconda-project                     time
# 0      anaconda-project                distutils
# 0      anaconda-project                   pprint
# 0      anaconda-project               contextlib
# 0      anaconda-project           print_function
# 0      anaconda-project     setup_atomic_replace
# 0      anaconda-project                     yapf
# 0      anaconda-project               webbrowser
# 0      anaconda-project              unicodedata
# 0      anaconda-project                     user
# 0      anaconda-project                    pipes
# 0      anaconda-project                    numpy
# 0      anaconda-project                  sqlite3
# 0      anaconda-project                  inspect
# 0      anaconda-project             load_project
# 0      anaconda-project                   falcon
# 0      anaconda-project                 gunicorn
# 0      anaconda-project          multiprocessing
# 0      anaconda-project                 requests
# 0      anaconda-project                threading
# 0      anaconda-project              ruamel_yaml
# 0      anaconda-project                  hashlib
# 0      anaconda-project                  getpass
# 0      anaconda-project       with_file_contents
# 0      anaconda-project                 SOFTWARE
# 0      anaconda-project                    email
# 0      anaconda-project                mimetypes
# 0      anaconda-project                  urllib3
# 0      anaconda-project                  fnmatch
# 0      anaconda-project                       io
# 0      anaconda-project                     glob
# 0      anaconda-project                   random
# 0      anaconda-project                     that
# 0      anaconda-project                     stat
# 0      anaconda-project                    place
# 0       anaconda-verify          anaconda_verify
# 0       anaconda-verify                       os
# 0       anaconda-verify                       re
# 0       anaconda-verify                      sys
# 0       anaconda-verify              collections
# 0       anaconda-verify                 optparse
# 0       anaconda-verify                distutils
# 0       anaconda-verify                     yaml
# 0       anaconda-verify                     json
# 0       anaconda-verify                    shlex
# 0       anaconda-verify                  tarfile
# 0               appdirs                      sys
# 0               appdirs                       os
# 0               appdirs               setuptools
# 0               appdirs                unittest2
# 0               appdirs                 unittest
# 0               appdirs                 platform
# 0               appnope                distutils
# 0               appnope                      sys
# 0               appnope                 platform
# ..                  ...                      ...
# 0              waitress                 platform
# 0              waitress                 warnings
# 0              waitress                 urlparse
# 0              waitress               contextlib
# 0              waitress                  profile
# 0              waitress                     stat
# 0              waitress                 calendar
# 0              waitress               setuptools
# 0              waitress                traceback
# 0              waitress      find_double_newline
# 0              waitress          multiprocessing
# 0              waitress                   string
# 0              waitress               subprocess
# 0              waitress            pkg_resources
# 0              waitress     pylons_sphinx_themes
# 0              waitress                 tempfile
# 0               wcwidth              unicodedata
# 0               wcwidth               setuptools
# 0               wcwidth                   ctypes
# 0               wcwidth                 warnings
# 0               wcwidth                   locale
# 0               wcwidth                      sys
# 0               wcwidth                       os
# 0               wcwidth                  urllib2
# 0               wcwidth                functools
# 0               wcwidth                  coding:
# 0   win-unicode-console                   ctypes
# 0   win-unicode-console                      sys
# 0   win-unicode-console                       io
# 0   win-unicode-console                traceback
# 0   win-unicode-console      win_unicode_console
# 0   win-unicode-console                   runner
# 0   win-unicode-console                 platform
# 0   win-unicode-console                raw_input
# 0   win-unicode-console             unicode_argv
# 0   win-unicode-console                       os
# 0   win-unicode-console               setuptools
# 0   win-unicode-console                     code
# 0   win-unicode-console                 warnings
# 0   win-unicode-console                 argparse
# 0   win-unicode-console                 tokenize
# 0   win-unicode-console                    types
# 0   win-unicode-console                     time
# 0   win-unicode-console                   codecs
# 0   win-unicode-console                       re
# 0            workerpool                      six
# 0            workerpool                      sys
# 0            workerpool                       os
# 0            workerpool                     glob
# 0            workerpool                 unittest
# 0            workerpool                     pep8
# 0            workerpool                 pyflakes
# 0            workerpool                     time
# 0            workerpool                     boto
# 0            workerpool                threading
# 0            workerpool               setuptools
# 0                 wrapt                 unittest
# 0                 wrapt                  inspect
# 0                 wrapt                   compat
# 0                 wrapt                      imp
# 0                 wrapt                      sys
# 0                 wrapt                distutils
# 0                 wrapt                threading
# 0                 wrapt                 operator
# 0                 wrapt                     hook
# 0                 wrapt                   pytest
# 0                 wrapt                       os
# 0                 wrapt                decorator
# 0                 wrapt                       gc
# 0                 wrapt                 builtins
# 0                 wrapt                functools
# 0                 wrapt                  weakref
# 0                 wrapt         sphinx_rtd_theme
# 0            XlsxWriter                 unittest
# 0            XlsxWriter                 datetime
# 0            XlsxWriter                      sys
# 0            XlsxWriter                       io
# 0            XlsxWriter                  decimal
# 0            XlsxWriter               subprocess
# 0            XlsxWriter                 warnings
# 0            XlsxWriter               setuptools
# 0            XlsxWriter                distutils
# 0            XlsxWriter                   urllib
# 0            XlsxWriter                       os
# 0            XlsxWriter               xlsxwriter
# 0                  zict                       os
# 0                  zict                      sys
# 0                  zict              collections
# 0                  zict                   pytest
# 0                  zict                   shutil
# 0                  zict                   urllib
# 0                  zict                  zipfile
# 0                  zict                itertools
# 0                  zict                       gc
# 0                  zict                 tempfile
# 0                  zict               setuptools
# 0                  zict                    errno
# 0                  zict                   random
# 0                  zict                   string
# 0                  zict                 heapdict
#
# [4420 rows x 2 columns]

# %%
db_edges = pd.merge(db_edges, db_nodes, how='left', on = 'Label')
db_edges = db_edges[['ID', 'Label2']]
db_edges.columns = ['Source','Label']
db_edges = pd.merge(db_edges, db_nodes, how='left', on = 'Label')
db_edges = db_edges[['Source', 'ID']]
db_edges.columns = ['Source','Target']
db_edges['Type'] = "Direct"
db_edges['Weight'] = 1
db_edges
# Out:
#       Source  Target    Type  Weight
# 0         78     683  Direct       1
# 1         78     835  Direct       1
# 2         78     724  Direct       1
# 3         78     213  Direct       1
# 4         78    1023  Direct       1
# 5         78    1219  Direct       1
# 6         78    1149  Direct       1
# 7         78     753  Direct       1
# 8         78     221  Direct       1
# 9         85    1118  Direct       1
# 10        85     793  Direct       1
# 11        85     337  Direct       1
# 12        85    1163  Direct       1
# 13        85     789  Direct       1
# 14        86      88  Direct       1
# 15        86     793  Direct       1
# 16        86    1118  Direct       1
# 17        86     847  Direct       1
# 18        86     213  Direct       1
# 19        86      62  Direct       1
# 20        86     911  Direct       1
# 21        86    1178  Direct       1
# 22        86     275  Direct       1
# 23        86     375  Direct       1
# 24        86     609  Direct       1
# 25        86    1032  Direct       1
# 26        86     221  Direct       1
# 27        86    1109  Direct       1
# 28        86    1298  Direct       1
# 29        86    1239  Direct       1
# 30        86      61  Direct       1
# 31        86     945  Direct       1
# 32        86     660  Direct       1
# 33        86     158  Direct       1
# 34        86    1054  Direct       1
# 35        86    1131  Direct       1
# 36        86    1274  Direct       1
# 37        86    1029  Direct       1
# 38        86    1226  Direct       1
# 39        86     446  Direct       1
# 40        86     803  Direct       1
# 41        86     163  Direct       1
# 42        86     104  Direct       1
# 43        86    1125  Direct       1
# 44        86     329  Direct       1
# 45        86    1163  Direct       1
# 46        86     337  Direct       1
# 47        86     854  Direct       1
# 48        86     265  Direct       1
# 49        86     859  Direct       1
# 50        86    1022  Direct       1
# 51        86    1294  Direct       1
# 52        86    1260  Direct       1
# 53        86    1218  Direct       1
# 54        86    1232  Direct       1
# 55        86     839  Direct       1
# 56        86     763  Direct       1
# 57        86    1082  Direct       1
# 58        86     571  Direct       1
# 59        86     648  Direct       1
# 60        86     401  Direct       1
# 61        86     498  Direct       1
# 62        86     724  Direct       1
# 63        86     961  Direct       1
# 64        86    1160  Direct       1
# 65        86     986  Direct       1
# 66        86     502  Direct       1
# 67        86     476  Direct       1
# 68        86    1275  Direct       1
# 69        86      44  Direct       1
# 70        86     363  Direct       1
# 71        86     693  Direct       1
# 72        86    1228  Direct       1
# 73        86     431  Direct       1
# 74        86     582  Direct       1
# 75        86     484  Direct       1
# 76        86     939  Direct       1
# 77        86    1150  Direct       1
# 78        86    1090  Direct       1
# 79        86     846  Direct       1
# 80        87      89  Direct       1
# 81        87     793  Direct       1
# 82        87     945  Direct       1
# 83        87    1118  Direct       1
# 84        87     221  Direct       1
# 85        87     789  Direct       1
# 86        87     337  Direct       1
# 87        87    1293  Direct       1
# 88        87     609  Direct       1
# 89        87    1029  Direct       1
# 90        87    1125  Direct       1
# 91        99    1118  Direct       1
# 92        99     793  Direct       1
# 93        99    1023  Direct       1
# 94        99    1221  Direct       1
# 95        99    1219  Direct       1
# 96        99     847  Direct       1
# 97       100     337  Direct       1
# 98       100    1118  Direct       1
# 99       100     847  Direct       1
# ...      ...     ...     ...     ...
# 4320    1252     847  Direct       1
# 4321    1252    1254  Direct       1
# 4322    1252    1229  Direct       1
# 4323    1252     265  Direct       1
# 4324    1252     862  Direct       1
# 4325    1252    1090  Direct       1
# 4326    1252     183  Direct       1
# 4327    1252    1023  Direct       1
# 4328    1252    1183  Direct       1
# 4329    1252     415  Direct       1
# 4330    1252     724  Direct       1
# 4331    1252    1100  Direct       1
# 4332    1252    1109  Direct       1
# 4333    1252     843  Direct       1
# 4334    1252     899  Direct       1
# 4335    1252    1131  Direct       1
# 4336    1257    1218  Direct       1
# 4337    1257    1023  Direct       1
# 4338    1257     293  Direct       1
# 4339    1257    1254  Direct       1
# 4340    1257     651  Direct       1
# 4341    1257    1118  Direct       1
# 4342    1257     793  Direct       1
# 4343    1257    1227  Direct       1
# 4344    1257     446  Direct       1
# 4345    1257     217  Direct       1
# 4346    1267     293  Direct       1
# 4347    1267    1118  Direct       1
# 4348    1267     582  Direct       1
# 4349    1267    1183  Direct       1
# 4350    1267    1269  Direct       1
# 4351    1267     990  Direct       1
# 4352    1267     847  Direct       1
# 4353    1267     944  Direct       1
# 4354    1267    1214  Direct       1
# 4355    1267     793  Direct       1
# 4356    1267    1023  Direct       1
# 4357    1267     210  Direct       1
# 4358    1267    1254  Direct       1
# 4359    1267     104  Direct       1
# 4360    1267    1175  Direct       1
# 4361    1267    1205  Direct       1
# 4362    1267    1163  Direct       1
# 4363    1267     213  Direct       1
# 4364    1267     945  Direct       1
# 4365    1279    1038  Direct       1
# 4366    1279    1118  Direct       1
# 4367    1279     793  Direct       1
# 4368    1279     484  Direct       1
# 4369    1279    1219  Direct       1
# 4370    1279     826  Direct       1
# 4371    1279     890  Direct       1
# 4372    1279    1163  Direct       1
# 4373    1279     159  Direct       1
# 4374    1279    1160  Direct       1
# 4375    1279    1023  Direct       1
# 4376    1281    1219  Direct       1
# 4377    1281     571  Direct       1
# 4378    1281     234  Direct       1
# 4379    1281     553  Direct       1
# 4380    1281    1118  Direct       1
# 4381    1281     337  Direct       1
# 4382    1281    1160  Direct       1
# 4383    1281     786  Direct       1
# 4384    1281     514  Direct       1
# 4385    1281     911  Direct       1
# 4386    1281     793  Direct       1
# 4387    1281     317  Direct       1
# 4388    1281     452  Direct       1
# 4389    1281     171  Direct       1
# 4390    1281     446  Direct       1
# 4391    1281    1258  Direct       1
# 4392    1281    1072  Direct       1
# 4393      51    1219  Direct       1
# 4394      51     310  Direct       1
# 4395      51    1118  Direct       1
# 4396      51     582  Direct       1
# 4397      51     316  Direct       1
# 4398      51    1109  Direct       1
# 4399      51    1254  Direct       1
# 4400      51    1023  Direct       1
# 4401      51     337  Direct       1
# 4402      51    1226  Direct       1
# 4403      51     793  Direct       1
# 4404      51    1287  Direct       1
# 4405    1296     793  Direct       1
# 4406    1296    1118  Direct       1
# 4407    1296     221  Direct       1
# 4408    1296     911  Direct       1
# 4409    1296    1032  Direct       1
# 4410    1296    1226  Direct       1
# 4411    1296    1298  Direct       1
# 4412    1296     600  Direct       1
# 4413    1296     452  Direct       1
# 4414    1296    1131  Direct       1
# 4415    1296    1023  Direct       1
# 4416    1296     375  Direct       1
# 4417    1296     939  Direct       1
# 4418    1296    1100  Direct       1
# 4419    1296     504  Direct       1
#
# [4420 rows x 4 columns]

# %% [markdown]
# Salva os csv`s!

# %%
db_nodes.to_csv(path_or_buf='db_nodes.csv', sep=';',na_rep=0, index=False)
db_edges.to_csv(path_or_buf='db_edges.csv', sep=';',na_rep=0,  index=False)
